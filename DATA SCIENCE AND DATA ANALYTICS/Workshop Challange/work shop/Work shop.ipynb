# %% [markdown]
# # WORKSHOP ON NUMPY PANDAS AND VISUALIZATIONS

# %%
"""
NAME    :   RANGUMUDRI VINAY SAI 
COURSE  :   DATA SCIENCE AND ANALIYTICS
"""
# Out:
# '\nNAME    :   RANGUMUDRI VINAY SAI \n\nCOURSE  :   DATA SCIENCE AND ANALIYTICS\n'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("city_day.csv.zip")
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.style.format({"Date": lambda t: t.strftime("%d-%m-%Y")})
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df['Date']=pd.to_datetime(df['Date']).dt.strftime('%d-%m-%Y')
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  01-01-2015    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  02-01-2015    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  03-01-2015    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  04-01-2015    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  05-01-2015    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  27-06-2020  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  28-06-2020  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  29-06-2020  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  30-06-2020  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  01-07-2020  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df1 = df.drop(['AQI', 'AQI_Bucket'], axis = 1)
df1
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  01-01-2015    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  02-01-2015    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  03-01-2015    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  04-01-2015    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  05-01-2015    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  27-06-2020  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  28-06-2020  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  29-06-2020  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  30-06-2020  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  01-07-2020  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     29531 non-null  object
#  1   Date     29531 non-null  object
#  2   PM2.5    24933 non-null  float64
#  3   PM10     18391 non-null  float64
#  4   NO       25949 non-null  float64
#  5   NO2      25946 non-null  float64
#  6   NOx      25346 non-null  float64
#  7   NH3      19203 non-null  float64
#  8   CO       27472 non-null  float64
#  9   SO2      25677 non-null  float64
#  10  O3       25509 non-null  float64
#  11  Benzene  23908 non-null  float64
#  12  Toluene  21490 non-null  float64
#  13  Xylene   11422 non-null  float64
# dtypes: float64(12), object(2)
# memory usage: 3.2+ MB

# %% [markdown]
# #### Prepare the Data
# #### We will now use pd to datetime() function from the Pandas module. The input to the pd to datetime() function is the Pandas series whose values are to be converted into datetime values
# #### Syntax: pd to datetime(series)
# #### The default format of a datetime value is YYYY-MM-DD.

# %%
df1["Date"]= pd.to_datetime(df1['Date'],format= '%d-%m-%Y')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     29531 non-null  object
#  1   Date     29531 non-null  datetime64[ns]
#  2   PM2.5    24933 non-null  float64
#  3   PM10     18391 non-null  float64
#  4   NO       25949 non-null  float64
#  5   NO2      25946 non-null  float64
#  6   NOx      25346 non-null  float64
#  7   NH3      19203 non-null  float64
#  8   CO       27472 non-null  float64
#  9   SO2      25677 non-null  float64
#  10  O3       25509 non-null  float64
#  11  Benzene  23908 non-null  float64
#  12  Toluene  21490 non-null  float64
#  13  Xylene   11422 non-null  float64
# dtypes: datetime64[ns](1), float64(12), object(1)
# memory usage: 3.2+ MB

# %%
#extracting date series
date_series=df1["Date"]
date_series
# Out:
# 0       2015-01-01
# 1       2015-01-02
# 2       2015-01-03
# 3       2015-01-04
# 4       2015-01-05
#            ...
# 29526   2020-06-27
# 29527   2020-06-28
# 29528   2020-06-29
# 29529   2020-06-30
# 29530   2020-07-01
# Name: Date, Length: 29531, dtype: datetime64[ns]

# %%
#extracting year from date
year_series = date_series.dt.year 
year_series
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 29526    2020
# 29527    2020
# 29528    2020
# 29529    2020
# 29530    2020
# Name: Date, Length: 29531, dtype: int64

# %%
#extracting month and day
month_series = date_series.dt.month 
day_series = date_series.dt.day

# %%
df1['year'] = year_series
df1['month'] = month_series
df1['day'] = day_series
df1
# Out:
#                 City       Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad 2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad 2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad 2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad 2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad 2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...        ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam 2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam 2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam 2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam 2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam 2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene  year  month  day
# ...

# %%
#Check for the missing values in the 'df' DataFrane. 
df1.isnull().sum()
# Out:
# City           0
# Date           0
# PM2.5       4598
# PM10       11140
# NO          3582
# NO2         3585
# NOx         4185
# NH3        10328
# CO          2059
# SO2         3854
# O3          4022
# Benzene     5623
# Toluene     8041
# Xylene     18109
# year           0
# month          0
# day            0
# dtype: int64

# %%
# Check for the missing values in the 'df' DataFrame.
df1.isnull()
# Out:
#         City   Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0      False  False   True   True  False  False  False   True  False  False
# 1      False  False   True   True  False  False  False   True  False  False
# 2      False  False   True   True  False  False  False   True  False  False
# 3      False  False   True   True  False  False  False   True  False  False
# 4      False  False   True   True  False  False  False   True  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  False  False  False  False  False  False  False  False  False  False
# 29527  False  False  False  False  False  False  False  False  False  False
# 29528  False  False  False  False  False  False  False  False  False  False
# 29529  False  False  False  False  False  False  False  False  False  False
# 29530  False  False  False  False  False  False  False  False  False  False
#
# ...

# %% [markdown]
# #### More than 10000 values contained in the PM10, NH3,Xylene columns are the missing (or null) values. So, let's drop these columns using the drop() function. It removes rows or columns by specifying lebel names and corresponding axis. We will specify the column names

# %%
#Drop the PM10, NH3, Xylene columns from the 'df' DataFrame.
df2 = df1.drop(columns=['PM10', 'NH3', 'Xylene'], axis = 1 )
df2
# Out:
#                 City       Date  PM2.5     NO    NO2    NOx     CO    SO2  \
# 0          Ahmedabad 2015-01-01    NaN   0.92  18.22  17.15   0.92  27.64
# 1          Ahmedabad 2015-01-02    NaN   0.97  15.69  16.46   0.97  24.55
# 2          Ahmedabad 2015-01-03    NaN  17.40  19.30  29.70  17.40  29.07
# 3          Ahmedabad 2015-01-04    NaN   1.70  18.48  17.97   1.70  18.59
# 4          Ahmedabad 2015-01-05    NaN  22.10  21.42  37.76  22.10  39.33
# ...              ...        ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam 2020-06-27  15.02   7.68  25.06  19.54   0.47   8.55
# 29527  Visakhapatnam 2020-06-28  24.38   3.42  26.06  16.53   0.52  12.72
# 29528  Visakhapatnam 2020-06-29  22.91   3.45  29.53  18.33   0.48   8.42
# 29529  Visakhapatnam 2020-06-30  16.64   4.05  29.26  18.80   0.52   9.84
# 29530  Visakhapatnam 2020-07-01  15.00   0.40  26.85  14.05   0.59   2.10
#
#            O3  Benzene  Toluene  year  month  day
# ...

# %%
#Get the List of columns present in the 'df' DataFrame after removing the PM10, NH3, Xylene columns.
df2.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'NO', 'NO2', 'NOx', 'CO', 'SO2', 'O3',
#        'Benzene', 'Toluene', 'year', 'month', 'day'],
#       dtype='object')

# %%
# Lets Check again for the missing values in the 'of' DataFrame.
df2.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5      4598
# NO         3582
# NO2        3585
# NOx        4185
# CO         2059
# SO2        3854
# O3         4022
# Benzene    5623
# Toluene    8041
# year          0
# month         0
# day           0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     29531 non-null  object
#  1   Date     29531 non-null  datetime64[ns]
#  2   PM2.5    24933 non-null  float64
#  3   NO       25949 non-null  float64
#  4   NO2      25946 non-null  float64
#  5   NOx      25346 non-null  float64
#  6   CO       27472 non-null  float64
#  7   SO2      25677 non-null  float64
#  8   O3       25509 non-null  float64
#  9   Benzene  23908 non-null  float64
#  10  Toluene  21490 non-null  float64
#  11  year     29531 non-null  int64
#  12  month    29531 non-null  int64
#  13  day      29531 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(1)
# memory usage: 3.2+ MB

# %% [markdown]
# #### We know that the other columns have missing values. So let's see which rows in the PM2.5 column are having missing values

# %%
df2[df2["PM2.5"].isnull() == True ]
# Out:
#                 City       Date  PM2.5     NO    NO2    NOx     CO    SO2  \
# 0          Ahmedabad 2015-01-01    NaN   0.92  18.22  17.15   0.92  27.64
# 1          Ahmedabad 2015-01-02    NaN   0.97  15.69  16.46   0.97  24.55
# 2          Ahmedabad 2015-01-03    NaN  17.40  19.30  29.70  17.40  29.07
# 3          Ahmedabad 2015-01-04    NaN   1.70  18.48  17.97   1.70  18.59
# 4          Ahmedabad 2015-01-05    NaN  22.10  21.42  37.76  22.10  39.33
# ...              ...        ...    ...    ...    ...    ...    ...    ...
# 29227  Visakhapatnam 2019-09-02    NaN    NaN    NaN    NaN    NaN    NaN
# 29228  Visakhapatnam 2019-09-03    NaN    NaN    NaN    NaN    NaN    NaN
# 29229  Visakhapatnam 2019-09-04    NaN    NaN    NaN    NaN    NaN    NaN
# 29462  Visakhapatnam 2020-04-24    NaN    NaN    NaN    NaN    NaN    NaN
# 29463  Visakhapatnam 2020-04-25    NaN    NaN    NaN    NaN    NaN    NaN
#
#            O3  Benzene  Toluene  year  month  day
# ...

# %%
#replace null values in each column
for col in df2.columns[2:-3]:
    row_ind = df2[df2[col].isnull() == True].index
    df2.loc[row_ind,col] = df2[col].median()

# %%
#Check for missing values again 
df2.isnull().sum()
# Out:
# City       0
# Date       0
# PM2.5      0
# NO         0
# NO2        0
# NOx        0
# CO         0
# SO2        0
# O3         0
# Benzene    0
# Toluene    0
# year       0
# month      0
# day        0
# dtype: int64

# %% [markdown]
# #### Analyze the Data - Data Transformation
# #### Group/Aggregation functions are the most commonly used functions for analysing

# %%
#Data frame with data about the year 2015. 
df_2015 = df2.loc[df2['year'] == 2015, df2.columns]
df_2015
# Out:
#             City       Date   PM2.5      NO    NO2     NOx     CO    SO2  \
# 0      Ahmedabad 2015-01-01   48.57    0.92  18.22   17.15   0.92  27.64
# 1      Ahmedabad 2015-01-02   48.57    0.97  15.69   16.46   0.97  24.55
# 2      Ahmedabad 2015-01-03   48.57   17.40  19.30   29.70  17.40  29.07
# 3      Ahmedabad 2015-01-04   48.57    1.70  18.48   17.97   1.70  18.59
# 4      Ahmedabad 2015-01-05   48.57   22.10  21.42   37.76  22.10  39.33
# ...          ...        ...     ...     ...    ...     ...    ...    ...
# 24073      Patna 2015-12-27  324.50   73.44  38.86  112.29   2.26   3.12
# 24074      Patna 2015-12-28  364.83   60.67  43.96  104.28   2.51   7.72
# 24075      Patna 2015-12-29  391.47   45.95  45.49   91.44   2.35   3.46
# 24076      Patna 2015-12-30  498.75  200.37  51.59  251.96   8.06   4.57
# 24077      Patna 2015-12-31  498.02  195.00  45.11  239.99   6.15   7.32
#
#            O3  Benzene  Toluene  year  month  day
# ...

# %%
#Data frame with data about the year 2016. 
df_2016 = df2.loc[df2['year'] == 2016, df2.columns]
df_2016
# Out:
#                 City       Date  PM2.5     NO    NO2    NOx    CO    SO2  \
# 365        Ahmedabad 2016-01-01  48.57   9.89  21.69  23.52  0.89   9.16
# 366        Ahmedabad 2016-01-02  48.57   9.89  21.69  23.52  0.89   9.16
# 367        Ahmedabad 2016-01-03  48.57   9.89  21.69  23.52  0.89   9.16
# 368        Ahmedabad 2016-01-04  48.57   9.89  21.69  23.52  0.89   9.16
# 369        Ahmedabad 2016-01-05  48.57   9.89  21.69  23.52  0.89   9.16
# ...              ...        ...    ...    ...    ...    ...   ...    ...
# 28248  Visakhapatnam 2016-12-27  66.59  31.18  53.96  53.86  1.55  12.91
# 28249  Visakhapatnam 2016-12-28  56.00   4.13  41.25  24.23  1.52  11.00
# 28250  Visakhapatnam 2016-12-29  56.00  20.37  57.45  44.24  1.69   8.02
# 28251  Visakhapatnam 2016-12-30  56.00  29.71  53.10  49.12  1.67   5.13
# 28252  Visakhapatnam 2016-12-31  71.19  19.61  55.17  42.59  1.57   6.80
#
#           O3  Benzene  Toluene  year  month  day
# ...

# %%
# Data frames for the year 2017, 2018, 2019, 2020.
df_2017 = df2.loc[df2['year'] == 2017, df2.columns]
df_2018 = df2.loc[df2['year'] == 2018, df2.columns]
df_2019 = df2.loc[df2['year'] == 2019, df2.columns]
df_2020 = df2.loc[df2['year'] == 2020, df2.columns]

# %%
df_2017
# Out:
#                 City       Date   PM2.5     NO    NO2    NOx    CO    SO2  \
# 731        Ahmedabad 2017-01-01   48.57   9.89  21.69  23.52  0.89   9.16
# 732        Ahmedabad 2017-01-02   48.57   9.89  21.69  23.52  0.89   9.16
# 733        Ahmedabad 2017-01-03   48.57   9.89  21.69  23.52  0.89   9.16
# 734        Ahmedabad 2017-01-04   48.57   9.89  21.69  23.52  0.89   9.16
# 735        Ahmedabad 2017-01-05   48.57   9.89  21.69  23.52  0.89   9.16
# ...              ...        ...     ...    ...    ...    ...   ...    ...
# 28613  Visakhapatnam 2017-12-27  101.93  15.87  55.93  42.58  1.20  16.39
# 28614  Visakhapatnam 2017-12-28   88.29  28.26  60.83  55.30  1.28  16.54
# 28615  Visakhapatnam 2017-12-29   52.25   9.07  52.56  35.20  1.08   6.26
# 28616  Visakhapatnam 2017-12-30   58.56   2.43  32.45  19.08  0.93   5.44
# 28617  Visakhapatnam 2017-12-31   67.75   1.62  23.54  13.63  0.93   8.38
#
#            O3  Benzene  Toluene  year  month  day
# ...

# %%
df_2018
# Out:
#                 City       Date   PM2.5     NO     NO2     NOx     CO     SO2  \
# 1096       Ahmedabad 2018-01-01   84.46   7.58   87.62   48.40   7.58  102.36
# 1097       Ahmedabad 2018-01-02   76.51   9.26   76.69   44.32   9.26  103.46
# 1098       Ahmedabad 2018-01-03   63.88  13.87   69.32   44.16  13.87   70.30
# 1099       Ahmedabad 2018-01-04   81.10  19.42  109.07   67.15  19.42   93.30
# 1100       Ahmedabad 2018-01-05   73.61  25.96  173.08  103.80  25.96   93.86
# ...              ...        ...     ...    ...     ...     ...    ...     ...
# 28978  Visakhapatnam 2018-12-27  111.24  31.43   79.61   67.90   0.92   19.05
# 28979  Visakhapatnam 2018-12-28  100.63  10.12   58.23   39.29   0.73   12.57
# 28980  Visakhapatnam 2018-12-29   77.43   3.76   40.68   24.69   0.65   17.41
# 28981  Visakhapatnam 2018-12-30   70.20   2.04   21.96   13.33   0.47   17.86
# 28982  Visakhapatnam 2018-12-31   67.62  21.63   82.71   61.57   1.09   25.66
#
# ...

# %%
df_2019
# Out:
#                 City       Date   PM2.5      NO     NO2     NOx      CO  \
# 1461       Ahmedabad 2019-01-01  110.71   63.03  111.56  100.04   63.03
# 1462       Ahmedabad 2019-01-02  147.57   59.56  107.46  129.87   59.56
# 1463       Ahmedabad 2019-01-03  131.50  119.68   75.82   88.04  119.68
# 1464       Ahmedabad 2019-01-04  102.12   57.92   95.29   54.93   57.92
# 1465       Ahmedabad 2019-01-05  115.00   63.86  111.04   61.99   63.86
# ...              ...        ...     ...     ...     ...     ...     ...
# 29343  Visakhapatnam 2019-12-27   51.79   34.78   48.39   54.01    1.24
# 29344  Visakhapatnam 2019-12-28   74.53    4.21   33.50   21.25    1.21
# 29345  Visakhapatnam 2019-12-29   41.00    2.37   20.94   13.07    0.74
# 29346  Visakhapatnam 2019-12-30   44.79    3.22   35.67   21.58    1.06
# 29347  Visakhapatnam 2019-12-31   52.33    3.51   33.70   20.78    1.13
#
#          SO2     O3  Benzene  Toluene  year  month  day
# ...

# %%
df_2020
# Out:
#                 City       Date  PM2.5    NO    NO2    NOx    CO    SO2  \
# 1826       Ahmedabad 2020-01-01  79.57  3.78  12.64   8.99  3.78  27.70
# 1827       Ahmedabad 2020-01-02  72.59  3.63  14.38   9.73  3.63  23.96
# 1828       Ahmedabad 2020-01-03  69.54  7.06  15.13  12.65  7.06  35.78
# 1829       Ahmedabad 2020-01-04  66.20  8.97  20.79  16.84  8.97  38.98
# 1830       Ahmedabad 2020-01-05  55.99  5.41  15.34  11.53  5.41  45.83
# ...              ...        ...    ...   ...    ...    ...   ...    ...
# 29526  Visakhapatnam 2020-06-27  15.02  7.68  25.06  19.54  0.47   8.55
# 29527  Visakhapatnam 2020-06-28  24.38  3.42  26.06  16.53  0.52  12.72
# 29528  Visakhapatnam 2020-06-29  22.91  3.45  29.53  18.33  0.48   8.42
# 29529  Visakhapatnam 2020-06-30  16.64  4.05  29.26  18.80  0.52   9.84
# 29530  Visakhapatnam 2020-07-01  15.00  0.40  26.85  14.05  0.59   2.10
#
#           O3  Benzene  Toluene  year  month  day
# 1826   23.67     4.21    31.42  2020      1    1
# ...

# %%
#Lets group the data frame year wise using groupby() and get the data for 2020 year 
gp_year = df2.groupby(by='year') 
yr_2019 = gp_year.get_group(2019) 
yr_2020 = gp_year.get_group(2020)
yr_2020
# Out:
#                 City       Date  PM2.5    NO    NO2    NOx    CO    SO2  \
# 1826       Ahmedabad 2020-01-01  79.57  3.78  12.64   8.99  3.78  27.70
# 1827       Ahmedabad 2020-01-02  72.59  3.63  14.38   9.73  3.63  23.96
# 1828       Ahmedabad 2020-01-03  69.54  7.06  15.13  12.65  7.06  35.78
# 1829       Ahmedabad 2020-01-04  66.20  8.97  20.79  16.84  8.97  38.98
# 1830       Ahmedabad 2020-01-05  55.99  5.41  15.34  11.53  5.41  45.83
# ...              ...        ...    ...   ...    ...    ...   ...    ...
# 29526  Visakhapatnam 2020-06-27  15.02  7.68  25.06  19.54  0.47   8.55
# 29527  Visakhapatnam 2020-06-28  24.38  3.42  26.06  16.53  0.52  12.72
# 29528  Visakhapatnam 2020-06-29  22.91  3.45  29.53  18.33  0.48   8.42
# 29529  Visakhapatnam 2020-06-30  16.64  4.05  29.26  18.80  0.52   9.84
# 29530  Visakhapatnam 2020-07-01  15.00  0.40  26.85  14.05  0.59   2.10
#
#           O3  Benzene  Toluene  year  month  day
# 1826   23.67     4.21    31.42  2020      1    1
# ...

# %%
yr_2019
# Out:
#                 City       Date   PM2.5      NO     NO2     NOx      CO  \
# 1461       Ahmedabad 2019-01-01  110.71   63.03  111.56  100.04   63.03
# 1462       Ahmedabad 2019-01-02  147.57   59.56  107.46  129.87   59.56
# 1463       Ahmedabad 2019-01-03  131.50  119.68   75.82   88.04  119.68
# 1464       Ahmedabad 2019-01-04  102.12   57.92   95.29   54.93   57.92
# 1465       Ahmedabad 2019-01-05  115.00   63.86  111.04   61.99   63.86
# ...              ...        ...     ...     ...     ...     ...     ...
# 29343  Visakhapatnam 2019-12-27   51.79   34.78   48.39   54.01    1.24
# 29344  Visakhapatnam 2019-12-28   74.53    4.21   33.50   21.25    1.21
# 29345  Visakhapatnam 2019-12-29   41.00    2.37   20.94   13.07    0.74
# 29346  Visakhapatnam 2019-12-30   44.79    3.22   35.67   21.58    1.06
# 29347  Visakhapatnam 2019-12-31   52.33    3.51   33.70   20.78    1.13
#
#          SO2     O3  Benzene  Toluene  year  month  day
# ...

# %%
# Apply mean and median for all the years using agg().
gp_year.agg(func=['mean', 'median'])
# Out:
#                               Date                 PM2.5                 NO  \
#                               mean     median       mean  median       mean
# year
# 2015 2015-07-10 00:34:26.690467584 2015-07-14  71.598547  48.570  15.524477
# 2016 2016-07-06 07:32:32.156411648 2016-07-11  81.755871  48.570  17.205483
# 2017 2017-07-16 13:38:07.140115200 2017-07-22  74.888812  48.570  15.576488
# 2018 2018-07-04 00:50:04.172461824 2018-07-05  66.210261  48.570  17.945729
# 2019 2019-07-11 01:11:10.104754176 2019-07-16  58.525747  45.970  16.252667
# 2020 2020-04-02 14:00:15.497201920 2020-04-03  44.079363  35.415  16.781229
#
#                     NO2               NOx         ...         O3          \
#       median       mean median       mean median  ...       mean  median
# year                                              ...
# 2015   9.890  23.406148  21.29  35.202342  22.27  ...  32.577522  30.840
# 2016   9.890  29.134848  21.69  29.415765  23.52  ...  36.315046  30.840
# ...

# %%
# Find median of CO in each year 
gp_year[['CO']].median()
# Out:
#         CO
# year
# 2015  1.58
# 2016  0.96
# 2017  0.65
# 2018  0.90
# 2019  0.89
# 2020  0.76

# %%
#Group the data by month using groupby() 
gp_month = df2.groupby(by='month')
gp_month.get_group(12)
# Out:
#                 City       Date  PM2.5     NO    NO2    NOx    CO   SO2  \
# 334        Ahmedabad 2015-12-01  48.57   9.89  21.69  23.52  0.89  9.16
# 335        Ahmedabad 2015-12-02  48.57   9.89  21.69  23.52  0.89  9.16
# 336        Ahmedabad 2015-12-03  48.57   9.89  21.69  23.52  0.89  9.16
# 337        Ahmedabad 2015-12-04  48.57   9.89  21.69  23.52  0.89  9.16
# 338        Ahmedabad 2015-12-05  48.57   9.89  21.69  23.52  0.89  9.16
# ...              ...        ...    ...    ...    ...    ...   ...   ...
# 29343  Visakhapatnam 2019-12-27  51.79  34.78  48.39  54.01  1.24  9.01
# 29344  Visakhapatnam 2019-12-28  74.53   4.21  33.50  21.25  1.21  6.30
# 29345  Visakhapatnam 2019-12-29  41.00   2.37  20.94  13.07  0.74  6.25
# 29346  Visakhapatnam 2019-12-30  44.79   3.22  35.67  21.58  1.06  9.71
# 29347  Visakhapatnam 2019-12-31  52.33   3.51  33.70  20.78  1.13  8.44
#
#           O3  Benzene  Toluene  year  month  day
# 334    30.84     1.07     2.97  2015     12    1
# ...

# %%
gp_month ['PM2.5'].median()
# Out:
# month
# 1     67.990
# 2     57.830
# 3     48.570
# 4     48.570
# 5     45.670
# 6     39.810
# 7     35.415
# 8     34.800
# 9     37.510
# 10    50.810
# 11    69.700
# 12    71.570
# Name: PM2.5, dtype: float64

# %%
# Apply different functions on different columns using dictionary in the agg()
gp_month.agg (func={'PM2.5': ['min', 'max'], 'month': 'count'})
#month_min_max =
#month_min_max
# Out:
#       PM2.5         month
#         min     max count
# month
# 1      2.85  553.63  2621
# 2      3.42  525.09  2457
# 3      7.73  914.94  2749
# 4      1.97  389.54  2702
# 5      1.96  916.67  2821
# 6      0.16  571.02  2811
# 7      2.00  858.73  2196
# 8      2.54  949.99  2175
# 9      0.04  917.77  2173
# 10     3.18  516.20  2263
# 11     4.23  685.36  2201
# 12     1.72  645.50  2362

# %%
gp_month_2020 = yr_2020.groupby(by='month')
gp_month_2019 = yr_2019.groupby(by='month')  
gp_month_2020

# %%
gp_month_2019

# %%
gp_month_2020.median()
# Out:
#         PM2.5      NO     NO2     NOx     CO     SO2      O3  Benzene  \
# month
# 1      59.900  10.740  25.070  30.050  0.990   9.720  30.670     1.17
# 2      55.330  13.340  25.160  30.220  0.960  10.310  35.680     1.07
# 3      36.045   8.145  17.545  21.900  0.795   9.710  33.450     1.07
# 4      26.670   6.240  12.015  13.665  0.600   9.160  31.900     1.07
# 5      23.220   5.780  13.700  15.155  0.650   8.980  32.545     1.07
# 6      20.805   6.925  13.230  15.870  0.610   9.160  30.450     1.07
# 7      25.840   6.105  10.800  14.970  0.590   7.115  19.775     1.07
#
#        Toluene    year   day
# month
# 1         2.97  2020.0  16.0
# 2         2.97  2020.0  15.0
# 3         2.97  2020.0  16.0
# 4         2.97  2020.0  15.5
# 5         2.97  2020.0  16.0
# 6         2.97  2020.0  15.5
# 7         2.97  2020.0   1.0

# %% [markdown]
# #### Share/Visualize the data
# #### Line plots, Bar charts, Pie charts are an effective way to show the results

# %%
#plot the graph for median Carbon Monoxide (CO) concentration
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('Yearly Median CO Concentration')
plt.plot(df2['year'].unique(), gp_year['CO'].median())
plt.xlabel('year')
plt.ylabel('Responses')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('Yearly Median NO Concentration')
plt.plot(df2['year'].unique(), gp_year['NO'].median())
plt.xlabel('year')
plt.ylabel('Responses')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('Yearly Median NO2 Concentration')
plt.plot(df2['year'].unique(), gp_year['NO2'].median())
plt.xlabel('year')
plt.ylabel('Responses')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('Yearly Median PM2.5 Concentration')
plt.plot(df2['year'].unique(), gp_year['PM2.5'].median())
plt.xlabel('year')
plt.ylabel('Responses')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.title('Yearly Median SO2 Concentration')
plt.plot(df2['year'].unique(), gp_year['SO2'].median())
plt.xlabel('year')
plt.ylabel('Responses')
plt.grid(True)
plt.show()
