# %% [markdown]
# ### 1. Install Python, Anaconda and MySQL Connector

# %% [markdown]
# -- python, Anaconda and MySQL are installed
#
# -- python, Anaconda and MySQL are Connected

# %% [markdown]
# ### 2. Connect with schema sakila through python MySQL Connector

# %%
import mysql.connector
testdb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1321",
    database="sakila")
testcursor = testdb.cursor()

# %%
testcursor.execute("SHOW DATABASES")
for x in testcursor:
    print(x)
# Out:
# ('backup_sakila',)
# ('ecommerce',)
# ('employee5',)
# ('employees',)
# ('employees2',)
# ('employees3',)
# ('employees4',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('test',)
# ('world',)

# %% [markdown]
# ### 3. Run describe command for table language and rental through python code

# %%
testcursor.execute("show tables")
for a in testcursor:
    print(a)
# Out:
# ('active_customer',)
# ('actor',)
# ('actor_info',)
# ('address',)
# ('category',)
# ('city',)
# ('country',)
# ('customer',)
# ('customer_list',)
# ('film',)
# ('film_actor',)
# ('film_category',)
# ('film_list',)
# ('film_text',)
# ('inventory',)
# ('language',)
# ('nicer_but_slower_film_list',)
# ('payment',)
# ('product',)
# ('rental',)
# ('sales_by_film_category',)
# ('sales_by_store',)
# ('staff',)
# ('staff_list',)
# ('store',)

# %%
# Desc Command for language table
import mysql.connector
testdb = mysql.connector.connect(
host="localhost",
user="root",
password="1321",
database="sakila")
testcursor = testdb.cursor()
testcursor.execute("DESC language")
for a in testcursor:
    print(a)
# Out:
# ('language_id', b'tinyint unsigned', 'NO', 'PRI', None, 'auto_increment')
# ('name', b'char(20)', 'NO', '', None, '')
# ('last_update', b'timestamp', 'NO', '', b'CURRENT_TIMESTAMP', 'DEFAULT_GENERATED on update CURRENT_TIMESTAMP')

# %%
# Desc Command for rental table
import mysql.connector
testdb = mysql.connector.connect(
host="localhost",
user="root",
password="1321",
database="sakila")
testcursor = testdb.cursor()
testcursor.execute("DESC rental")
for b in testcursor:
    print(b)
# Out:
# ('rental_id', b'int', 'NO', 'PRI', None, 'auto_increment')
# ('rental_date', b'datetime', 'NO', 'MUL', None, '')
# ('inventory_id', b'mediumint unsigned', 'NO', 'MUL', None, '')
# ('customer_id', b'smallint unsigned', 'NO', 'MUL', None, '')
# ('return_date', b'datetime', 'YES', '', None, '')
# ('staff_id', b'tinyint unsigned', 'NO', 'MUL', None, '')
# ('last_update', b'timestamp', 'NO', '', b'CURRENT_TIMESTAMP', 'DEFAULT_GENERATED on update CURRENT_TIMESTAMP')

# %% [markdown]
# ### 4. Write code to display result set from three tables store, inventory and film_text using inner join through python.

# %%
testdb=mysql.connector.connect(host="localhost",user="root",password="1321",database="sakila")
testcursor=testdb.cursor()
testcursor.execute('''
                    select s.store_id,s.manager_staff_id,s.address_id,i.inventory_id,f.film_id,f.title
                    from store s inner join inventory i on s.store_id=i.store_id
                    inner join film_text f on i.film_id=f.film_id
                    order by f.title''')
a=testcursor.fetchall()
for i in a :
    print(i)
# Out:
# (2, 2, 2, 5, 1, 'ACADEMY DINOSAUR')
# (2, 2, 2, 6, 1, 'ACADEMY DINOSAUR')
# (2, 2, 2, 7, 1, 'ACADEMY DINOSAUR')
# (2, 2, 2, 8, 1, 'ACADEMY DINOSAUR')
# (1, 1, 1, 1, 1, 'ACADEMY DINOSAUR')
# (1, 1, 1, 2, 1, 'ACADEMY DINOSAUR')
# (1, 1, 1, 3, 1, 'ACADEMY DINOSAUR')
# (1, 1, 1, 4, 1, 'ACADEMY DINOSAUR')
# (2, 2, 2, 9, 2, 'ACE GOLDFINGER')
# (2, 2, 2, 10, 2, 'ACE GOLDFINGER')
# (2, 2, 2, 11, 2, 'ACE GOLDFINGER')
# (2, 2, 2, 12, 3, 'ADAPTATION HOLES')
# (2, 2, 2, 13, 3, 'ADAPTATION HOLES')
# (2, 2, 2, 14, 3, 'ADAPTATION HOLES')
# (2, 2, 2, 15, 3, 'ADAPTATION HOLES')
# (2, 2, 2, 20, 4, 'AFFAIR PREJUDICE')
# (2, 2, 2, 21, 4, 'AFFAIR PREJUDICE')
# (2, 2, 2, 22, 4, 'AFFAIR PREJUDICE')
# (1, 1, 1, 16, 4, 'AFFAIR PREJUDICE')
# (1, 1, 1, 17, 4, 'AFFAIR PREJUDICE')
# (1, 1, 1, 18, 4, 'AFFAIR PREJUDICE')
# (1, 1, 1, 19, 4, 'AFFAIR PREJUDICE')
# (2, 2, 2, 23, 5, 'AFRICAN EGG')
# (2, 2, 2, 24, 5, 'AFRICAN EGG')
# (2, 2, 2, 25, 5, 'AFRICAN EGG')
# (2, 2, 2, 29, 6, 'AGENT TRUMAN')
# (2, 2, 2, 30, 6, 'AGENT TRUMAN')
# (2, 2, 2, 31, 6, 'AGENT TRUMAN')
# (1, 1, 1, 26, 6, 'AGENT TRUMAN')
# (1, 1, 1, 27, 6, 'AGENT TRUMAN')
# (1, 1, 1, 28, 6, 'AGENT TRUMAN')
# (1, 1, 1, 32, 7, 'AIRPLANE SIERRA')
# (1, 1, 1, 33, 7, 'AIRPLANE SIERRA')
# (2, 2, 2, 34, 7, 'AIRPLANE SIERRA')
# (2, 2, 2, 35, 7, 'AIRPLANE SIERRA')
# (2, 2, 2, 36, 7, 'AIRPLANE SIERRA')
# (2, 2, 2, 37, 8, 'AIRPORT POLLOCK')
# (2, 2, 2, 38, 8, 'AIRPORT POLLOCK')
# (2, 2, 2, 39, 8, 'AIRPORT POLLOCK')
# (2, 2, 2, 40, 8, 'AIRPORT POLLOCK')
# (2, 2, 2, 44, 9, 'ALABAMA DEVIL')
# (2, 2, 2, 45, 9, 'ALABAMA DEVIL')
# (1, 1, 1, 41, 9, 'ALABAMA DEVIL')
# (1, 1, 1, 42, 9, 'ALABAMA DEVIL')
# (1, 1, 1, 43, 9, 'ALABAMA DEVIL')
# (1, 1, 1, 46, 10, 'ALADDIN CALENDAR')
# (1, 1, 1, 47, 10, 'ALADDIN CALENDAR')
# (1, 1, 1, 48, 10, 'ALADDIN CALENDAR')
# (1, 1, 1, 49, 10, 'ALADDIN CALENDAR')
# (2, 2, 2, 50, 10, 'ALADDIN CALENDAR')
# (2, 2, 2, 51, 10, 'ALADDIN CALENDAR')
# (2, 2, 2, 52, 10, 'ALADDIN CALENDAR')
# (2, 2, 2, 57, 11, 'ALAMO VIDEOTAPE')
# (2, 2, 2, 58, 11, 'ALAMO VIDEOTAPE')
# (2, 2, 2, 59, 11, 'ALAMO VIDEOTAPE')
# (1, 1, 1, 53, 11, 'ALAMO VIDEOTAPE')
# (1, 1, 1, 54, 11, 'ALAMO VIDEOTAPE')
# (1, 1, 1, 55, 11, 'ALAMO VIDEOTAPE')
# (1, 1, 1, 56, 11, 'ALAMO VIDEOTAPE')
# (1, 1, 1, 60, 12, 'ALASKA PHANTOM')
# (1, 1, 1, 61, 12, 'ALASKA PHANTOM')
# (1, 1, 1, 62, 12, 'ALASKA PHANTOM')
# (2, 2, 2, 63, 12, 'ALASKA PHANTOM')
# (2, 2, 2, 64, 12, 'ALASKA PHANTOM')
# (2, 2, 2, 65, 12, 'ALASKA PHANTOM')
# (2, 2, 2, 66, 12, 'ALASKA PHANTOM')
# (2, 2, 2, 67, 13, 'ALI FOREVER')
# (2, 2, 2, 68, 13, 'ALI FOREVER')
# (2, 2, 2, 69, 13, 'ALI FOREVER')
# (2, 2, 2, 70, 13, 'ALI FOREVER')
# (2, 2, 2, 73, 15, 'ALIEN CENTER')
# (2, 2, 2, 74, 15, 'ALIEN CENTER')
# (2, 2, 2, 75, 15, 'ALIEN CENTER')
# (2, 2, 2, 76, 15, 'ALIEN CENTER')
# (1, 1, 1, 71, 15, 'ALIEN CENTER')
# (1, 1, 1, 72, 15, 'ALIEN CENTER')
# (1, 1, 1, 77, 16, 'ALLEY EVOLUTION')
# (1, 1, 1, 78, 16, 'ALLEY EVOLUTION')
# (2, 2, 2, 79, 16, 'ALLEY EVOLUTION')
# (2, 2, 2, 80, 16, 'ALLEY EVOLUTION')
# (2, 2, 2, 84, 17, 'ALONE TRIP')
# (2, 2, 2, 85, 17, 'ALONE TRIP')
# (2, 2, 2, 86, 17, 'ALONE TRIP')
# (1, 1, 1, 81, 17, 'ALONE TRIP')
# (1, 1, 1, 82, 17, 'ALONE TRIP')
# (1, 1, 1, 83, 17, 'ALONE TRIP')
# (1, 1, 1, 87, 18, 'ALTER VICTORY')
# (1, 1, 1, 88, 18, 'ALTER VICTORY')
# (1, 1, 1, 89, 18, 'ALTER VICTORY')
# (2, 2, 2, 90, 18, 'ALTER VICTORY')
# (2, 2, 2, 91, 18, 'ALTER VICTORY')
# (2, 2, 2, 92, 18, 'ALTER VICTORY')
# (2, 2, 2, 97, 19, 'AMADEUS HOLY')
# (2, 2, 2, 98, 19, 'AMADEUS HOLY')
# (1, 1, 1, 93, 19, 'AMADEUS HOLY')
# (1, 1, 1, 94, 19, 'AMADEUS HOLY')
# (1, 1, 1, 95, 19, 'AMADEUS HOLY')
# (1, 1, 1, 96, 19, 'AMADEUS HOLY')
# (1, 1, 1, 99, 20, 'AMELIE HELLFIGHTERS')
# (1, 1, 1, 100, 20, 'AMELIE HELLFIGHTERS')
# (1, 1, 1, 101, 20, 'AMELIE HELLFIGHTERS')
# (1, 1, 1, 102, 21, 'AMERICAN CIRCUS')
# (1, 1, 1, 103, 21, 'AMERICAN CIRCUS')
# (2, 2, 2, 104, 21, 'AMERICAN CIRCUS')
# (2, 2, 2, 105, 21, 'AMERICAN CIRCUS')
# (2, 2, 2, 106, 21, 'AMERICAN CIRCUS')
# (2, 2, 2, 107, 21, 'AMERICAN CIRCUS')
# (2, 2, 2, 112, 22, 'AMISTAD MIDSUMMER')
# (2, 2, 2, 113, 22, 'AMISTAD MIDSUMMER')
# (2, 2, 2, 114, 22, 'AMISTAD MIDSUMMER')
# (1, 1, 1, 108, 22, 'AMISTAD MIDSUMMER')
# (1, 1, 1, 109, 22, 'AMISTAD MIDSUMMER')
# (1, 1, 1, 110, 22, 'AMISTAD MIDSUMMER')
# (1, 1, 1, 111, 22, 'AMISTAD MIDSUMMER')
# (1, 1, 1, 115, 23, 'ANACONDA CONFESSIONS')
# (1, 1, 1, 116, 23, 'ANACONDA CONFESSIONS')
# (1, 1, 1, 117, 23, 'ANACONDA CONFESSIONS')
# (2, 2, 2, 118, 23, 'ANACONDA CONFESSIONS')
# (2, 2, 2, 119, 23, 'ANACONDA CONFESSIONS')
# (1, 1, 1, 120, 24, 'ANALYZE HOOSIERS')
# (1, 1, 1, 121, 24, 'ANALYZE HOOSIERS')
# (1, 1, 1, 122, 24, 'ANALYZE HOOSIERS')
# (1, 1, 1, 123, 24, 'ANALYZE HOOSIERS')
# (1, 1, 1, 124, 25, 'ANGELS LIFE')
# (1, 1, 1, 125, 25, 'ANGELS LIFE')
# (1, 1, 1, 126, 25, 'ANGELS LIFE')
# (1, 1, 1, 127, 25, 'ANGELS LIFE')
# (2, 2, 2, 128, 25, 'ANGELS LIFE')
# (2, 2, 2, 129, 25, 'ANGELS LIFE')
# (2, 2, 2, 132, 26, 'ANNIE IDENTITY')
# (2, 2, 2, 133, 26, 'ANNIE IDENTITY')
# (2, 2, 2, 134, 26, 'ANNIE IDENTITY')
# (1, 1, 1, 130, 26, 'ANNIE IDENTITY')
# (1, 1, 1, 131, 26, 'ANNIE IDENTITY')
# (1, 1, 1, 135, 27, 'ANONYMOUS HUMAN')
# (1, 1, 1, 136, 27, 'ANONYMOUS HUMAN')
# (1, 1, 1, 137, 27, 'ANONYMOUS HUMAN')
# (1, 1, 1, 138, 27, 'ANONYMOUS HUMAN')
# (1, 1, 1, 139, 28, 'ANTHEM LUKE')
# (1, 1, 1, 140, 28, 'ANTHEM LUKE')
# (1, 1, 1, 141, 28, 'ANTHEM LUKE')
# (1, 1, 1, 142, 29, 'ANTITRUST TOMATOES')
# (1, 1, 1, 143, 29, 'ANTITRUST TOMATOES')
# (1, 1, 1, 144, 30, 'ANYTHING SAVANNAH')
# (1, 1, 1, 145, 30, 'ANYTHING SAVANNAH')
# (1, 1, 1, 146, 31, 'APACHE DIVINE')
# (1, 1, 1, 147, 31, 'APACHE DIVINE')
# (1, 1, 1, 148, 31, 'APACHE DIVINE')
# (1, 1, 1, 149, 31, 'APACHE DIVINE')
# (2, 2, 2, 150, 31, 'APACHE DIVINE')
# (2, 2, 2, 151, 31, 'APACHE DIVINE')
# (2, 2, 2, 152, 31, 'APACHE DIVINE')
# (2, 2, 2, 153, 31, 'APACHE DIVINE')
# (2, 2, 2, 154, 32, 'APOCALYPSE FLAMINGOS')
# (2, 2, 2, 155, 32, 'APOCALYPSE FLAMINGOS')
# (2, 2, 2, 156, 34, 'ARABIA DOGMA')
# (2, 2, 2, 157, 34, 'ARABIA DOGMA')
# (2, 2, 2, 158, 34, 'ARABIA DOGMA')
# (2, 2, 2, 159, 34, 'ARABIA DOGMA')
# (2, 2, 2, 164, 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# (2, 2, 2, 165, 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# (2, 2, 2, 166, 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# (1, 1, 1, 160, 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# (1, 1, 1, 161, 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# (1, 1, 1, 162, 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# (1, 1, 1, 163, 35, 'ARACHNOPHOBIA ROLLERCOASTER')
# (1, 1, 1, 167, 37, 'ARIZONA BANG')
# (1, 1, 1, 168, 37, 'ARIZONA BANG')
# (1, 1, 1, 169, 37, 'ARIZONA BANG')
# (1, 1, 1, 170, 37, 'ARIZONA BANG')
# (2, 2, 2, 171, 37, 'ARIZONA BANG')
# (2, 2, 2, 172, 37, 'ARIZONA BANG')
# (2, 2, 2, 173, 37, 'ARIZONA BANG')
# (2, 2, 2, 177, 39, 'ARMAGEDDON LOST')
# (2, 2, 2, 178, 39, 'ARMAGEDDON LOST')
# (2, 2, 2, 179, 39, 'ARMAGEDDON LOST')
# (2, 2, 2, 180, 39, 'ARMAGEDDON LOST')
# (1, 1, 1, 174, 39, 'ARMAGEDDON LOST')
# (1, 1, 1, 175, 39, 'ARMAGEDDON LOST')
# (1, 1, 1, 176, 39, 'ARMAGEDDON LOST')
# (2, 2, 2, 181, 40, 'ARMY FLINTSTONES')
# (2, 2, 2, 182, 40, 'ARMY FLINTSTONES')
# (2, 2, 2, 183, 40, 'ARMY FLINTSTONES')
# (2, 2, 2, 184, 40, 'ARMY FLINTSTONES')
# (2, 2, 2, 185, 42, 'ARTIST COLDBLOODED')
# (2, 2, 2, 186, 42, 'ARTIST COLDBLOODED')
# (2, 2, 2, 187, 42, 'ARTIST COLDBLOODED')
# (2, 2, 2, 188, 42, 'ARTIST COLDBLOODED')
# (2, 2, 2, 192, 43, 'ATLANTIS CAUSE')
# (2, 2, 2, 193, 43, 'ATLANTIS CAUSE')
# (2, 2, 2, 194, 43, 'ATLANTIS CAUSE')
# (2, 2, 2, 195, 43, 'ATLANTIS CAUSE')
# (1, 1, 1, 189, 43, 'ATLANTIS CAUSE')
# (1, 1, 1, 190, 43, 'ATLANTIS CAUSE')
# (1, 1, 1, 191, 43, 'ATLANTIS CAUSE')
# (1, 1, 1, 196, 44, 'ATTACKS HATE')
# (1, 1, 1, 197, 44, 'ATTACKS HATE')
# (2, 2, 2, 198, 44, 'ATTACKS HATE')
# (2, 2, 2, 199, 44, 'ATTACKS HATE')
# (2, 2, 2, 200, 44, 'ATTACKS HATE')
# (2, 2, 2, 205, 45, 'ATTRACTION NEWTON')
# (2, 2, 2, 206, 45, 'ATTRACTION NEWTON')
# (1, 1, 1, 201, 45, 'ATTRACTION NEWTON')
# (1, 1, 1, 202, 45, 'ATTRACTION NEWTON')
# (1, 1, 1, 203, 45, 'ATTRACTION NEWTON')
# (1, 1, 1, 204, 45, 'ATTRACTION NEWTON')
# (2, 2, 2, 207, 46, 'AUTUMN CROW')
# (2, 2, 2, 208, 46, 'AUTUMN CROW')
# (2, 2, 2, 209, 46, 'AUTUMN CROW')
# (2, 2, 2, 210, 47, 'BABY HALL')
# (2, 2, 2, 211, 47, 'BABY HALL')
# (2, 2, 2, 214, 48, 'BACKLASH UNDEFEATED')
# (2, 2, 2, 215, 48, 'BACKLASH UNDEFEATED')
# (1, 1, 1, 212, 48, 'BACKLASH UNDEFEATED')
# (1, 1, 1, 213, 48, 'BACKLASH UNDEFEATED')
# (1, 1, 1, 216, 49, 'BADMAN DAWN')
# (1, 1, 1, 217, 49, 'BADMAN DAWN')
# (1, 1, 1, 218, 49, 'BADMAN DAWN')
# (2, 2, 2, 219, 49, 'BADMAN DAWN')
# (2, 2, 2, 220, 49, 'BADMAN DAWN')
# (2, 2, 2, 221, 49, 'BADMAN DAWN')
# (2, 2, 2, 225, 50, 'BAKED CLEOPATRA')
# (2, 2, 2, 226, 50, 'BAKED CLEOPATRA')
# (1, 1, 1, 222, 50, 'BAKED CLEOPATRA')
# (1, 1, 1, 223, 50, 'BAKED CLEOPATRA')
# (1, 1, 1, 224, 50, 'BAKED CLEOPATRA')
# (1, 1, 1, 227, 51, 'BALLOON HOMEWARD')
# (1, 1, 1, 228, 51, 'BALLOON HOMEWARD')
# (2, 2, 2, 229, 51, 'BALLOON HOMEWARD')
# (2, 2, 2, 230, 51, 'BALLOON HOMEWARD')
# (2, 2, 2, 231, 51, 'BALLOON HOMEWARD')
# (2, 2, 2, 232, 51, 'BALLOON HOMEWARD')
# (2, 2, 2, 233, 52, 'BALLROOM MOCKINGBIRD')
# (2, 2, 2, 234, 52, 'BALLROOM MOCKINGBIRD')
# (1, 1, 1, 235, 53, 'BANG KWAI')
# (1, 1, 1, 236, 53, 'BANG KWAI')
# (1, 1, 1, 237, 54, 'BANGER PINOCCHIO')
# (1, 1, 1, 238, 54, 'BANGER PINOCCHIO')
# (1, 1, 1, 239, 54, 'BANGER PINOCCHIO')
# (2, 2, 2, 240, 54, 'BANGER PINOCCHIO')
# (2, 2, 2, 241, 54, 'BANGER PINOCCHIO')
# (2, 2, 2, 246, 55, 'BARBARELLA STREETCAR')
# (2, 2, 2, 247, 55, 'BARBARELLA STREETCAR')
# (1, 1, 1, 242, 55, 'BARBARELLA STREETCAR')
# (1, 1, 1, 243, 55, 'BARBARELLA STREETCAR')
# (1, 1, 1, 244, 55, 'BARBARELLA STREETCAR')
# (1, 1, 1, 245, 55, 'BARBARELLA STREETCAR')
# (1, 1, 1, 248, 56, 'BAREFOOT MANCHURIAN')
# (1, 1, 1, 249, 56, 'BAREFOOT MANCHURIAN')
# (1, 1, 1, 250, 56, 'BAREFOOT MANCHURIAN')
# (2, 2, 2, 251, 56, 'BAREFOOT MANCHURIAN')
# (2, 2, 2, 252, 56, 'BAREFOOT MANCHURIAN')
# (2, 2, 2, 257, 57, 'BASIC EASY')
# (2, 2, 2, 258, 57, 'BASIC EASY')
# (2, 2, 2, 259, 57, 'BASIC EASY')
# (1, 1, 1, 253, 57, 'BASIC EASY')
# (1, 1, 1, 254, 57, 'BASIC EASY')
# (1, 1, 1, 255, 57, 'BASIC EASY')
# (1, 1, 1, 256, 57, 'BASIC EASY')
# (2, 2, 2, 260, 58, 'BEACH HEARTBREAKERS')
# (2, 2, 2, 261, 58, 'BEACH HEARTBREAKERS')
# (2, 2, 2, 262, 58, 'BEACH HEARTBREAKERS')
# (2, 2, 2, 263, 58, 'BEACH HEARTBREAKERS')
# (2, 2, 2, 267, 59, 'BEAR GRACELAND')
# (2, 2, 2, 268, 59, 'BEAR GRACELAND')
# (1, 1, 1, 264, 59, 'BEAR GRACELAND')
# (1, 1, 1, 265, 59, 'BEAR GRACELAND')
# (1, 1, 1, 266, 59, 'BEAR GRACELAND')
# (1, 1, 1, 269, 60, 'BEAST HUNCHBACK')
# (1, 1, 1, 270, 60, 'BEAST HUNCHBACK')
# (1, 1, 1, 271, 60, 'BEAST HUNCHBACK')
# (1, 1, 1, 272, 61, 'BEAUTY GREASE')
# (1, 1, 1, 273, 61, 'BEAUTY GREASE')
# (1, 1, 1, 274, 61, 'BEAUTY GREASE')
# (1, 1, 1, 275, 61, 'BEAUTY GREASE')
# (2, 2, 2, 276, 61, 'BEAUTY GREASE')
# (2, 2, 2, 277, 61, 'BEAUTY GREASE')
# (2, 2, 2, 278, 62, 'BED HIGHBALL')
# (2, 2, 2, 279, 62, 'BED HIGHBALL')
# (2, 2, 2, 282, 63, 'BEDAZZLED MARRIED')
# (2, 2, 2, 283, 63, 'BEDAZZLED MARRIED')
# (1, 1, 1, 280, 63, 'BEDAZZLED MARRIED')
# (1, 1, 1, 281, 63, 'BEDAZZLED MARRIED')
# (2, 2, 2, 284, 64, 'BEETHOVEN EXORCIST')
# (2, 2, 2, 285, 64, 'BEETHOVEN EXORCIST')
# (2, 2, 2, 286, 64, 'BEETHOVEN EXORCIST')
# (2, 2, 2, 287, 65, 'BEHAVIOR RUNAWAY')
# (2, 2, 2, 288, 65, 'BEHAVIOR RUNAWAY')
# (2, 2, 2, 289, 65, 'BEHAVIOR RUNAWAY')
# (2, 2, 2, 290, 65, 'BEHAVIOR RUNAWAY')
# (1, 1, 1, 291, 66, 'BENEATH RUSH')
# (1, 1, 1, 292, 66, 'BENEATH RUSH')
# (1, 1, 1, 293, 66, 'BENEATH RUSH')
# (1, 1, 1, 294, 67, 'BERETS AGENT')
# (1, 1, 1, 295, 67, 'BERETS AGENT')
# (2, 2, 2, 296, 67, 'BERETS AGENT')
# (2, 2, 2, 297, 67, 'BERETS AGENT')
# (2, 2, 2, 298, 67, 'BERETS AGENT')
# (2, 2, 2, 299, 67, 'BERETS AGENT')
# (2, 2, 2, 302, 68, 'BETRAYED REAR')
# (2, 2, 2, 303, 68, 'BETRAYED REAR')
# (1, 1, 1, 300, 68, 'BETRAYED REAR')
# (1, 1, 1, 301, 68, 'BETRAYED REAR')
# (1, 1, 1, 304, 69, 'BEVERLY OUTLAW')
# (1, 1, 1, 305, 69, 'BEVERLY OUTLAW')
# (1, 1, 1, 306, 69, 'BEVERLY OUTLAW')
# (1, 1, 1, 307, 69, 'BEVERLY OUTLAW')
# (2, 2, 2, 308, 69, 'BEVERLY OUTLAW')
# (2, 2, 2, 309, 69, 'BEVERLY OUTLAW')
# (2, 2, 2, 310, 69, 'BEVERLY OUTLAW')
# (2, 2, 2, 311, 69, 'BEVERLY OUTLAW')
# (2, 2, 2, 314, 70, 'BIKINI BORROWERS')
# (2, 2, 2, 315, 70, 'BIKINI BORROWERS')
# (1, 1, 1, 312, 70, 'BIKINI BORROWERS')
# (1, 1, 1, 313, 70, 'BIKINI BORROWERS')
# (2, 2, 2, 316, 71, 'BILKO ANONYMOUS')
# (2, 2, 2, 317, 71, 'BILKO ANONYMOUS')
# (2, 2, 2, 318, 71, 'BILKO ANONYMOUS')
# (2, 2, 2, 319, 71, 'BILKO ANONYMOUS')
# (2, 2, 2, 324, 72, 'BILL OTHERS')
# (2, 2, 2, 325, 72, 'BILL OTHERS')
# (1, 1, 1, 320, 72, 'BILL OTHERS')
# (1, 1, 1, 321, 72, 'BILL OTHERS')
# (1, 1, 1, 322, 72, 'BILL OTHERS')
# (1, 1, 1, 323, 72, 'BILL OTHERS')
# (1, 1, 1, 326, 73, 'BINGO TALENTED')
# (1, 1, 1, 327, 73, 'BINGO TALENTED')
# (1, 1, 1, 328, 73, 'BINGO TALENTED')
# (1, 1, 1, 329, 73, 'BINGO TALENTED')
# (2, 2, 2, 330, 73, 'BINGO TALENTED')
# (2, 2, 2, 331, 73, 'BINGO TALENTED')
# (2, 2, 2, 332, 73, 'BINGO TALENTED')
# (2, 2, 2, 333, 73, 'BINGO TALENTED')
# (2, 2, 2, 337, 74, 'BIRCH ANTITRUST')
# (2, 2, 2, 338, 74, 'BIRCH ANTITRUST')
# (1, 1, 1, 334, 74, 'BIRCH ANTITRUST')
# (1, 1, 1, 335, 74, 'BIRCH ANTITRUST')
# (1, 1, 1, 336, 74, 'BIRCH ANTITRUST')
# (2, 2, 2, 339, 75, 'BIRD INDEPENDENCE')
# (2, 2, 2, 340, 75, 'BIRD INDEPENDENCE')
# (2, 2, 2, 341, 75, 'BIRD INDEPENDENCE')
# (1, 1, 1, 342, 76, 'BIRDCAGE CASPER')
# (1, 1, 1, 343, 76, 'BIRDCAGE CASPER')
# (1, 1, 1, 344, 76, 'BIRDCAGE CASPER')
# (1, 1, 1, 345, 77, 'BIRDS PERDITION')
# (1, 1, 1, 346, 77, 'BIRDS PERDITION')
# (1, 1, 1, 347, 77, 'BIRDS PERDITION')
# (1, 1, 1, 348, 77, 'BIRDS PERDITION')
# (2, 2, 2, 349, 77, 'BIRDS PERDITION')
# (2, 2, 2, 350, 77, 'BIRDS PERDITION')
# (2, 2, 2, 354, 78, 'BLACKOUT PRIVATE')
# (2, 2, 2, 355, 78, 'BLACKOUT PRIVATE')
# (2, 2, 2, 356, 78, 'BLACKOUT PRIVATE')
# (2, 2, 2, 357, 78, 'BLACKOUT PRIVATE')
# (1, 1, 1, 351, 78, 'BLACKOUT PRIVATE')
# (1, 1, 1, 352, 78, 'BLACKOUT PRIVATE')
# (1, 1, 1, 353, 78, 'BLACKOUT PRIVATE')
# (1, 1, 1, 358, 79, 'BLADE POLISH')
# (1, 1, 1, 359, 79, 'BLADE POLISH')
# (1, 1, 1, 360, 79, 'BLADE POLISH')
# (2, 2, 2, 361, 79, 'BLADE POLISH')
# (2, 2, 2, 362, 79, 'BLADE POLISH')
# (2, 2, 2, 363, 79, 'BLADE POLISH')
# (1, 1, 1, 364, 80, 'BLANKET BEVERLY')
# (1, 1, 1, 365, 80, 'BLANKET BEVERLY')
# (1, 1, 1, 366, 80, 'BLANKET BEVERLY')
# (1, 1, 1, 367, 80, 'BLANKET BEVERLY')
# (1, 1, 1, 368, 81, 'BLINDNESS GUN')
# (1, 1, 1, 369, 81, 'BLINDNESS GUN')
# (1, 1, 1, 370, 81, 'BLINDNESS GUN')
# (1, 1, 1, 371, 81, 'BLINDNESS GUN')
# (1, 1, 1, 372, 82, 'BLOOD ARGONAUTS')
# (1, 1, 1, 373, 82, 'BLOOD ARGONAUTS')
# (1, 1, 1, 374, 83, 'BLUES INSTINCT')
# (1, 1, 1, 375, 83, 'BLUES INSTINCT')
# (1, 1, 1, 376, 83, 'BLUES INSTINCT')
# (2, 2, 2, 377, 83, 'BLUES INSTINCT')
# (2, 2, 2, 378, 83, 'BLUES INSTINCT')
# (1, 1, 1, 379, 84, 'BOILED DARES')
# (1, 1, 1, 380, 84, 'BOILED DARES')
# (1, 1, 1, 381, 84, 'BOILED DARES')
# (1, 1, 1, 382, 84, 'BOILED DARES')
# (2, 2, 2, 383, 85, 'BONNIE HOLOCAUST')
# (2, 2, 2, 384, 85, 'BONNIE HOLOCAUST')
# (2, 2, 2, 385, 85, 'BONNIE HOLOCAUST')
# (2, 2, 2, 386, 85, 'BONNIE HOLOCAUST')
# (2, 2, 2, 391, 86, 'BOOGIE AMELIE')
# (2, 2, 2, 392, 86, 'BOOGIE AMELIE')
# (2, 2, 2, 393, 86, 'BOOGIE AMELIE')
# (2, 2, 2, 394, 86, 'BOOGIE AMELIE')
# (1, 1, 1, 387, 86, 'BOOGIE AMELIE')
# (1, 1, 1, 388, 86, 'BOOGIE AMELIE')
# (1, 1, 1, 389, 86, 'BOOGIE AMELIE')
# (1, 1, 1, 390, 86, 'BOOGIE AMELIE')
# (2, 2, 2, 395, 88, 'BORN SPINAL')
# (2, 2, 2, 396, 88, 'BORN SPINAL')
# (2, 2, 2, 397, 88, 'BORN SPINAL')
# (2, 2, 2, 398, 88, 'BORN SPINAL')
# (2, 2, 2, 402, 89, 'BORROWERS BEDAZZLED')
# (2, 2, 2, 403, 89, 'BORROWERS BEDAZZLED')
# (2, 2, 2, 404, 89, 'BORROWERS BEDAZZLED')
# (1, 1, 1, 399, 89, 'BORROWERS BEDAZZLED')
# (1, 1, 1, 400, 89, 'BORROWERS BEDAZZLED')
# (1, 1, 1, 401, 89, 'BORROWERS BEDAZZLED')
# (1, 1, 1, 405, 90, 'BOULEVARD MOB')
# (1, 1, 1, 406, 90, 'BOULEVARD MOB')
# (1, 1, 1, 407, 90, 'BOULEVARD MOB')
# (2, 2, 2, 408, 90, 'BOULEVARD MOB')
# (2, 2, 2, 409, 90, 'BOULEVARD MOB')
# (2, 2, 2, 410, 90, 'BOULEVARD MOB')
# (2, 2, 2, 415, 91, 'BOUND CHEAPER')
# (2, 2, 2, 416, 91, 'BOUND CHEAPER')
# (2, 2, 2, 417, 91, 'BOUND CHEAPER')
# (2, 2, 2, 418, 91, 'BOUND CHEAPER')
# (1, 1, 1, 411, 91, 'BOUND CHEAPER')
# (1, 1, 1, 412, 91, 'BOUND CHEAPER')
# (1, 1, 1, 413, 91, 'BOUND CHEAPER')
# (1, 1, 1, 414, 91, 'BOUND CHEAPER')
# (1, 1, 1, 419, 92, 'BOWFINGER GABLES')
# (1, 1, 1, 420, 92, 'BOWFINGER GABLES')
# (2, 2, 2, 421, 92, 'BOWFINGER GABLES')
# (2, 2, 2, 422, 92, 'BOWFINGER GABLES')
# (2, 2, 2, 423, 93, 'BRANNIGAN SUNRISE')
# (2, 2, 2, 424, 93, 'BRANNIGAN SUNRISE')
# (2, 2, 2, 425, 93, 'BRANNIGAN SUNRISE')
# (1, 1, 1, 426, 94, 'BRAVEHEART HUMAN')
# (1, 1, 1, 427, 94, 'BRAVEHEART HUMAN')
# (1, 1, 1, 428, 95, 'BREAKFAST GOLDFINGER')
# (1, 1, 1, 429, 95, 'BREAKFAST GOLDFINGER')
# (2, 2, 2, 430, 95, 'BREAKFAST GOLDFINGER')
# (2, 2, 2, 431, 95, 'BREAKFAST GOLDFINGER')
# (2, 2, 2, 432, 95, 'BREAKFAST GOLDFINGER')
# (1, 1, 1, 433, 96, 'BREAKING HOME')
# (1, 1, 1, 434, 96, 'BREAKING HOME')
# (1, 1, 1, 435, 96, 'BREAKING HOME')
# (1, 1, 1, 436, 97, 'BRIDE INTRIGUE')
# (1, 1, 1, 437, 97, 'BRIDE INTRIGUE')
# (1, 1, 1, 438, 97, 'BRIDE INTRIGUE')
# (1, 1, 1, 439, 97, 'BRIDE INTRIGUE')
# (2, 2, 2, 440, 97, 'BRIDE INTRIGUE')
# (2, 2, 2, 441, 97, 'BRIDE INTRIGUE')
# (1, 1, 1, 442, 98, 'BRIGHT ENCOUNTERS')
# (1, 1, 1, 443, 98, 'BRIGHT ENCOUNTERS')
# (1, 1, 1, 444, 98, 'BRIGHT ENCOUNTERS')
# (1, 1, 1, 445, 99, 'BRINGING HYSTERICAL')
# (1, 1, 1, 446, 99, 'BRINGING HYSTERICAL')
# (1, 1, 1, 447, 99, 'BRINGING HYSTERICAL')
# (2, 2, 2, 448, 99, 'BRINGING HYSTERICAL')
# (2, 2, 2, 449, 99, 'BRINGING HYSTERICAL')
# (2, 2, 2, 450, 99, 'BRINGING HYSTERICAL')
# (2, 2, 2, 455, 100, 'BROOKLYN DESERT')
# (2, 2, 2, 456, 100, 'BROOKLYN DESERT')
# (1, 1, 1, 451, 100, 'BROOKLYN DESERT')
# (1, 1, 1, 452, 100, 'BROOKLYN DESERT')
# (1, 1, 1, 453, 100, 'BROOKLYN DESERT')
# (1, 1, 1, 454, 100, 'BROOKLYN DESERT')
# (1, 1, 1, 457, 101, 'BROTHERHOOD BLANKET')
# (1, 1, 1, 458, 101, 'BROTHERHOOD BLANKET')
# (1, 1, 1, 459, 101, 'BROTHERHOOD BLANKET')
# (1, 1, 1, 460, 101, 'BROTHERHOOD BLANKET')
# (2, 2, 2, 461, 101, 'BROTHERHOOD BLANKET')
# (2, 2, 2, 462, 101, 'BROTHERHOOD BLANKET')
# (2, 2, 2, 463, 102, 'BUBBLE GROSSE')
# (2, 2, 2, 464, 102, 'BUBBLE GROSSE')
# (2, 2, 2, 469, 103, 'BUCKET BROTHERHOOD')
# (2, 2, 2, 470, 103, 'BUCKET BROTHERHOOD')
# (2, 2, 2, 471, 103, 'BUCKET BROTHERHOOD')
# (2, 2, 2, 472, 103, 'BUCKET BROTHERHOOD')
# (1, 1, 1, 465, 103, 'BUCKET BROTHERHOOD')
# (1, 1, 1, 466, 103, 'BUCKET BROTHERHOOD')
# (1, 1, 1, 467, 103, 'BUCKET BROTHERHOOD')
# (1, 1, 1, 468, 103, 'BUCKET BROTHERHOOD')
# (2, 2, 2, 473, 104, 'BUGSY SONG')
# (2, 2, 2, 474, 104, 'BUGSY SONG')
# (2, 2, 2, 475, 104, 'BUGSY SONG')
# (2, 2, 2, 478, 105, 'BULL SHAWSHANK')
# (2, 2, 2, 479, 105, 'BULL SHAWSHANK')
# (2, 2, 2, 480, 105, 'BULL SHAWSHANK')
# (1, 1, 1, 476, 105, 'BULL SHAWSHANK')
# (1, 1, 1, 477, 105, 'BULL SHAWSHANK')
# (1, 1, 1, 481, 106, 'BULWORTH COMMANDMENTS')
# (1, 1, 1, 482, 106, 'BULWORTH COMMANDMENTS')
# (2, 2, 2, 483, 107, 'BUNCH MINDS')
# (2, 2, 2, 484, 107, 'BUNCH MINDS')
# (2, 2, 2, 489, 109, 'BUTTERFLY CHOCOLAT')
# (2, 2, 2, 490, 109, 'BUTTERFLY CHOCOLAT')
# (2, 2, 2, 491, 109, 'BUTTERFLY CHOCOLAT')
# (2, 2, 2, 492, 109, 'BUTTERFLY CHOCOLAT')
# (1, 1, 1, 485, 109, 'BUTTERFLY CHOCOLAT')
# (1, 1, 1, 486, 109, 'BUTTERFLY CHOCOLAT')
# (1, 1, 1, 487, 109, 'BUTTERFLY CHOCOLAT')
# (1, 1, 1, 488, 109, 'BUTTERFLY CHOCOLAT')
# (1, 1, 1, 493, 110, 'CABIN FLASH')
# (1, 1, 1, 494, 110, 'CABIN FLASH')
# (1, 1, 1, 495, 110, 'CABIN FLASH')
# (1, 1, 1, 496, 110, 'CABIN FLASH')
# (2, 2, 2, 497, 111, 'CADDYSHACK JEDI')
# (2, 2, 2, 498, 111, 'CADDYSHACK JEDI')
# (2, 2, 2, 499, 111, 'CADDYSHACK JEDI')
# (2, 2, 2, 500, 111, 'CADDYSHACK JEDI')
# (2, 2, 2, 505, 112, 'CALENDAR GUNFIGHT')
# (2, 2, 2, 506, 112, 'CALENDAR GUNFIGHT')
# (2, 2, 2, 507, 112, 'CALENDAR GUNFIGHT')
# (1, 1, 1, 501, 112, 'CALENDAR GUNFIGHT')
# (1, 1, 1, 502, 112, 'CALENDAR GUNFIGHT')
# (1, 1, 1, 503, 112, 'CALENDAR GUNFIGHT')
# (1, 1, 1, 504, 112, 'CALENDAR GUNFIGHT')
# (2, 2, 2, 508, 113, 'CALIFORNIA BIRDS')
# (2, 2, 2, 509, 113, 'CALIFORNIA BIRDS')
# (2, 2, 2, 510, 113, 'CALIFORNIA BIRDS')
# (2, 2, 2, 511, 113, 'CALIFORNIA BIRDS')
# (2, 2, 2, 516, 114, 'CAMELOT VACATION')
# (2, 2, 2, 517, 114, 'CAMELOT VACATION')
# (2, 2, 2, 518, 114, 'CAMELOT VACATION')
# (1, 1, 1, 512, 114, 'CAMELOT VACATION')
# (1, 1, 1, 513, 114, 'CAMELOT VACATION')
# (1, 1, 1, 514, 114, 'CAMELOT VACATION')
# (1, 1, 1, 515, 114, 'CAMELOT VACATION')
# (1, 1, 1, 519, 115, 'CAMPUS REMEMBER')
# (1, 1, 1, 520, 115, 'CAMPUS REMEMBER')
# (1, 1, 1, 521, 115, 'CAMPUS REMEMBER')
# (2, 2, 2, 522, 115, 'CAMPUS REMEMBER')
# (2, 2, 2, 523, 115, 'CAMPUS REMEMBER')
# (2, 2, 2, 524, 115, 'CAMPUS REMEMBER')
# (2, 2, 2, 525, 115, 'CAMPUS REMEMBER')
# (2, 2, 2, 528, 116, 'CANDIDATE PERDITION')
# (2, 2, 2, 529, 116, 'CANDIDATE PERDITION')
# (2, 2, 2, 530, 116, 'CANDIDATE PERDITION')
# (2, 2, 2, 531, 116, 'CANDIDATE PERDITION')
# (1, 1, 1, 526, 116, 'CANDIDATE PERDITION')
# (1, 1, 1, 527, 116, 'CANDIDATE PERDITION')
# (1, 1, 1, 532, 117, 'CANDLES GRAPES')
# (1, 1, 1, 533, 117, 'CANDLES GRAPES')
# (1, 1, 1, 534, 117, 'CANDLES GRAPES')
# (1, 1, 1, 535, 117, 'CANDLES GRAPES')
# (2, 2, 2, 536, 117, 'CANDLES GRAPES')
# (2, 2, 2, 537, 117, 'CANDLES GRAPES')
# (2, 2, 2, 542, 118, 'CANYON STOCK')
# (2, 2, 2, 543, 118, 'CANYON STOCK')
# (1, 1, 1, 538, 118, 'CANYON STOCK')
# (1, 1, 1, 539, 118, 'CANYON STOCK')
# (1, 1, 1, 540, 118, 'CANYON STOCK')
# (1, 1, 1, 541, 118, 'CANYON STOCK')
# (1, 1, 1, 544, 119, 'CAPER MOTIONS')
# (1, 1, 1, 545, 119, 'CAPER MOTIONS')
# (1, 1, 1, 546, 119, 'CAPER MOTIONS')
# (2, 2, 2, 547, 119, 'CAPER MOTIONS')
# (2, 2, 2, 548, 119, 'CAPER MOTIONS')
# (2, 2, 2, 549, 119, 'CAPER MOTIONS')
# (2, 2, 2, 550, 119, 'CAPER MOTIONS')
# (1, 1, 1, 551, 120, 'CARIBBEAN LIBERTY')
# (1, 1, 1, 552, 120, 'CARIBBEAN LIBERTY')
# (1, 1, 1, 553, 120, 'CARIBBEAN LIBERTY')
# (1, 1, 1, 554, 121, 'CAROL TEXAS')
# (1, 1, 1, 555, 121, 'CAROL TEXAS')
# (1, 1, 1, 556, 121, 'CAROL TEXAS')
# (2, 2, 2, 557, 121, 'CAROL TEXAS')
# (2, 2, 2, 558, 121, 'CAROL TEXAS')
# (2, 2, 2, 559, 121, 'CAROL TEXAS')
# (2, 2, 2, 564, 122, 'CARRIE BUNCH')
# (2, 2, 2, 565, 122, 'CARRIE BUNCH')
# (2, 2, 2, 566, 122, 'CARRIE BUNCH')
# (1, 1, 1, 560, 122, 'CARRIE BUNCH')
# (1, 1, 1, 561, 122, 'CARRIE BUNCH')
# (1, 1, 1, 562, 122, 'CARRIE BUNCH')
# (1, 1, 1, 563, 122, 'CARRIE BUNCH')
# (1, 1, 1, 567, 123, 'CASABLANCA SUPER')
# (1, 1, 1, 568, 123, 'CASABLANCA SUPER')
# (2, 2, 2, 569, 123, 'CASABLANCA SUPER')
# (2, 2, 2, 570, 123, 'CASABLANCA SUPER')
# (2, 2, 2, 571, 123, 'CASABLANCA SUPER')
# (2, 2, 2, 572, 124, 'CASPER DRAGONFLY')
# (2, 2, 2, 573, 124, 'CASPER DRAGONFLY')
# (2, 2, 2, 574, 124, 'CASPER DRAGONFLY')
# (2, 2, 2, 575, 125, 'CASSIDY WYOMING')
# (2, 2, 2, 576, 125, 'CASSIDY WYOMING')
# (2, 2, 2, 577, 126, 'CASUALTIES ENCINO')
# (2, 2, 2, 578, 126, 'CASUALTIES ENCINO')
# (2, 2, 2, 579, 126, 'CASUALTIES ENCINO')
# (2, 2, 2, 584, 127, 'CAT CONEHEADS')
# (2, 2, 2, 585, 127, 'CAT CONEHEADS')
# (2, 2, 2, 586, 127, 'CAT CONEHEADS')
# (2, 2, 2, 587, 127, 'CAT CONEHEADS')
# (1, 1, 1, 580, 127, 'CAT CONEHEADS')
# (1, 1, 1, 581, 127, 'CAT CONEHEADS')
# (1, 1, 1, 582, 127, 'CAT CONEHEADS')
# (1, 1, 1, 583, 127, 'CAT CONEHEADS')
# (1, 1, 1, 588, 129, 'CAUSE DATE')
# (1, 1, 1, 589, 129, 'CAUSE DATE')
# (1, 1, 1, 590, 129, 'CAUSE DATE')
# (2, 2, 2, 591, 129, 'CAUSE DATE')
# (2, 2, 2, 592, 129, 'CAUSE DATE')
# (2, 2, 2, 593, 129, 'CAUSE DATE')
# (2, 2, 2, 596, 130, 'CELEBRITY HORN')
# (2, 2, 2, 597, 130, 'CELEBRITY HORN')
# (2, 2, 2, 598, 130, 'CELEBRITY HORN')
# (2, 2, 2, 599, 130, 'CELEBRITY HORN')
# (1, 1, 1, 594, 130, 'CELEBRITY HORN')
# (1, 1, 1, 595, 130, 'CELEBRITY HORN')
# (1, 1, 1, 600, 131, 'CENTER DINOSAUR')
# (1, 1, 1, 601, 131, 'CENTER DINOSAUR')
# (1, 1, 1, 602, 131, 'CENTER DINOSAUR')
# (1, 1, 1, 603, 131, 'CENTER DINOSAUR')
# (2, 2, 2, 604, 131, 'CENTER DINOSAUR')
# (2, 2, 2, 605, 131, 'CENTER DINOSAUR')
# (2, 2, 2, 610, 132, 'CHAINSAW UPTOWN')
# (2, 2, 2, 611, 132, 'CHAINSAW UPTOWN')
# (1, 1, 1, 606, 132, 'CHAINSAW UPTOWN')
# (1, 1, 1, 607, 132, 'CHAINSAW UPTOWN')
# (1, 1, 1, 608, 132, 'CHAINSAW UPTOWN')
# (1, 1, 1, 609, 132, 'CHAINSAW UPTOWN')
# (1, 1, 1, 612, 133, 'CHAMBER ITALIAN')
# (1, 1, 1, 613, 133, 'CHAMBER ITALIAN')
# (2, 2, 2, 614, 133, 'CHAMBER ITALIAN')
# (2, 2, 2, 615, 133, 'CHAMBER ITALIAN')
# (2, 2, 2, 616, 134, 'CHAMPION FLATLINERS')
# (2, 2, 2, 617, 134, 'CHAMPION FLATLINERS')
# (2, 2, 2, 618, 134, 'CHAMPION FLATLINERS')
# (2, 2, 2, 622, 135, 'CHANCE RESURRECTION')
# (2, 2, 2, 623, 135, 'CHANCE RESURRECTION')
# (2, 2, 2, 624, 135, 'CHANCE RESURRECTION')
# (2, 2, 2, 625, 135, 'CHANCE RESURRECTION')
# (1, 1, 1, 619, 135, 'CHANCE RESURRECTION')
# (1, 1, 1, 620, 135, 'CHANCE RESURRECTION')
# (1, 1, 1, 621, 135, 'CHANCE RESURRECTION')
# (1, 1, 1, 626, 136, 'CHAPLIN LICENSE')
# (1, 1, 1, 627, 136, 'CHAPLIN LICENSE')
# (1, 1, 1, 628, 136, 'CHAPLIN LICENSE')
# (2, 2, 2, 629, 137, 'CHARADE DUFFEL')
# (2, 2, 2, 630, 137, 'CHARADE DUFFEL')
# (2, 2, 2, 631, 137, 'CHARADE DUFFEL')
# (2, 2, 2, 632, 137, 'CHARADE DUFFEL')
# (2, 2, 2, 635, 138, 'CHARIOTS CONSPIRACY')
# (2, 2, 2, 636, 138, 'CHARIOTS CONSPIRACY')
# (2, 2, 2, 637, 138, 'CHARIOTS CONSPIRACY')
# (1, 1, 1, 633, 138, 'CHARIOTS CONSPIRACY')
# (1, 1, 1, 634, 138, 'CHARIOTS CONSPIRACY')
# (1, 1, 1, 638, 139, 'CHASING FIGHT')
# (1, 1, 1, 639, 139, 'CHASING FIGHT')
# (1, 1, 1, 640, 139, 'CHASING FIGHT')
# (1, 1, 1, 641, 139, 'CHASING FIGHT')
# (2, 2, 2, 642, 139, 'CHASING FIGHT')
# (2, 2, 2, 643, 139, 'CHASING FIGHT')
# (2, 2, 2, 646, 140, 'CHEAPER CLYDE')
# (2, 2, 2, 647, 140, 'CHEAPER CLYDE')
# (2, 2, 2, 648, 140, 'CHEAPER CLYDE')
# (1, 1, 1, 644, 140, 'CHEAPER CLYDE')
# (1, 1, 1, 645, 140, 'CHEAPER CLYDE')
# (1, 1, 1, 649, 141, 'CHICAGO NORTH')
# (1, 1, 1, 650, 141, 'CHICAGO NORTH')
# (1, 1, 1, 651, 141, 'CHICAGO NORTH')
# (2, 2, 2, 652, 141, 'CHICAGO NORTH')
# (2, 2, 2, 653, 141, 'CHICAGO NORTH')
# (2, 2, 2, 657, 142, 'CHICKEN HELLFIGHTERS')
# (2, 2, 2, 658, 142, 'CHICKEN HELLFIGHTERS')
# (1, 1, 1, 654, 142, 'CHICKEN HELLFIGHTERS')
# (1, 1, 1, 655, 142, 'CHICKEN HELLFIGHTERS')
# (1, 1, 1, 656, 142, 'CHICKEN HELLFIGHTERS')
# (1, 1, 1, 659, 143, 'CHILL LUCK')
# (1, 1, 1, 660, 143, 'CHILL LUCK')
# (1, 1, 1, 661, 143, 'CHILL LUCK')
# (1, 1, 1, 662, 143, 'CHILL LUCK')
# (2, 2, 2, 663, 143, 'CHILL LUCK')
# (2, 2, 2, 664, 143, 'CHILL LUCK')
# (2, 2, 2, 665, 143, 'CHILL LUCK')
# (2, 2, 2, 666, 145, 'CHISUM BEHAVIOR')
# (2, 2, 2, 667, 145, 'CHISUM BEHAVIOR')
# (2, 2, 2, 668, 145, 'CHISUM BEHAVIOR')
# (1, 1, 1, 669, 146, 'CHITTY LOCK')
# (1, 1, 1, 670, 146, 'CHITTY LOCK')
# (1, 1, 1, 671, 146, 'CHITTY LOCK')
# (1, 1, 1, 672, 147, 'CHOCOLAT HARRY')
# (1, 1, 1, 673, 147, 'CHOCOLAT HARRY')
# (1, 1, 1, 674, 147, 'CHOCOLAT HARRY')
# (2, 2, 2, 675, 147, 'CHOCOLAT HARRY')
# (2, 2, 2, 676, 147, 'CHOCOLAT HARRY')
# (2, 2, 2, 677, 147, 'CHOCOLAT HARRY')
# (2, 2, 2, 681, 149, 'CHRISTMAS MOONSHINE')
# (2, 2, 2, 682, 149, 'CHRISTMAS MOONSHINE')
# (2, 2, 2, 683, 149, 'CHRISTMAS MOONSHINE')
# (1, 1, 1, 678, 149, 'CHRISTMAS MOONSHINE')
# (1, 1, 1, 679, 149, 'CHRISTMAS MOONSHINE')
# (1, 1, 1, 680, 149, 'CHRISTMAS MOONSHINE')
# (1, 1, 1, 684, 150, 'CIDER DESIRE')
# (1, 1, 1, 685, 150, 'CIDER DESIRE')
# (2, 2, 2, 686, 150, 'CIDER DESIRE')
# (2, 2, 2, 687, 150, 'CIDER DESIRE')
# (2, 2, 2, 688, 150, 'CIDER DESIRE')
# (2, 2, 2, 689, 150, 'CIDER DESIRE')
# (2, 2, 2, 692, 151, 'CINCINATTI WHISPERER')
# (2, 2, 2, 693, 151, 'CINCINATTI WHISPERER')
# (1, 1, 1, 690, 151, 'CINCINATTI WHISPERER')
# (1, 1, 1, 691, 151, 'CINCINATTI WHISPERER')
# (1, 1, 1, 694, 152, 'CIRCUS YOUTH')
# (1, 1, 1, 695, 152, 'CIRCUS YOUTH')
# (1, 1, 1, 696, 152, 'CIRCUS YOUTH')
# (1, 1, 1, 697, 152, 'CIRCUS YOUTH')
# (1, 1, 1, 698, 153, 'CITIZEN SHREK')
# (1, 1, 1, 699, 153, 'CITIZEN SHREK')
# (1, 1, 1, 700, 153, 'CITIZEN SHREK')
# (1, 1, 1, 701, 153, 'CITIZEN SHREK')
# (1, 1, 1, 702, 154, 'CLASH FREDDY')
# (1, 1, 1, 703, 154, 'CLASH FREDDY')
# (1, 1, 1, 704, 154, 'CLASH FREDDY')
# (2, 2, 2, 705, 154, 'CLASH FREDDY')
# (2, 2, 2, 706, 154, 'CLASH FREDDY')
# (2, 2, 2, 707, 154, 'CLASH FREDDY')
# (2, 2, 2, 708, 154, 'CLASH FREDDY')
# (2, 2, 2, 711, 155, 'CLEOPATRA DEVIL')
# (2, 2, 2, 712, 155, 'CLEOPATRA DEVIL')
# (2, 2, 2, 713, 155, 'CLEOPATRA DEVIL')
# (1, 1, 1, 709, 155, 'CLEOPATRA DEVIL')
# (1, 1, 1, 710, 155, 'CLEOPATRA DEVIL')
# (2, 2, 2, 714, 156, 'CLERKS ANGELS')
# (2, 2, 2, 715, 156, 'CLERKS ANGELS')
# (2, 2, 2, 716, 157, 'CLOCKWORK PARADISE')
# (2, 2, 2, 717, 157, 'CLOCKWORK PARADISE')
# (2, 2, 2, 718, 157, 'CLOCKWORK PARADISE')
# (2, 2, 2, 721, 158, 'CLONES PINOCCHIO')
# (2, 2, 2, 722, 158, 'CLONES PINOCCHIO')
# (2, 2, 2, 723, 158, 'CLONES PINOCCHIO')
# (1, 1, 1, 719, 158, 'CLONES PINOCCHIO')
# (1, 1, 1, 720, 158, 'CLONES PINOCCHIO')
# (1, 1, 1, 724, 159, 'CLOSER BANG')
# (1, 1, 1, 725, 159, 'CLOSER BANG')
# (1, 1, 1, 726, 159, 'CLOSER BANG')
# (1, 1, 1, 727, 159, 'CLOSER BANG')
# (2, 2, 2, 728, 159, 'CLOSER BANG')
# (2, 2, 2, 729, 159, 'CLOSER BANG')
# (2, 2, 2, 730, 159, 'CLOSER BANG')
# (2, 2, 2, 733, 160, 'CLUB GRAFFITI')
# (2, 2, 2, 734, 160, 'CLUB GRAFFITI')
# (2, 2, 2, 735, 160, 'CLUB GRAFFITI')
# (1, 1, 1, 731, 160, 'CLUB GRAFFITI')
# (1, 1, 1, 732, 160, 'CLUB GRAFFITI')
# (1, 1, 1, 736, 161, 'CLUE GRAIL')
# (1, 1, 1, 737, 161, 'CLUE GRAIL')
# (1, 1, 1, 738, 162, 'CLUELESS BUCKET')
# (1, 1, 1, 739, 162, 'CLUELESS BUCKET')
# (1, 1, 1, 740, 162, 'CLUELESS BUCKET')
# (2, 2, 2, 741, 162, 'CLUELESS BUCKET')
# (2, 2, 2, 742, 162, 'CLUELESS BUCKET')
# (2, 2, 2, 743, 162, 'CLUELESS BUCKET')
# (2, 2, 2, 744, 162, 'CLUELESS BUCKET')
# (2, 2, 2, 745, 163, 'CLYDE THEORY')
# (2, 2, 2, 746, 163, 'CLYDE THEORY')
# (2, 2, 2, 747, 163, 'CLYDE THEORY')
# (2, 2, 2, 750, 164, 'COAST RAINBOW')
# (2, 2, 2, 751, 164, 'COAST RAINBOW')
# (2, 2, 2, 752, 164, 'COAST RAINBOW')
# (1, 1, 1, 748, 164, 'COAST RAINBOW')
# (1, 1, 1, 749, 164, 'COAST RAINBOW')
# (1, 1, 1, 753, 165, 'COLDBLOODED DARLING')
# (1, 1, 1, 754, 165, 'COLDBLOODED DARLING')
# (1, 1, 1, 755, 165, 'COLDBLOODED DARLING')
# (2, 2, 2, 756, 165, 'COLDBLOODED DARLING')
# (2, 2, 2, 757, 165, 'COLDBLOODED DARLING')
# (2, 2, 2, 762, 166, 'COLOR PHILADELPHIA')
# (2, 2, 2, 763, 166, 'COLOR PHILADELPHIA')
# (1, 1, 1, 758, 166, 'COLOR PHILADELPHIA')
# (1, 1, 1, 759, 166, 'COLOR PHILADELPHIA')
# (1, 1, 1, 760, 166, 'COLOR PHILADELPHIA')
# (1, 1, 1, 761, 166, 'COLOR PHILADELPHIA')
# (1, 1, 1, 764, 167, 'COMA HEAD')
# (1, 1, 1, 765, 167, 'COMA HEAD')
# (1, 1, 1, 766, 167, 'COMA HEAD')
# (1, 1, 1, 767, 167, 'COMA HEAD')
# (2, 2, 2, 768, 167, 'COMA HEAD')
# (2, 2, 2, 769, 167, 'COMA HEAD')
# (2, 2, 2, 770, 167, 'COMA HEAD')
# (1, 1, 1, 771, 168, 'COMANCHEROS ENEMY')
# (1, 1, 1, 772, 168, 'COMANCHEROS ENEMY')
# (1, 1, 1, 773, 169, 'COMFORTS RUSH')
# (1, 1, 1, 774, 169, 'COMFORTS RUSH')
# (2, 2, 2, 775, 169, 'COMFORTS RUSH')
# (2, 2, 2, 776, 169, 'COMFORTS RUSH')
# (2, 2, 2, 779, 170, 'COMMAND DARLING')
# (2, 2, 2, 780, 170, 'COMMAND DARLING')
# (2, 2, 2, 781, 170, 'COMMAND DARLING')
# (2, 2, 2, 782, 170, 'COMMAND DARLING')
# (1, 1, 1, 777, 170, 'COMMAND DARLING')
# (1, 1, 1, 778, 170, 'COMMAND DARLING')
# (1, 1, 1, 783, 172, 'CONEHEADS SMOOCHY')
# (1, 1, 1, 784, 172, 'CONEHEADS SMOOCHY')
# (1, 1, 1, 785, 172, 'CONEHEADS SMOOCHY')
# (1, 1, 1, 786, 172, 'CONEHEADS SMOOCHY')
# (2, 2, 2, 787, 172, 'CONEHEADS SMOOCHY')
# (2, 2, 2, 788, 172, 'CONEHEADS SMOOCHY')
# (2, 2, 2, 789, 172, 'CONEHEADS SMOOCHY')
# (2, 2, 2, 793, 173, 'CONFESSIONS MAGUIRE')
# (2, 2, 2, 794, 173, 'CONFESSIONS MAGUIRE')
# (1, 1, 1, 790, 173, 'CONFESSIONS MAGUIRE')
# (1, 1, 1, 791, 173, 'CONFESSIONS MAGUIRE')
# (1, 1, 1, 792, 173, 'CONFESSIONS MAGUIRE')
# (1, 1, 1, 795, 174, 'CONFIDENTIAL INTERVIEW')
# (1, 1, 1, 796, 174, 'CONFIDENTIAL INTERVIEW')
# (1, 1, 1, 797, 174, 'CONFIDENTIAL INTERVIEW')
# (1, 1, 1, 798, 174, 'CONFIDENTIAL INTERVIEW')
# (2, 2, 2, 799, 174, 'CONFIDENTIAL INTERVIEW')
# (2, 2, 2, 800, 174, 'CONFIDENTIAL INTERVIEW')
# (2, 2, 2, 801, 174, 'CONFIDENTIAL INTERVIEW')
# (2, 2, 2, 802, 174, 'CONFIDENTIAL INTERVIEW')
# (2, 2, 2, 805, 175, 'CONFUSED CANDLES')
# (2, 2, 2, 806, 175, 'CONFUSED CANDLES')
# (2, 2, 2, 807, 175, 'CONFUSED CANDLES')
# (1, 1, 1, 803, 175, 'CONFUSED CANDLES')
# (1, 1, 1, 804, 175, 'CONFUSED CANDLES')
# (1, 1, 1, 808, 176, 'CONGENIALITY QUEST')
# (1, 1, 1, 809, 176, 'CONGENIALITY QUEST')
# (2, 2, 2, 810, 176, 'CONGENIALITY QUEST')
# (2, 2, 2, 811, 176, 'CONGENIALITY QUEST')
# (2, 2, 2, 812, 176, 'CONGENIALITY QUEST')
# (2, 2, 2, 813, 176, 'CONGENIALITY QUEST')
# (2, 2, 2, 814, 177, 'CONNECTICUT TRAMP')
# (2, 2, 2, 815, 177, 'CONNECTICUT TRAMP')
# (2, 2, 2, 816, 177, 'CONNECTICUT TRAMP')
# (1, 1, 1, 817, 178, 'CONNECTION MICROCOSMOS')
# (1, 1, 1, 818, 178, 'CONNECTION MICROCOSMOS')
# (1, 1, 1, 819, 179, 'CONQUERER NUTS')
# (1, 1, 1, 820, 179, 'CONQUERER NUTS')
# (1, 1, 1, 821, 179, 'CONQUERER NUTS')
# (1, 1, 1, 822, 179, 'CONQUERER NUTS')
# (2, 2, 2, 823, 180, 'CONSPIRACY SPIRIT')
# (2, 2, 2, 824, 180, 'CONSPIRACY SPIRIT')
# (2, 2, 2, 828, 181, 'CONTACT ANONYMOUS')
# (2, 2, 2, 829, 181, 'CONTACT ANONYMOUS')
# (2, 2, 2, 830, 181, 'CONTACT ANONYMOUS')
# (2, 2, 2, 831, 181, 'CONTACT ANONYMOUS')
# (1, 1, 1, 825, 181, 'CONTACT ANONYMOUS')
# (1, 1, 1, 826, 181, 'CONTACT ANONYMOUS')
# (1, 1, 1, 827, 181, 'CONTACT ANONYMOUS')
# (1, 1, 1, 832, 182, 'CONTROL ANTHEM')
# (1, 1, 1, 833, 182, 'CONTROL ANTHEM')
# (1, 1, 1, 834, 183, 'CONVERSATION DOWNHILL')
# (1, 1, 1, 835, 183, 'CONVERSATION DOWNHILL')
# (1, 1, 1, 836, 183, 'CONVERSATION DOWNHILL')
# (2, 2, 2, 837, 183, 'CONVERSATION DOWNHILL')
# (2, 2, 2, 838, 183, 'CONVERSATION DOWNHILL')
# (2, 2, 2, 839, 183, 'CONVERSATION DOWNHILL')
# (2, 2, 2, 842, 184, 'CORE SUIT')
# (2, 2, 2, 843, 184, 'CORE SUIT')
# (2, 2, 2, 844, 184, 'CORE SUIT')
# (1, 1, 1, 840, 184, 'CORE SUIT')
# (1, 1, 1, 841, 184, 'CORE SUIT')
# (1, 1, 1, 845, 185, 'COWBOY DOOM')
# (1, 1, 1, 846, 185, 'COWBOY DOOM')
# (1, 1, 1, 847, 186, 'CRAFT OUTFIELD')
# (1, 1, 1, 848, 186, 'CRAFT OUTFIELD')
# (2, 2, 2, 849, 186, 'CRAFT OUTFIELD')
# (2, 2, 2, 850, 186, 'CRAFT OUTFIELD')
# (2, 2, 2, 851, 187, 'CRANES RESERVOIR')
# (2, 2, 2, 852, 187, 'CRANES RESERVOIR')
# (2, 2, 2, 853, 187, 'CRANES RESERVOIR')
# (1, 1, 1, 854, 188, 'CRAZY HOME')
# (1, 1, 1, 855, 188, 'CRAZY HOME')
# (1, 1, 1, 856, 188, 'CRAZY HOME')
# (1, 1, 1, 857, 189, 'CREATURES SHAKESPEARE')
# (1, 1, 1, 858, 189, 'CREATURES SHAKESPEARE')
# (2, 2, 2, 859, 189, 'CREATURES SHAKESPEARE')
# (2, 2, 2, 860, 189, 'CREATURES SHAKESPEARE')
# (2, 2, 2, 861, 189, 'CREATURES SHAKESPEARE')
# (2, 2, 2, 862, 189, 'CREATURES SHAKESPEARE')
# (2, 2, 2, 863, 190, 'CREEPERS KANE')
# (2, 2, 2, 864, 190, 'CREEPERS KANE')
# (2, 2, 2, 865, 190, 'CREEPERS KANE')
# (2, 2, 2, 866, 190, 'CREEPERS KANE')
# (2, 2, 2, 870, 191, 'CROOKED FROGMEN')
# (2, 2, 2, 871, 191, 'CROOKED FROGMEN')
# (2, 2, 2, 872, 191, 'CROOKED FROGMEN')
# (1, 1, 1, 867, 191, 'CROOKED FROGMEN')
# (1, 1, 1, 868, 191, 'CROOKED FROGMEN')
# (1, 1, 1, 869, 191, 'CROOKED FROGMEN')
# (1, 1, 1, 873, 193, 'CROSSROADS CASUALTIES')
# (1, 1, 1, 874, 193, 'CROSSROADS CASUALTIES')
# (1, 1, 1, 875, 193, 'CROSSROADS CASUALTIES')
# (1, 1, 1, 876, 193, 'CROSSROADS CASUALTIES')
# (2, 2, 2, 877, 193, 'CROSSROADS CASUALTIES')
# (2, 2, 2, 878, 193, 'CROSSROADS CASUALTIES')
# (2, 2, 2, 879, 193, 'CROSSROADS CASUALTIES')
# (2, 2, 2, 880, 193, 'CROSSROADS CASUALTIES')
# (2, 2, 2, 883, 194, 'CROW GREASE')
# (2, 2, 2, 884, 194, 'CROW GREASE')
# (1, 1, 1, 881, 194, 'CROW GREASE')
# (1, 1, 1, 882, 194, 'CROW GREASE')
# (1, 1, 1, 885, 196, 'CRUELTY UNFORGIVEN')
# (1, 1, 1, 886, 196, 'CRUELTY UNFORGIVEN')
# (1, 1, 1, 887, 197, 'CRUSADE HONEY')
# (1, 1, 1, 888, 197, 'CRUSADE HONEY')
# (1, 1, 1, 889, 199, 'CUPBOARD SINNERS')
# (1, 1, 1, 890, 199, 'CUPBOARD SINNERS')
# (1, 1, 1, 891, 199, 'CUPBOARD SINNERS')
# (1, 1, 1, 892, 199, 'CUPBOARD SINNERS')
# (2, 2, 2, 893, 199, 'CUPBOARD SINNERS')
# (2, 2, 2, 894, 199, 'CUPBOARD SINNERS')
# (2, 2, 2, 895, 199, 'CUPBOARD SINNERS')
# (2, 2, 2, 896, 199, 'CUPBOARD SINNERS')
# (2, 2, 2, 901, 200, 'CURTAIN VIDEOTAPE')
# (2, 2, 2, 902, 200, 'CURTAIN VIDEOTAPE')
# (2, 2, 2, 903, 200, 'CURTAIN VIDEOTAPE')
# (2, 2, 2, 904, 200, 'CURTAIN VIDEOTAPE')
# (1, 1, 1, 897, 200, 'CURTAIN VIDEOTAPE')
# (1, 1, 1, 898, 200, 'CURTAIN VIDEOTAPE')
# (1, 1, 1, 899, 200, 'CURTAIN VIDEOTAPE')
# (1, 1, 1, 900, 200, 'CURTAIN VIDEOTAPE')
# (1, 1, 1, 905, 201, 'CYCLONE FAMILY')
# (1, 1, 1, 906, 201, 'CYCLONE FAMILY')
# (1, 1, 1, 907, 201, 'CYCLONE FAMILY')
# (1, 1, 1, 908, 201, 'CYCLONE FAMILY')
# (1, 1, 1, 909, 202, 'DADDY PITTSBURGH')
# (1, 1, 1, 910, 202, 'DADDY PITTSBURGH')
# (1, 1, 1, 911, 202, 'DADDY PITTSBURGH')
# (2, 2, 2, 912, 203, 'DAISY MENAGERIE')
# (2, 2, 2, 913, 203, 'DAISY MENAGERIE')
# (2, 2, 2, 914, 203, 'DAISY MENAGERIE')
# (2, 2, 2, 915, 203, 'DAISY MENAGERIE')
# (2, 2, 2, 920, 204, 'DALMATIONS SWEDEN')
# (2, 2, 2, 921, 204, 'DALMATIONS SWEDEN')
# (1, 1, 1, 916, 204, 'DALMATIONS SWEDEN')
# (1, 1, 1, 917, 204, 'DALMATIONS SWEDEN')
# (1, 1, 1, 918, 204, 'DALMATIONS SWEDEN')
# (1, 1, 1, 919, 204, 'DALMATIONS SWEDEN')
# (1, 1, 1, 922, 205, 'DANCES NONE')
# (1, 1, 1, 923, 205, 'DANCES NONE')
# (1, 1, 1, 924, 205, 'DANCES NONE')
# (1, 1, 1, 925, 205, 'DANCES NONE')
# (1, 1, 1, 926, 206, 'DANCING FEVER')
# (1, 1, 1, 927, 206, 'DANCING FEVER')
# (1, 1, 1, 928, 206, 'DANCING FEVER')
# (1, 1, 1, 929, 206, 'DANCING FEVER')
# (2, 2, 2, 930, 206, 'DANCING FEVER')
# (2, 2, 2, 931, 206, 'DANCING FEVER')
# (2, 2, 2, 932, 206, 'DANCING FEVER')
# (2, 2, 2, 933, 206, 'DANCING FEVER')
# (1, 1, 1, 934, 207, 'DANGEROUS UPTOWN')
# (1, 1, 1, 935, 207, 'DANGEROUS UPTOWN')
# (1, 1, 1, 936, 207, 'DANGEROUS UPTOWN')
# (1, 1, 1, 937, 207, 'DANGEROUS UPTOWN')
# (1, 1, 1, 938, 208, 'DARES PLUTO')
# (1, 1, 1, 939, 208, 'DARES PLUTO')
# (1, 1, 1, 940, 208, 'DARES PLUTO')
# (1, 1, 1, 941, 209, 'DARKNESS WAR')
# (1, 1, 1, 942, 209, 'DARKNESS WAR')
# (1, 1, 1, 943, 209, 'DARKNESS WAR')
# (1, 1, 1, 944, 209, 'DARKNESS WAR')
# (2, 2, 2, 945, 210, 'DARKO DORADO')
# (2, 2, 2, 946, 210, 'DARKO DORADO')
# (2, 2, 2, 947, 210, 'DARKO DORADO')
# (1, 1, 1, 948, 211, 'DARLING BREAKING')
# (1, 1, 1, 949, 211, 'DARLING BREAKING')
# (1, 1, 1, 950, 212, 'DARN FORRESTER')
# (1, 1, 1, 951, 212, 'DARN FORRESTER')
# (1, 1, 1, 952, 212, 'DARN FORRESTER')
# (2, 2, 2, 953, 212, 'DARN FORRESTER')
# (2, 2, 2, 954, 212, 'DARN FORRESTER')
# (1, 1, 1, 955, 213, 'DATE SPEED')
# (1, 1, 1, 956, 213, 'DATE SPEED')
# (1, 1, 1, 957, 213, 'DATE SPEED')
# (1, 1, 1, 958, 213, 'DATE SPEED')
# (2, 2, 2, 959, 214, 'DAUGHTER MADIGAN')
# (2, 2, 2, 960, 214, 'DAUGHTER MADIGAN')
# (2, 2, 2, 961, 214, 'DAUGHTER MADIGAN')
# (2, 2, 2, 962, 214, 'DAUGHTER MADIGAN')
# (2, 2, 2, 966, 215, 'DAWN POND')
# (2, 2, 2, 967, 215, 'DAWN POND')
# (2, 2, 2, 968, 215, 'DAWN POND')
# (1, 1, 1, 963, 215, 'DAWN POND')
# (1, 1, 1, 964, 215, 'DAWN POND')
# (1, 1, 1, 965, 215, 'DAWN POND')
# (1, 1, 1, 969, 216, 'DAY UNFAITHFUL')
# (1, 1, 1, 970, 216, 'DAY UNFAITHFUL')
# (2, 2, 2, 971, 216, 'DAY UNFAITHFUL')
# (2, 2, 2, 972, 216, 'DAY UNFAITHFUL')
# (2, 2, 2, 973, 216, 'DAY UNFAITHFUL')
# (2, 2, 2, 978, 218, 'DECEIVER BETRAYED')
# (2, 2, 2, 979, 218, 'DECEIVER BETRAYED')
# (2, 2, 2, 980, 218, 'DECEIVER BETRAYED')
# (1, 1, 1, 974, 218, 'DECEIVER BETRAYED')
# (1, 1, 1, 975, 218, 'DECEIVER BETRAYED')
# (1, 1, 1, 976, 218, 'DECEIVER BETRAYED')
# (1, 1, 1, 977, 218, 'DECEIVER BETRAYED')
# (1, 1, 1, 981, 219, 'DEEP CRUSADE')
# (1, 1, 1, 982, 219, 'DEEP CRUSADE')
# (1, 1, 1, 983, 219, 'DEEP CRUSADE')
# (1, 1, 1, 984, 219, 'DEEP CRUSADE')
# (1, 1, 1, 985, 220, 'DEER VIRGINIAN')
# (1, 1, 1, 986, 220, 'DEER VIRGINIAN')
# (1, 1, 1, 987, 220, 'DEER VIRGINIAN')
# (1, 1, 1, 988, 220, 'DEER VIRGINIAN')
# (2, 2, 2, 989, 220, 'DEER VIRGINIAN')
# (2, 2, 2, 990, 220, 'DEER VIRGINIAN')
# (2, 2, 2, 991, 220, 'DEER VIRGINIAN')
# (2, 2, 2, 992, 220, 'DEER VIRGINIAN')
# (2, 2, 2, 995, 222, 'DESERT POSEIDON')
# (2, 2, 2, 996, 222, 'DESERT POSEIDON')
# (2, 2, 2, 997, 222, 'DESERT POSEIDON')
# (2, 2, 2, 998, 222, 'DESERT POSEIDON')
# (1, 1, 1, 993, 222, 'DESERT POSEIDON')
# (1, 1, 1, 994, 222, 'DESERT POSEIDON')
# (2, 2, 2, 999, 223, 'DESIRE ALIEN')
# (2, 2, 2, 1000, 223, 'DESIRE ALIEN')
# (1, 1, 1, 1001, 224, 'DESPERATE TRAINSPOTTING')
# (1, 1, 1, 1002, 224, 'DESPERATE TRAINSPOTTING')
# (1, 1, 1, 1003, 225, 'DESTINATION JERK')
# (1, 1, 1, 1004, 225, 'DESTINATION JERK')
# (1, 1, 1, 1005, 225, 'DESTINATION JERK')
# (1, 1, 1, 1006, 226, 'DESTINY SATURDAY')
# (1, 1, 1, 1007, 226, 'DESTINY SATURDAY')
# (2, 2, 2, 1008, 226, 'DESTINY SATURDAY')
# (2, 2, 2, 1009, 226, 'DESTINY SATURDAY')
# (2, 2, 2, 1010, 226, 'DESTINY SATURDAY')
# (2, 2, 2, 1014, 227, 'DETAILS PACKER')
# (2, 2, 2, 1015, 227, 'DETAILS PACKER')
# (1, 1, 1, 1011, 227, 'DETAILS PACKER')
# (1, 1, 1, 1012, 227, 'DETAILS PACKER')
# (1, 1, 1, 1013, 227, 'DETAILS PACKER')
# (1, 1, 1, 1016, 228, 'DETECTIVE VISION')
# (1, 1, 1, 1017, 228, 'DETECTIVE VISION')
# (1, 1, 1, 1018, 228, 'DETECTIVE VISION')
# (2, 2, 2, 1019, 228, 'DETECTIVE VISION')
# (2, 2, 2, 1020, 228, 'DETECTIVE VISION')
# (2, 2, 2, 1021, 228, 'DETECTIVE VISION')
# (2, 2, 2, 1022, 228, 'DETECTIVE VISION')
# (2, 2, 2, 1025, 229, 'DEVIL DESIRE')
# (2, 2, 2, 1026, 229, 'DEVIL DESIRE')
# (1, 1, 1, 1023, 229, 'DEVIL DESIRE')
# (1, 1, 1, 1024, 229, 'DEVIL DESIRE')
# (1, 1, 1, 1027, 230, 'DIARY PANIC')
# (1, 1, 1, 1028, 230, 'DIARY PANIC')
# (1, 1, 1, 1029, 231, 'DINOSAUR SECRETARY')
# (1, 1, 1, 1030, 231, 'DINOSAUR SECRETARY')
# (1, 1, 1, 1031, 231, 'DINOSAUR SECRETARY')
# (1, 1, 1, 1032, 231, 'DINOSAUR SECRETARY')
# (2, 2, 2, 1033, 231, 'DINOSAUR SECRETARY')
# (2, 2, 2, 1034, 231, 'DINOSAUR SECRETARY')
# (2, 2, 2, 1035, 231, 'DINOSAUR SECRETARY')
# (2, 2, 2, 1036, 231, 'DINOSAUR SECRETARY')
# (2, 2, 2, 1040, 232, 'DIRTY ACE')
# (2, 2, 2, 1041, 232, 'DIRTY ACE')
# (1, 1, 1, 1037, 232, 'DIRTY ACE')
# (1, 1, 1, 1038, 232, 'DIRTY ACE')
# (1, 1, 1, 1039, 232, 'DIRTY ACE')
# (1, 1, 1, 1042, 233, 'DISCIPLE MOTHER')
# (1, 1, 1, 1043, 233, 'DISCIPLE MOTHER')
# (1, 1, 1, 1044, 233, 'DISCIPLE MOTHER')
# (1, 1, 1, 1045, 233, 'DISCIPLE MOTHER')
# (2, 2, 2, 1046, 233, 'DISCIPLE MOTHER')
# (2, 2, 2, 1047, 233, 'DISCIPLE MOTHER')
# (2, 2, 2, 1052, 234, 'DISTURBING SCARFACE')
# (2, 2, 2, 1053, 234, 'DISTURBING SCARFACE')
# (2, 2, 2, 1054, 234, 'DISTURBING SCARFACE')
# (1, 1, 1, 1048, 234, 'DISTURBING SCARFACE')
# (1, 1, 1, 1049, 234, 'DISTURBING SCARFACE')
# (1, 1, 1, 1050, 234, 'DISTURBING SCARFACE')
# (1, 1, 1, 1051, 234, 'DISTURBING SCARFACE')
# (1, 1, 1, 1055, 235, 'DIVIDE MONSTER')
# (1, 1, 1, 1056, 235, 'DIVIDE MONSTER')
# (2, 2, 2, 1057, 235, 'DIVIDE MONSTER')
# (2, 2, 2, 1058, 235, 'DIVIDE MONSTER')
# (2, 2, 2, 1059, 235, 'DIVIDE MONSTER')
# (2, 2, 2, 1060, 235, 'DIVIDE MONSTER')
# (2, 2, 2, 1061, 236, 'DIVINE RESURRECTION')
# (2, 2, 2, 1062, 236, 'DIVINE RESURRECTION')
# (2, 2, 2, 1063, 236, 'DIVINE RESURRECTION')
# (2, 2, 2, 1064, 236, 'DIVINE RESURRECTION')
# (1, 1, 1, 1065, 237, 'DIVORCE SHINING')
# (1, 1, 1, 1066, 237, 'DIVORCE SHINING')
# (1, 1, 1, 1067, 238, 'DOCTOR GRAIL')
# (1, 1, 1, 1068, 238, 'DOCTOR GRAIL')
# (1, 1, 1, 1069, 239, 'DOGMA FAMILY')
# (1, 1, 1, 1070, 239, 'DOGMA FAMILY')
# (1, 1, 1, 1071, 239, 'DOGMA FAMILY')
# (1, 1, 1, 1072, 239, 'DOGMA FAMILY')
# (2, 2, 2, 1073, 239, 'DOGMA FAMILY')
# (2, 2, 2, 1074, 239, 'DOGMA FAMILY')
# (2, 2, 2, 1075, 239, 'DOGMA FAMILY')
# (2, 2, 2, 1076, 239, 'DOGMA FAMILY')
# (2, 2, 2, 1077, 240, 'DOLLS RAGE')
# (2, 2, 2, 1078, 240, 'DOLLS RAGE')
# (2, 2, 2, 1079, 240, 'DOLLS RAGE')
# (1, 1, 1, 1080, 241, 'DONNIE ALLEY')
# (1, 1, 1, 1081, 241, 'DONNIE ALLEY')
# (1, 1, 1, 1082, 241, 'DONNIE ALLEY')
# (1, 1, 1, 1083, 241, 'DONNIE ALLEY')
# (1, 1, 1, 1084, 242, 'DOOM DANCING')
# (1, 1, 1, 1085, 242, 'DOOM DANCING')
# (2, 2, 2, 1086, 242, 'DOOM DANCING')
# (2, 2, 2, 1087, 242, 'DOOM DANCING')
# (2, 2, 2, 1088, 242, 'DOOM DANCING')
# (2, 2, 2, 1091, 243, 'DOORS PRESIDENT')
# (2, 2, 2, 1092, 243, 'DOORS PRESIDENT')
# (2, 2, 2, 1093, 243, 'DOORS PRESIDENT')
# (2, 2, 2, 1094, 243, 'DOORS PRESIDENT')
# (1, 1, 1, 1089, 243, 'DOORS PRESIDENT')
# (1, 1, 1, 1090, 243, 'DOORS PRESIDENT')
# (1, 1, 1, 1095, 244, 'DORADO NOTTING')
# (1, 1, 1, 1096, 244, 'DORADO NOTTING')
# (1, 1, 1, 1097, 244, 'DORADO NOTTING')
# (1, 1, 1, 1098, 244, 'DORADO NOTTING')
# (2, 2, 2, 1099, 244, 'DORADO NOTTING')
# (2, 2, 2, 1100, 244, 'DORADO NOTTING')
# (2, 2, 2, 1101, 244, 'DORADO NOTTING')
# (2, 2, 2, 1105, 245, 'DOUBLE WRATH')
# (2, 2, 2, 1106, 245, 'DOUBLE WRATH')
# (2, 2, 2, 1107, 245, 'DOUBLE WRATH')
# (2, 2, 2, 1108, 245, 'DOUBLE WRATH')
# (1, 1, 1, 1102, 245, 'DOUBLE WRATH')
# (1, 1, 1, 1103, 245, 'DOUBLE WRATH')
# (1, 1, 1, 1104, 245, 'DOUBLE WRATH')
# (2, 2, 2, 1109, 246, 'DOUBTFIRE LABYRINTH')
# (2, 2, 2, 1110, 246, 'DOUBTFIRE LABYRINTH')
# (2, 2, 2, 1111, 246, 'DOUBTFIRE LABYRINTH')
# (2, 2, 2, 1115, 247, 'DOWNHILL ENOUGH')
# (2, 2, 2, 1116, 247, 'DOWNHILL ENOUGH')
# (2, 2, 2, 1117, 247, 'DOWNHILL ENOUGH')
# (2, 2, 2, 1118, 247, 'DOWNHILL ENOUGH')
# (1, 1, 1, 1112, 247, 'DOWNHILL ENOUGH')
# (1, 1, 1, 1113, 247, 'DOWNHILL ENOUGH')
# (1, 1, 1, 1114, 247, 'DOWNHILL ENOUGH')
# (2, 2, 2, 1119, 248, 'DOZEN LION')
# (2, 2, 2, 1120, 248, 'DOZEN LION')
# (2, 2, 2, 1123, 249, 'DRACULA CRYSTAL')
# (2, 2, 2, 1124, 249, 'DRACULA CRYSTAL')
# (2, 2, 2, 1125, 249, 'DRACULA CRYSTAL')
# (2, 2, 2, 1126, 249, 'DRACULA CRYSTAL')
# (1, 1, 1, 1121, 249, 'DRACULA CRYSTAL')
# (1, 1, 1, 1122, 249, 'DRACULA CRYSTAL')
# (2, 2, 2, 1127, 250, 'DRAGON SQUAD')
# (2, 2, 2, 1128, 250, 'DRAGON SQUAD')
# (2, 2, 2, 1129, 250, 'DRAGON SQUAD')
# (2, 2, 2, 1130, 250, 'DRAGON SQUAD')
# (2, 2, 2, 1133, 251, 'DRAGONFLY STRANGERS')
# (2, 2, 2, 1134, 251, 'DRAGONFLY STRANGERS')
# (2, 2, 2, 1135, 251, 'DRAGONFLY STRANGERS')
# (1, 1, 1, 1131, 251, 'DRAGONFLY STRANGERS')
# (1, 1, 1, 1132, 251, 'DRAGONFLY STRANGERS')
# (1, 1, 1, 1136, 252, 'DREAM PICKUP')
# (1, 1, 1, 1137, 252, 'DREAM PICKUP')
# (1, 1, 1, 1138, 252, 'DREAM PICKUP')
# (2, 2, 2, 1139, 252, 'DREAM PICKUP')
# (2, 2, 2, 1140, 252, 'DREAM PICKUP')
# (2, 2, 2, 1141, 252, 'DREAM PICKUP')
# (2, 2, 2, 1146, 253, 'DRIFTER COMMANDMENTS')
# (2, 2, 2, 1147, 253, 'DRIFTER COMMANDMENTS')
# (1, 1, 1, 1142, 253, 'DRIFTER COMMANDMENTS')
# (1, 1, 1, 1143, 253, 'DRIFTER COMMANDMENTS')
# (1, 1, 1, 1144, 253, 'DRIFTER COMMANDMENTS')
# (1, 1, 1, 1145, 253, 'DRIFTER COMMANDMENTS')
# (1, 1, 1, 1148, 254, 'DRIVER ANNIE')
# (1, 1, 1, 1149, 254, 'DRIVER ANNIE')
# (2, 2, 2, 1150, 254, 'DRIVER ANNIE')
# (2, 2, 2, 1151, 254, 'DRIVER ANNIE')
# (2, 2, 2, 1152, 254, 'DRIVER ANNIE')
# (2, 2, 2, 1157, 255, 'DRIVING POLISH')
# (2, 2, 2, 1158, 255, 'DRIVING POLISH')
# (1, 1, 1, 1153, 255, 'DRIVING POLISH')
# (1, 1, 1, 1154, 255, 'DRIVING POLISH')
# (1, 1, 1, 1155, 255, 'DRIVING POLISH')
# (1, 1, 1, 1156, 255, 'DRIVING POLISH')
# (2, 2, 2, 1159, 256, 'DROP WATERFRONT')
# (2, 2, 2, 1160, 256, 'DROP WATERFRONT')
# (2, 2, 2, 1161, 256, 'DROP WATERFRONT')
# (2, 2, 2, 1162, 257, 'DRUMLINE CYCLONE')
# (2, 2, 2, 1163, 257, 'DRUMLINE CYCLONE')
# (2, 2, 2, 1164, 257, 'DRUMLINE CYCLONE')
# (2, 2, 2, 1165, 258, 'DRUMS DYNAMITE')
# (2, 2, 2, 1166, 258, 'DRUMS DYNAMITE')
# (2, 2, 2, 1167, 258, 'DRUMS DYNAMITE')
# (2, 2, 2, 1168, 258, 'DRUMS DYNAMITE')
# (1, 1, 1, 1169, 259, 'DUCK RACER')
# (1, 1, 1, 1170, 259, 'DUCK RACER')
# (2, 2, 2, 1171, 260, 'DUDE BLINDNESS')
# (2, 2, 2, 1172, 260, 'DUDE BLINDNESS')
# (2, 2, 2, 1173, 260, 'DUDE BLINDNESS')
# (2, 2, 2, 1174, 260, 'DUDE BLINDNESS')
# (1, 1, 1, 1175, 261, 'DUFFEL APOCALYPSE')
# (1, 1, 1, 1176, 261, 'DUFFEL APOCALYPSE')
# (2, 2, 2, 1177, 262, 'DUMBO LUST')
# (2, 2, 2, 1178, 262, 'DUMBO LUST')
# (2, 2, 2, 1183, 263, 'DURHAM PANKY')
# (2, 2, 2, 1184, 263, 'DURHAM PANKY')
# (2, 2, 2, 1185, 263, 'DURHAM PANKY')
# (1, 1, 1, 1179, 263, 'DURHAM PANKY')
# (1, 1, 1, 1180, 263, 'DURHAM PANKY')
# (1, 1, 1, 1181, 263, 'DURHAM PANKY')
# (1, 1, 1, 1182, 263, 'DURHAM PANKY')
# (2, 2, 2, 1186, 264, 'DWARFS ALTER')
# (2, 2, 2, 1187, 264, 'DWARFS ALTER')
# (1, 1, 1, 1188, 265, 'DYING MAKER')
# (1, 1, 1, 1189, 265, 'DYING MAKER')
# (1, 1, 1, 1190, 265, 'DYING MAKER')
# (1, 1, 1, 1191, 265, 'DYING MAKER')
# (1, 1, 1, 1192, 266, 'DYNAMITE TARZAN')
# (1, 1, 1, 1193, 266, 'DYNAMITE TARZAN')
# (1, 1, 1, 1194, 266, 'DYNAMITE TARZAN')
# (1, 1, 1, 1195, 266, 'DYNAMITE TARZAN')
# (2, 2, 2, 1196, 266, 'DYNAMITE TARZAN')
# (2, 2, 2, 1197, 266, 'DYNAMITE TARZAN')
# (2, 2, 2, 1198, 266, 'DYNAMITE TARZAN')
# (2, 2, 2, 1199, 266, 'DYNAMITE TARZAN')
# (2, 2, 2, 1204, 267, 'EAGLES PANKY')
# (2, 2, 2, 1205, 267, 'EAGLES PANKY')
# (1, 1, 1, 1200, 267, 'EAGLES PANKY')
# (1, 1, 1, 1201, 267, 'EAGLES PANKY')
# (1, 1, 1, 1202, 267, 'EAGLES PANKY')
# (1, 1, 1, 1203, 267, 'EAGLES PANKY')
# (2, 2, 2, 1206, 268, 'EARLY HOME')
# (2, 2, 2, 1207, 268, 'EARLY HOME')
# (2, 2, 2, 1210, 269, 'EARRING INSTINCT')
# (2, 2, 2, 1211, 269, 'EARRING INSTINCT')
# (2, 2, 2, 1212, 269, 'EARRING INSTINCT')
# (2, 2, 2, 1213, 269, 'EARRING INSTINCT')
# (1, 1, 1, 1208, 269, 'EARRING INSTINCT')
# (1, 1, 1, 1209, 269, 'EARRING INSTINCT')
# (1, 1, 1, 1214, 270, 'EARTH VISION')
# (1, 1, 1, 1215, 270, 'EARTH VISION')
# (1, 1, 1, 1216, 270, 'EARTH VISION')
# (2, 2, 2, 1217, 270, 'EARTH VISION')
# (2, 2, 2, 1218, 270, 'EARTH VISION')
# (2, 2, 2, 1219, 270, 'EARTH VISION')
# (2, 2, 2, 1220, 270, 'EARTH VISION')
# (2, 2, 2, 1224, 271, 'EASY GLADIATOR')
# (2, 2, 2, 1225, 271, 'EASY GLADIATOR')
# (1, 1, 1, 1221, 271, 'EASY GLADIATOR')
# (1, 1, 1, 1222, 271, 'EASY GLADIATOR')
# (1, 1, 1, 1223, 271, 'EASY GLADIATOR')
# (1, 1, 1, 1226, 272, 'EDGE KISSING')
# (1, 1, 1, 1227, 272, 'EDGE KISSING')
# (1, 1, 1, 1228, 272, 'EDGE KISSING')
# (1, 1, 1, 1229, 272, 'EDGE KISSING')
# (1, 1, 1, 1230, 273, 'EFFECT GLADIATOR')
# (1, 1, 1, 1231, 273, 'EFFECT GLADIATOR')
# (1, 1, 1, 1232, 273, 'EFFECT GLADIATOR')
# (1, 1, 1, 1233, 273, 'EFFECT GLADIATOR')
# (2, 2, 2, 1234, 273, 'EFFECT GLADIATOR')
# (2, 2, 2, 1235, 273, 'EFFECT GLADIATOR')
# (2, 2, 2, 1236, 273, 'EFFECT GLADIATOR')
# (2, 2, 2, 1240, 274, 'EGG IGBY')
# (2, 2, 2, 1241, 274, 'EGG IGBY')
# (2, 2, 2, 1242, 274, 'EGG IGBY')
# (2, 2, 2, 1243, 274, 'EGG IGBY')
# (1, 1, 1, 1237, 274, 'EGG IGBY')
# (1, 1, 1, 1238, 274, 'EGG IGBY')
# (1, 1, 1, 1239, 274, 'EGG IGBY')
# (1, 1, 1, 1244, 275, 'EGYPT TENENBAUMS')
# (1, 1, 1, 1245, 275, 'EGYPT TENENBAUMS')
# (1, 1, 1, 1246, 275, 'EGYPT TENENBAUMS')
# (2, 2, 2, 1247, 275, 'EGYPT TENENBAUMS')
# (2, 2, 2, 1248, 275, 'EGYPT TENENBAUMS')
# (1, 1, 1, 1249, 276, 'ELEMENT FREDDY')
# ...
# (1, 1, 1, 4171, 907, 'TRANSLATION SUMMER')
# (1, 1, 1, 4172, 907, 'TRANSLATION SUMMER')
# (1, 1, 1, 4173, 907, 'TRANSLATION SUMMER')
# (1, 1, 1, 4174, 907, 'TRANSLATION SUMMER')
# (1, 1, 1, 4175, 908, 'TRAP GUYS')
# (1, 1, 1, 4176, 908, 'TRAP GUYS')
# (2, 2, 2, 4177, 908, 'TRAP GUYS')
# (2, 2, 2, 4178, 908, 'TRAP GUYS')
# (2, 2, 2, 4179, 910, 'TREATMENT JEKYLL')
# (2, 2, 2, 4180, 910, 'TREATMENT JEKYLL')
# (2, 2, 2, 4185, 911, 'TRIP NEWTON')
# (2, 2, 2, 4186, 911, 'TRIP NEWTON')
# (2, 2, 2, 4187, 911, 'TRIP NEWTON')
# (2, 2, 2, 4188, 911, 'TRIP NEWTON')
# (1, 1, 1, 4181, 911, 'TRIP NEWTON')
# (1, 1, 1, 4182, 911, 'TRIP NEWTON')
# (1, 1, 1, 4183, 911, 'TRIP NEWTON')
# (1, 1, 1, 4184, 911, 'TRIP NEWTON')
# (1, 1, 1, 4189, 912, 'TROJAN TOMORROW')
# (1, 1, 1, 4190, 912, 'TROJAN TOMORROW')
# (1, 1, 1, 4191, 912, 'TROJAN TOMORROW')
# (2, 2, 2, 4192, 912, 'TROJAN TOMORROW')
# (2, 2, 2, 4193, 912, 'TROJAN TOMORROW')
# (2, 2, 2, 4194, 912, 'TROJAN TOMORROW')
# (2, 2, 2, 4199, 913, 'TROOPERS METAL')
# (2, 2, 2, 4200, 913, 'TROOPERS METAL')
# (1, 1, 1, 4195, 913, 'TROOPERS METAL')
# (1, 1, 1, 4196, 913, 'TROOPERS METAL')
# (1, 1, 1, 4197, 913, 'TROOPERS METAL')
# (1, 1, 1, 4198, 913, 'TROOPERS METAL')
# (1, 1, 1, 4201, 914, 'TROUBLE DATE')
# (1, 1, 1, 4202, 914, 'TROUBLE DATE')
# (2, 2, 2, 4203, 914, 'TROUBLE DATE')
# (2, 2, 2, 4204, 914, 'TROUBLE DATE')
# (2, 2, 2, 4205, 914, 'TROUBLE DATE')
# (2, 2, 2, 4206, 914, 'TROUBLE DATE')
# (2, 2, 2, 4211, 915, 'TRUMAN CRAZY')
# (2, 2, 2, 4212, 915, 'TRUMAN CRAZY')
# (1, 1, 1, 4207, 915, 'TRUMAN CRAZY')
# (1, 1, 1, 4208, 915, 'TRUMAN CRAZY')
# (1, 1, 1, 4209, 915, 'TRUMAN CRAZY')
# (1, 1, 1, 4210, 915, 'TRUMAN CRAZY')
# (1, 1, 1, 4213, 916, 'TURN STAR')
# (1, 1, 1, 4214, 916, 'TURN STAR')
# (2, 2, 2, 4215, 916, 'TURN STAR')
# (2, 2, 2, 4216, 916, 'TURN STAR')
# (2, 2, 2, 4220, 917, 'TUXEDO MILE')
# (2, 2, 2, 4221, 917, 'TUXEDO MILE')
# (1, 1, 1, 4217, 917, 'TUXEDO MILE')
# (1, 1, 1, 4218, 917, 'TUXEDO MILE')
# (1, 1, 1, 4219, 917, 'TUXEDO MILE')
# (2, 2, 2, 4222, 918, 'TWISTED PIRATES')
# (2, 2, 2, 4223, 918, 'TWISTED PIRATES')
# (2, 2, 2, 4224, 918, 'TWISTED PIRATES')
# (2, 2, 2, 4225, 918, 'TWISTED PIRATES')
# (1, 1, 1, 4226, 919, 'TYCOON GATHERING')
# (1, 1, 1, 4227, 919, 'TYCOON GATHERING')
# (1, 1, 1, 4228, 919, 'TYCOON GATHERING')
# (1, 1, 1, 4229, 919, 'TYCOON GATHERING')
# (1, 1, 1, 4230, 920, 'UNBREAKABLE KARATE')
# (1, 1, 1, 4231, 920, 'UNBREAKABLE KARATE')
# (1, 1, 1, 4232, 920, 'UNBREAKABLE KARATE')
# (2, 2, 2, 4233, 920, 'UNBREAKABLE KARATE')
# (2, 2, 2, 4234, 920, 'UNBREAKABLE KARATE')
# (2, 2, 2, 4237, 921, 'UNCUT SUICIDES')
# (2, 2, 2, 4238, 921, 'UNCUT SUICIDES')
# (1, 1, 1, 4235, 921, 'UNCUT SUICIDES')
# (1, 1, 1, 4236, 921, 'UNCUT SUICIDES')
# (1, 1, 1, 4239, 922, 'UNDEFEATED DALMATIONS')
# (1, 1, 1, 4240, 922, 'UNDEFEATED DALMATIONS')
# (1, 1, 1, 4241, 922, 'UNDEFEATED DALMATIONS')
# (2, 2, 2, 4242, 922, 'UNDEFEATED DALMATIONS')
# (2, 2, 2, 4243, 922, 'UNDEFEATED DALMATIONS')
# (2, 2, 2, 4244, 922, 'UNDEFEATED DALMATIONS')
# (2, 2, 2, 4245, 922, 'UNDEFEATED DALMATIONS')
# (2, 2, 2, 4246, 923, 'UNFAITHFUL KILL')
# (2, 2, 2, 4247, 923, 'UNFAITHFUL KILL')
# (2, 2, 2, 4248, 923, 'UNFAITHFUL KILL')
# (2, 2, 2, 4251, 924, 'UNFORGIVEN ZOOLANDER')
# (2, 2, 2, 4252, 924, 'UNFORGIVEN ZOOLANDER')
# (2, 2, 2, 4253, 924, 'UNFORGIVEN ZOOLANDER')
# (1, 1, 1, 4249, 924, 'UNFORGIVEN ZOOLANDER')
# (1, 1, 1, 4250, 924, 'UNFORGIVEN ZOOLANDER')
# (1, 1, 1, 4254, 925, 'UNITED PILOT')
# (1, 1, 1, 4255, 925, 'UNITED PILOT')
# (1, 1, 1, 4256, 925, 'UNITED PILOT')
# (2, 2, 2, 4257, 925, 'UNITED PILOT')
# (2, 2, 2, 4258, 925, 'UNITED PILOT')
# (2, 2, 2, 4259, 926, 'UNTOUCHABLES SUNRISE')
# (2, 2, 2, 4260, 926, 'UNTOUCHABLES SUNRISE')
# (1, 1, 1, 4261, 927, 'UPRISING UPTOWN')
# (1, 1, 1, 4262, 927, 'UPRISING UPTOWN')
# (1, 1, 1, 4263, 927, 'UPRISING UPTOWN')
# (1, 1, 1, 4264, 927, 'UPRISING UPTOWN')
# (1, 1, 1, 4265, 928, 'UPTOWN YOUNG')
# (1, 1, 1, 4266, 928, 'UPTOWN YOUNG')
# (1, 1, 1, 4267, 928, 'UPTOWN YOUNG')
# (1, 1, 1, 4268, 929, 'USUAL UNTOUCHABLES')
# (1, 1, 1, 4269, 929, 'USUAL UNTOUCHABLES')
# (1, 1, 1, 4270, 929, 'USUAL UNTOUCHABLES')
# (1, 1, 1, 4271, 929, 'USUAL UNTOUCHABLES')
# (1, 1, 1, 4272, 930, 'VACATION BOONDOCK')
# (1, 1, 1, 4273, 930, 'VACATION BOONDOCK')
# (1, 1, 1, 4274, 930, 'VACATION BOONDOCK')
# (2, 2, 2, 4275, 930, 'VACATION BOONDOCK')
# (2, 2, 2, 4276, 930, 'VACATION BOONDOCK')
# (2, 2, 2, 4277, 930, 'VACATION BOONDOCK')
# (2, 2, 2, 4278, 931, 'VALENTINE VANISHING')
# (2, 2, 2, 4279, 931, 'VALENTINE VANISHING')
# (2, 2, 2, 4280, 931, 'VALENTINE VANISHING')
# (2, 2, 2, 4283, 932, 'VALLEY PACKER')
# (2, 2, 2, 4284, 932, 'VALLEY PACKER')
# (1, 1, 1, 4281, 932, 'VALLEY PACKER')
# (1, 1, 1, 4282, 932, 'VALLEY PACKER')
# (1, 1, 1, 4285, 933, 'VAMPIRE WHALE')
# (1, 1, 1, 4286, 933, 'VAMPIRE WHALE')
# (1, 1, 1, 4287, 933, 'VAMPIRE WHALE')
# (2, 2, 2, 4288, 934, 'VANILLA DAY')
# (2, 2, 2, 4289, 934, 'VANILLA DAY')
# (2, 2, 2, 4290, 934, 'VANILLA DAY')
# (2, 2, 2, 4291, 935, 'VANISHED GARDEN')
# (2, 2, 2, 4292, 935, 'VANISHED GARDEN')
# (2, 2, 2, 4295, 936, 'VANISHING ROCKY')
# (2, 2, 2, 4296, 936, 'VANISHING ROCKY')
# (2, 2, 2, 4297, 936, 'VANISHING ROCKY')
# (2, 2, 2, 4298, 936, 'VANISHING ROCKY')
# (1, 1, 1, 4293, 936, 'VANISHING ROCKY')
# (1, 1, 1, 4294, 936, 'VANISHING ROCKY')
# (1, 1, 1, 4299, 937, 'VARSITY TRIP')
# (1, 1, 1, 4300, 937, 'VARSITY TRIP')
# (2, 2, 2, 4301, 937, 'VARSITY TRIP')
# (2, 2, 2, 4302, 937, 'VARSITY TRIP')
# (2, 2, 2, 4303, 937, 'VARSITY TRIP')
# (2, 2, 2, 4308, 938, 'VELVET TERMINATOR')
# (2, 2, 2, 4309, 938, 'VELVET TERMINATOR')
# (1, 1, 1, 4304, 938, 'VELVET TERMINATOR')
# (1, 1, 1, 4305, 938, 'VELVET TERMINATOR')
# (1, 1, 1, 4306, 938, 'VELVET TERMINATOR')
# (1, 1, 1, 4307, 938, 'VELVET TERMINATOR')
# (2, 2, 2, 4310, 939, 'VERTIGO NORTHWEST')
# (2, 2, 2, 4311, 939, 'VERTIGO NORTHWEST')
# (2, 2, 2, 4312, 939, 'VERTIGO NORTHWEST')
# (2, 2, 2, 4313, 939, 'VERTIGO NORTHWEST')
# (1, 1, 1, 4314, 940, 'VICTORY ACADEMY')
# (1, 1, 1, 4315, 940, 'VICTORY ACADEMY')
# (1, 1, 1, 4316, 940, 'VICTORY ACADEMY')
# (1, 1, 1, 4317, 941, 'VIDEOTAPE ARSENIC')
# (1, 1, 1, 4318, 941, 'VIDEOTAPE ARSENIC')
# (1, 1, 1, 4319, 941, 'VIDEOTAPE ARSENIC')
# (1, 1, 1, 4320, 941, 'VIDEOTAPE ARSENIC')
# (2, 2, 2, 4321, 941, 'VIDEOTAPE ARSENIC')
# (2, 2, 2, 4322, 941, 'VIDEOTAPE ARSENIC')
# (2, 2, 2, 4323, 941, 'VIDEOTAPE ARSENIC')
# (2, 2, 2, 4326, 942, 'VIETNAM SMOOCHY')
# (2, 2, 2, 4327, 942, 'VIETNAM SMOOCHY')
# (1, 1, 1, 4324, 942, 'VIETNAM SMOOCHY')
# (1, 1, 1, 4325, 942, 'VIETNAM SMOOCHY')
# (1, 1, 1, 4328, 944, 'VIRGIN DAISY')
# (1, 1, 1, 4329, 944, 'VIRGIN DAISY')
# (2, 2, 2, 4330, 944, 'VIRGIN DAISY')
# (2, 2, 2, 4331, 944, 'VIRGIN DAISY')
# (2, 2, 2, 4332, 944, 'VIRGIN DAISY')
# (2, 2, 2, 4337, 945, 'VIRGINIAN PLUTO')
# (2, 2, 2, 4338, 945, 'VIRGINIAN PLUTO')
# (2, 2, 2, 4339, 945, 'VIRGINIAN PLUTO')
# (2, 2, 2, 4340, 945, 'VIRGINIAN PLUTO')
# (1, 1, 1, 4333, 945, 'VIRGINIAN PLUTO')
# (1, 1, 1, 4334, 945, 'VIRGINIAN PLUTO')
# (1, 1, 1, 4335, 945, 'VIRGINIAN PLUTO')
# (1, 1, 1, 4336, 945, 'VIRGINIAN PLUTO')
# (2, 2, 2, 4341, 946, 'VIRTUAL SPOILERS')
# (2, 2, 2, 4342, 946, 'VIRTUAL SPOILERS')
# (2, 2, 2, 4343, 946, 'VIRTUAL SPOILERS')
# (2, 2, 2, 4344, 946, 'VIRTUAL SPOILERS')
# (1, 1, 1, 4345, 947, 'VISION TORQUE')
# (1, 1, 1, 4346, 947, 'VISION TORQUE')
# (1, 1, 1, 4347, 948, 'VOICE PEACH')
# (1, 1, 1, 4348, 948, 'VOICE PEACH')
# (2, 2, 2, 4349, 948, 'VOICE PEACH')
# (2, 2, 2, 4350, 948, 'VOICE PEACH')
# (2, 2, 2, 4351, 948, 'VOICE PEACH')
# (2, 2, 2, 4352, 948, 'VOICE PEACH')
# (2, 2, 2, 4357, 949, 'VOLCANO TEXAS')
# (2, 2, 2, 4358, 949, 'VOLCANO TEXAS')
# (1, 1, 1, 4353, 949, 'VOLCANO TEXAS')
# (1, 1, 1, 4354, 949, 'VOLCANO TEXAS')
# (1, 1, 1, 4355, 949, 'VOLCANO TEXAS')
# (1, 1, 1, 4356, 949, 'VOLCANO TEXAS')
# (1, 1, 1, 4359, 951, 'VOYAGE LEGALLY')
# (1, 1, 1, 4360, 951, 'VOYAGE LEGALLY')
# (1, 1, 1, 4361, 951, 'VOYAGE LEGALLY')
# (2, 2, 2, 4362, 951, 'VOYAGE LEGALLY')
# (2, 2, 2, 4363, 951, 'VOYAGE LEGALLY')
# (2, 2, 2, 4364, 951, 'VOYAGE LEGALLY')
# (2, 2, 2, 4365, 951, 'VOYAGE LEGALLY')
# (1, 1, 1, 4366, 952, 'WAGON JAWS')
# (1, 1, 1, 4367, 952, 'WAGON JAWS')
# (1, 1, 1, 4368, 952, 'WAGON JAWS')
# (1, 1, 1, 4369, 953, 'WAIT CIDER')
# (1, 1, 1, 4370, 953, 'WAIT CIDER')
# (1, 1, 1, 4371, 953, 'WAIT CIDER')
# (1, 1, 1, 4372, 953, 'WAIT CIDER')
# (2, 2, 2, 4373, 953, 'WAIT CIDER')
# (2, 2, 2, 4374, 953, 'WAIT CIDER')
# (1, 1, 1, 4375, 956, 'WANDA CHAMBER')
# (1, 1, 1, 4376, 956, 'WANDA CHAMBER')
# (1, 1, 1, 4377, 956, 'WANDA CHAMBER')
# (1, 1, 1, 4378, 956, 'WANDA CHAMBER')
# (1, 1, 1, 4379, 957, 'WAR NOTTING')
# (1, 1, 1, 4380, 957, 'WAR NOTTING')
# (1, 1, 1, 4381, 957, 'WAR NOTTING')
# (2, 2, 2, 4382, 957, 'WAR NOTTING')
# (2, 2, 2, 4383, 957, 'WAR NOTTING')
# (2, 2, 2, 4387, 958, 'WARDROBE PHANTOM')
# (2, 2, 2, 4388, 958, 'WARDROBE PHANTOM')
# (2, 2, 2, 4389, 958, 'WARDROBE PHANTOM')
# (1, 1, 1, 4384, 958, 'WARDROBE PHANTOM')
# (1, 1, 1, 4385, 958, 'WARDROBE PHANTOM')
# (1, 1, 1, 4386, 958, 'WARDROBE PHANTOM')
# (1, 1, 1, 4390, 959, 'WARLOCK WEREWOLF')
# (1, 1, 1, 4391, 959, 'WARLOCK WEREWOLF')
# (2, 2, 2, 4392, 960, 'WARS PLUTO')
# (2, 2, 2, 4393, 960, 'WARS PLUTO')
# (2, 2, 2, 4394, 960, 'WARS PLUTO')
# (2, 2, 2, 4398, 961, 'WASH HEAVENLY')
# (2, 2, 2, 4399, 961, 'WASH HEAVENLY')
# (1, 1, 1, 4395, 961, 'WASH HEAVENLY')
# (1, 1, 1, 4396, 961, 'WASH HEAVENLY')
# (1, 1, 1, 4397, 961, 'WASH HEAVENLY')
# (1, 1, 1, 4400, 962, 'WASTELAND DIVINE')
# (1, 1, 1, 4401, 962, 'WASTELAND DIVINE')
# (1, 1, 1, 4402, 962, 'WASTELAND DIVINE')
# (1, 1, 1, 4403, 962, 'WASTELAND DIVINE')
# (1, 1, 1, 4404, 963, 'WATCH TRACY')
# (1, 1, 1, 4405, 963, 'WATCH TRACY')
# (2, 2, 2, 4406, 963, 'WATCH TRACY')
# (2, 2, 2, 4407, 963, 'WATCH TRACY')
# (2, 2, 2, 4408, 963, 'WATCH TRACY')
# (2, 2, 2, 4412, 964, 'WATERFRONT DELIVERANCE')
# (2, 2, 2, 4413, 964, 'WATERFRONT DELIVERANCE')
# (1, 1, 1, 4409, 964, 'WATERFRONT DELIVERANCE')
# (1, 1, 1, 4410, 964, 'WATERFRONT DELIVERANCE')
# (1, 1, 1, 4411, 964, 'WATERFRONT DELIVERANCE')
# (1, 1, 1, 4414, 965, 'WATERSHIP FRONTIER')
# (1, 1, 1, 4415, 965, 'WATERSHIP FRONTIER')
# (1, 1, 1, 4416, 966, 'WEDDING APOLLO')
# (1, 1, 1, 4417, 966, 'WEDDING APOLLO')
# (2, 2, 2, 4418, 966, 'WEDDING APOLLO')
# (2, 2, 2, 4419, 966, 'WEDDING APOLLO')
# (2, 2, 2, 4420, 966, 'WEDDING APOLLO')
# (2, 2, 2, 4421, 966, 'WEDDING APOLLO')
# (2, 2, 2, 4425, 967, 'WEEKEND PERSONAL')
# (2, 2, 2, 4426, 967, 'WEEKEND PERSONAL')
# (1, 1, 1, 4422, 967, 'WEEKEND PERSONAL')
# (1, 1, 1, 4423, 967, 'WEEKEND PERSONAL')
# (1, 1, 1, 4424, 967, 'WEEKEND PERSONAL')
# (1, 1, 1, 4427, 968, 'WEREWOLF LOLA')
# (1, 1, 1, 4428, 968, 'WEREWOLF LOLA')
# (1, 1, 1, 4429, 968, 'WEREWOLF LOLA')
# (1, 1, 1, 4430, 969, 'WEST LION')
# (1, 1, 1, 4431, 969, 'WEST LION')
# (1, 1, 1, 4432, 969, 'WEST LION')
# (1, 1, 1, 4433, 969, 'WEST LION')
# (1, 1, 1, 4434, 970, 'WESTWARD SEABISCUIT')
# (1, 1, 1, 4435, 970, 'WESTWARD SEABISCUIT')
# (1, 1, 1, 4436, 970, 'WESTWARD SEABISCUIT')
# (2, 2, 2, 4437, 970, 'WESTWARD SEABISCUIT')
# (2, 2, 2, 4438, 970, 'WESTWARD SEABISCUIT')
# (2, 2, 2, 4439, 970, 'WESTWARD SEABISCUIT')
# (2, 2, 2, 4440, 970, 'WESTWARD SEABISCUIT')
# (1, 1, 1, 4441, 971, 'WHALE BIKINI')
# (1, 1, 1, 4442, 971, 'WHALE BIKINI')
# (1, 1, 1, 4443, 971, 'WHALE BIKINI')
# (1, 1, 1, 4444, 971, 'WHALE BIKINI')
# (1, 1, 1, 4445, 972, 'WHISPERER GIANT')
# (1, 1, 1, 4446, 972, 'WHISPERER GIANT')
# (1, 1, 1, 4447, 972, 'WHISPERER GIANT')
# (2, 2, 2, 4448, 972, 'WHISPERER GIANT')
# (2, 2, 2, 4449, 972, 'WHISPERER GIANT')
# (2, 2, 2, 4450, 972, 'WHISPERER GIANT')
# (2, 2, 2, 4455, 973, 'WIFE TURN')
# (2, 2, 2, 4456, 973, 'WIFE TURN')
# (2, 2, 2, 4457, 973, 'WIFE TURN')
# (2, 2, 2, 4458, 973, 'WIFE TURN')
# (1, 1, 1, 4451, 973, 'WIFE TURN')
# (1, 1, 1, 4452, 973, 'WIFE TURN')
# (1, 1, 1, 4453, 973, 'WIFE TURN')
# (1, 1, 1, 4454, 973, 'WIFE TURN')
# (1, 1, 1, 4459, 974, 'WILD APOLLO')
# (1, 1, 1, 4460, 974, 'WILD APOLLO')
# (1, 1, 1, 4461, 975, 'WILLOW TRACY')
# (1, 1, 1, 4462, 975, 'WILLOW TRACY')
# (2, 2, 2, 4463, 975, 'WILLOW TRACY')
# (2, 2, 2, 4464, 975, 'WILLOW TRACY')
# (2, 2, 2, 4465, 975, 'WILLOW TRACY')
# (2, 2, 2, 4468, 976, 'WIND PHANTOM')
# (2, 2, 2, 4469, 976, 'WIND PHANTOM')
# (2, 2, 2, 4470, 976, 'WIND PHANTOM')
# (2, 2, 2, 4471, 976, 'WIND PHANTOM')
# (1, 1, 1, 4466, 976, 'WIND PHANTOM')
# (1, 1, 1, 4467, 976, 'WIND PHANTOM')
# (2, 2, 2, 4472, 977, 'WINDOW SIDE')
# (2, 2, 2, 4473, 977, 'WINDOW SIDE')
# (2, 2, 2, 4474, 977, 'WINDOW SIDE')
# (1, 1, 1, 4475, 978, 'WISDOM WORKER')
# (1, 1, 1, 4476, 978, 'WISDOM WORKER')
# (1, 1, 1, 4477, 978, 'WISDOM WORKER')
# (1, 1, 1, 4478, 979, 'WITCHES PANIC')
# (1, 1, 1, 4479, 979, 'WITCHES PANIC')
# (1, 1, 1, 4480, 979, 'WITCHES PANIC')
# (1, 1, 1, 4481, 979, 'WITCHES PANIC')
# (2, 2, 2, 4482, 979, 'WITCHES PANIC')
# (2, 2, 2, 4483, 979, 'WITCHES PANIC')
# (2, 2, 2, 4484, 979, 'WITCHES PANIC')
# (2, 2, 2, 4488, 980, 'WIZARD COLDBLOODED')
# (2, 2, 2, 4489, 980, 'WIZARD COLDBLOODED')
# (1, 1, 1, 4485, 980, 'WIZARD COLDBLOODED')
# (1, 1, 1, 4486, 980, 'WIZARD COLDBLOODED')
# (1, 1, 1, 4487, 980, 'WIZARD COLDBLOODED')
# (1, 1, 1, 4490, 981, 'WOLVES DESIRE')
# (1, 1, 1, 4491, 981, 'WOLVES DESIRE')
# (1, 1, 1, 4492, 981, 'WOLVES DESIRE')
# (2, 2, 2, 4493, 981, 'WOLVES DESIRE')
# (2, 2, 2, 4494, 981, 'WOLVES DESIRE')
# (2, 2, 2, 4495, 981, 'WOLVES DESIRE')
# (2, 2, 2, 4499, 982, 'WOMEN DORADO')
# (2, 2, 2, 4500, 982, 'WOMEN DORADO')
# (2, 2, 2, 4501, 982, 'WOMEN DORADO')
# (2, 2, 2, 4502, 982, 'WOMEN DORADO')
# (1, 1, 1, 4496, 982, 'WOMEN DORADO')
# (1, 1, 1, 4497, 982, 'WOMEN DORADO')
# (1, 1, 1, 4498, 982, 'WOMEN DORADO')
# (1, 1, 1, 4503, 983, 'WON DARES')
# (1, 1, 1, 4504, 983, 'WON DARES')
# (1, 1, 1, 4505, 983, 'WON DARES')
# (1, 1, 1, 4506, 984, 'WONDERFUL DROP')
# (1, 1, 1, 4507, 984, 'WONDERFUL DROP')
# (1, 1, 1, 4508, 985, 'WONDERLAND CHRISTMAS')
# (1, 1, 1, 4509, 985, 'WONDERLAND CHRISTMAS')
# (1, 1, 1, 4510, 985, 'WONDERLAND CHRISTMAS')
# (1, 1, 1, 4511, 985, 'WONDERLAND CHRISTMAS')
# (2, 2, 2, 4512, 985, 'WONDERLAND CHRISTMAS')
# (2, 2, 2, 4513, 985, 'WONDERLAND CHRISTMAS')
# (2, 2, 2, 4514, 985, 'WONDERLAND CHRISTMAS')
# (2, 2, 2, 4519, 986, 'WONKA SEA')
# (2, 2, 2, 4520, 986, 'WONKA SEA')
# (1, 1, 1, 4515, 986, 'WONKA SEA')
# (1, 1, 1, 4516, 986, 'WONKA SEA')
# (1, 1, 1, 4517, 986, 'WONKA SEA')
# (1, 1, 1, 4518, 986, 'WONKA SEA')
# (1, 1, 1, 4521, 987, 'WORDS HUNTER')
# (1, 1, 1, 4522, 987, 'WORDS HUNTER')
# (2, 2, 2, 4523, 987, 'WORDS HUNTER')
# (2, 2, 2, 4524, 987, 'WORDS HUNTER')
# (2, 2, 2, 4528, 988, 'WORKER TARZAN')
# (2, 2, 2, 4529, 988, 'WORKER TARZAN')
# (1, 1, 1, 4525, 988, 'WORKER TARZAN')
# (1, 1, 1, 4526, 988, 'WORKER TARZAN')
# (1, 1, 1, 4527, 988, 'WORKER TARZAN')
# (1, 1, 1, 4530, 989, 'WORKING MICROCOSMOS')
# (1, 1, 1, 4531, 989, 'WORKING MICROCOSMOS')
# (1, 1, 1, 4532, 989, 'WORKING MICROCOSMOS')
# (1, 1, 1, 4533, 989, 'WORKING MICROCOSMOS')
# (2, 2, 2, 4534, 989, 'WORKING MICROCOSMOS')
# (2, 2, 2, 4535, 989, 'WORKING MICROCOSMOS')
# (2, 2, 2, 4536, 990, 'WORLD LEATHERNECKS')
# (2, 2, 2, 4537, 990, 'WORLD LEATHERNECKS')
# (2, 2, 2, 4540, 991, 'WORST BANGER')
# (2, 2, 2, 4541, 991, 'WORST BANGER')
# (2, 2, 2, 4542, 991, 'WORST BANGER')
# (1, 1, 1, 4538, 991, 'WORST BANGER')
# (1, 1, 1, 4539, 991, 'WORST BANGER')
# (2, 2, 2, 4543, 992, 'WRATH MILE')
# (2, 2, 2, 4544, 992, 'WRATH MILE')
# (2, 2, 2, 4545, 992, 'WRATH MILE')
# (2, 2, 2, 4546, 992, 'WRATH MILE')
# (2, 2, 2, 4551, 993, 'WRONG BEHAVIOR')
# (2, 2, 2, 4552, 993, 'WRONG BEHAVIOR')
# (2, 2, 2, 4553, 993, 'WRONG BEHAVIOR')
# (1, 1, 1, 4547, 993, 'WRONG BEHAVIOR')
# (1, 1, 1, 4548, 993, 'WRONG BEHAVIOR')
# (1, 1, 1, 4549, 993, 'WRONG BEHAVIOR')
# (1, 1, 1, 4550, 993, 'WRONG BEHAVIOR')
# (1, 1, 1, 4554, 994, 'WYOMING STORM')
# (1, 1, 1, 4555, 994, 'WYOMING STORM')
# (1, 1, 1, 4556, 994, 'WYOMING STORM')
# (1, 1, 1, 4557, 995, 'YENTL IDAHO')
# (1, 1, 1, 4558, 995, 'YENTL IDAHO')
# (1, 1, 1, 4559, 995, 'YENTL IDAHO')
# (1, 1, 1, 4560, 995, 'YENTL IDAHO')
# (2, 2, 2, 4561, 995, 'YENTL IDAHO')
# (2, 2, 2, 4562, 995, 'YENTL IDAHO')
# (1, 1, 1, 4563, 996, 'YOUNG LANGUAGE')
# (1, 1, 1, 4564, 996, 'YOUNG LANGUAGE')
# (1, 1, 1, 4565, 997, 'YOUTH KICK')
# (1, 1, 1, 4566, 997, 'YOUTH KICK')
# (2, 2, 2, 4567, 998, 'ZHIVAGO CORE')
# (2, 2, 2, 4568, 998, 'ZHIVAGO CORE')
# (2, 2, 2, 4571, 999, 'ZOOLANDER FICTION')
# (2, 2, 2, 4572, 999, 'ZOOLANDER FICTION')
# (2, 2, 2, 4573, 999, 'ZOOLANDER FICTION')
# (1, 1, 1, 4569, 999, 'ZOOLANDER FICTION')
# (1, 1, 1, 4570, 999, 'ZOOLANDER FICTION')
# (1, 1, 1, 4574, 1000, 'ZORRO ARK')
# (1, 1, 1, 4575, 1000, 'ZORRO ARK')
# (1, 1, 1, 4576, 1000, 'ZORRO ARK')
# (1, 1, 1, 4577, 1000, 'ZORRO ARK')
# (2, 2, 2, 4578, 1000, 'ZORRO ARK')
# (2, 2, 2, 4579, 1000, 'ZORRO ARK')
# (2, 2, 2, 4580, 1000, 'ZORRO ARK')
# (2, 2, 2, 4581, 1000, 'ZORRO ARK')
