# %% [markdown]
# #### A company has customer data that contains 8 columns of customer details and another table having name customer_policy data contains the policy details of the customer. The company intends to offer some discount in premium for certain customers. To do that they ask their Data scientist team to get some information. Hence, following tasks DS team decided to perform:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Table1 ( customer_details )

# %%
#importing customer_details.csv
df1=pd.read_csv('customer_details.csv')
df1
# Out:
#                0       1     2    3     4    5          6    7
# 0            1.0    Male  44.0  1.0  28.0  0.0  > 2 Years  Yes
# 1            2.0    Male  76.0  1.0   3.0  0.0   1-2 Year   No
# 2            3.0    Male  47.0  1.0  28.0  0.0  > 2 Years  Yes
# 3            4.0    Male  21.0  1.0  11.0  1.0   < 1 Year   No
# 4            5.0  Female  29.0  1.0  41.0  1.0   < 1 Year   No
# ...          ...     ...   ...  ...   ...  ...        ...  ...
# 381104  381105.0    Male  74.0  1.0  26.0  1.0   1-2 Year   No
# 381105  381106.0    Male  30.0  1.0  37.0  1.0   < 1 Year   No
# 381106  381107.0    Male  21.0  1.0  30.0  1.0   < 1 Year   No
# 381107  381108.0  Female  68.0  1.0  14.0  0.0  > 2 Years  Yes
# 381108  381109.0    Male  46.0  1.0  29.0  0.0   1-2 Year   No
#
# [381109 rows x 8 columns]

# %%
# Column Name for customer details table:
df1.columns=['customer_id', 'Gender','age',  'driving_licence_present','region_code','previously_insured','vehicle_age','vehicle_damage']
df1
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    Male  74.0                      1.0         26.0
# 381105     381106.0    Male  30.0                      1.0         37.0
# 381106     381107.0    Male  21.0                      1.0         30.0
# 381107     381108.0  Female  68.0                      1.0         14.0
# 381108     381109.0    Male  46.0                      1.0         29.0
#
#         previously_insured vehicle_age vehicle_damage
# ...

# %%
# checking and cleaning data from customer_details.csv
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   customer_id              380723 non-null  float64
#  1   Gender                   380741 non-null  object
#  2   age                      380741 non-null  float64
#  3   driving_licence_present  380716 non-null  float64
#  4   region_code              380717 non-null  float64
#  5   previously_insured       380728 non-null  float64
#  6   vehicle_age              380728 non-null  object
#  7   vehicle_damage           380702 non-null  object
# dtypes: float64(5), object(3)
# memory usage: 23.3+ MB

# %%
# Null values of columns
# Generate a summary of count of all the null values column wise

print('Null Values in Cusmoter_id:',df1['customer_id'].isna().sum())
print('Null Values in Gender:',df1['Gender'].isna().sum())
print('Null Values in age:',df1['age'].isna().sum())
print('Null Values in driving_licence_present:',df1['driving_licence_present'].isna().sum())
print('Null Values in region_code:',df1['region_code'].isna().sum())
print('Null Values in previously_insured:',df1['previously_insured'].isna().sum())
print('Null Values in vehicle_age:',df1['vehicle_age'].isna().sum())
print('Null Values in vehicle_damage:',df1['vehicle_damage'].isna().sum())
# Out:
# Null Values in Cusmoter_id: 386
# Null Values in Gender: 368
# Null Values in age: 368
# Null Values in driving_licence_present: 393
# Null Values in region_code: 392
# Null Values in previously_insured: 381
# Null Values in vehicle_age: 381
# Null Values in vehicle_damage: 407

# %%
#droping and filling null values
#Drop Null values for customer_id because central tendencies for id’s is not feasible.

df1.dropna(subset=['customer_id'])
df1.dropna(inplace=True)
print('Null Values in Cusmoter_id after droping Null values:',df1['customer_id'].isna().sum())
# Out:
# Null Values in Cusmoter_id after droping Null values: 0

# %%
#Replace all null values for numeric columns by mean. 

df1['age'].fillna(df1['age'].mean(),inplace=True)
print('Null Values in age after droping Null values:',df1['age'].isna().sum())
# Out:
# Null Values in age after droping Null values: 0

# %%
# Replace all null values for Categorical value by mode.

df1['driving_licence_present'].fillna(df1['driving_licence_present'].mode()[0],inplace=True)
print('Null Values in driving_licence_present after droping Null values:',df1['driving_licence_present'].isna().sum())
 
df1['region_code'].fillna(df1['region_code'].mode()[0],inplace=True)
print('Null Values in region_code after droping Null values:',df1['region_code'].isna().sum())
 
df1['previously_insured'].fillna(df1['previously_insured'].mode()[0],inplace=True)
print('Null Values in previously_insured after droping Null values:',df1['previously_insured'].isna().sum())

df1['customer_id'].fillna(df1['customer_id'].mode()[0],inplace=True)
print('Null Values in Cusmoter_id after droping Null values:',df1['customer_id'].isna().sum())

df1['Gender'].fillna(df1['Gender'].mode()[0],inplace=True)
print('Null Values in Gender after droping Null values:',df1['Gender'].isna().sum())
 
df1['vehicle_age'].fillna(df1['vehicle_age'].mode()[0],inplace=True)
print('Null Values in vehicle_age after droping Null values:',df1['vehicle_age'].isna().sum())
 
df1['vehicle_damage'].fillna(df1['vehicle_damage'].mode()[0],inplace=True)
print('Null Values in vehicle_damage after droping Null values:',df1['vehicle_damage'].isna().sum())
# Out:
# Null Values in driving_licence_present after droping Null values: 0
# Null Values in region_code after droping Null values: 0
# Null Values in previously_insured after droping Null values: 0
# Null Values in Cusmoter_id after droping Null values: 0
# Null Values in Gender after droping Null values: 0
# Null Values in vehicle_age after droping Null values: 0
# Null Values in vehicle_damage after droping Null values: 0

# %% [markdown]
# #### (Hint1: for outlier treatment use IQR method as follows: For example: for a column X calculate Q1 = 25th percentile and Q3 = 75th percentile then IQR = Q3 – Q1 ) then to check outlier, anything lower than a Q1 – 1.5IQR or greater than Q3 + 1.5 IQR would be an outlier, Hint2: For getting percentile value, explore pd.describe() function)

# %%
df1.describe()
# Out:
#          customer_id            age  driving_licence_present    region_code  \
# count  378049.000000  378049.000000            378049.000000  378049.000000
# mean   190573.212919      38.821208                 0.997873      26.392764
# std    110017.560502      15.510030                 0.046067      13.230727
# min         1.000000      20.000000                 0.000000       0.000000
# 25%     95304.000000      25.000000                 1.000000      15.000000
# 50%    190574.000000      36.000000                 1.000000      28.000000
# 75%    285866.000000      49.000000                 1.000000      35.000000
# max    381109.000000      85.000000                 1.000000      52.000000
#
#        previously_insured
# count       378049.000000
# mean             0.458195
# std              0.498250
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              1.000000

# %%
# Generate a summary of count of all the outliers column wise
# Replace all outlier values for numeric columns by mean. 

Q1=df1.describe().loc["25%","age"]
Q3=df1.describe().loc["75%","age"]

IQR=Q3-Q1
print("IQR value of age",IQR)

print('Outliners in age:',(Q1-IQR*1.5))
print('Outliners in age:',(Q3+IQR*1.5))

print('Outliners in age:',df1.loc[df1["age"]<(Q1-IQR*1.5),"age"].count())
print('Outliners in age:',df1.loc[df1["age"]>(Q3+IQR*1.5),"age"].count())
# Out:
# IQR value of age 24.0
# Outliners in age: -11.0
# Outliners in age: 85.0
# Outliners in age: 0
# Outliners in age: 0

# %%
Q1=df1.describe().loc["25%","driving_licence_present"]
Q3=df1.describe().loc["75%","driving_licence_present"]

IQR=Q3-Q1
print("IQR value of driving_licence_present",IQR)

print('Outliners in driving_licence_present:',(Q1-IQR*1.5))
print('Outliners in driving_licence_present:',(Q3+IQR*1.5))

print('Outliners in driving_licence_present:',df1.loc[df1["driving_licence_present"]<(Q1-IQR*1.5),"driving_licence_present"].count())
print('Outliners in driving_licence_present:',df1.loc[df1["driving_licence_present"]>(Q3+IQR*1.5),"driving_licence_present"].count())
# Out:
# IQR value of driving_licence_present 0.0
# Outliners in driving_licence_present: 1.0
# Outliners in driving_licence_present: 1.0
# Outliners in driving_licence_present: 804
# Outliners in driving_licence_present: 0

# %%
Q1=df1.describe().loc["25%","region_code"]
Q3=df1.describe().loc["75%","region_code"]

IQR=Q3-Q1
print("IQR value of region_code",IQR)

print('Outliners in region_code:',(Q1-IQR*1.5))
print('Outliners in region_code:',(Q3+IQR*1.5))
print('Outliners in region_code:',df1.loc[df1["region_code"]<(Q1-IQR*1.5),"region_code"].count())
print('Outliners in region_code:',df1.loc[df1["region_code"]>(Q3+IQR*1.5),"region_code"].count())
# Out:
# IQR value of region_code 20.0
# Outliners in region_code: -15.0
# Outliners in region_code: 65.0
# Outliners in region_code: 0
# Outliners in region_code: 0

# %%
Q1=df1.describe().loc["25%","previously_insured"]
Q3=df1.describe().loc["75%","previously_insured"]

IQR=Q3-Q1
print("IQR value of previously_insured",IQR)

print('Outliners in previously_insured:',(Q1-IQR*1.5))
print('Outliners in previously_insured:',(Q3+IQR*1.5))
print('Outliners in previously_insured:',df1.loc[df1["previously_insured"]<(Q1-IQR*1.5),"previously_insured"].count())
print('Outliners in previously_insured:',df1.loc[df1["previously_insured"]>(Q3+IQR*1.5),"previously_insured"].count())
# Out:
# IQR value of previously_insured 1.0
# Outliners in previously_insured: -1.5
# Outliners in previously_insured: 2.5
# Outliners in previously_insured: 0
# Outliners in previously_insured: 0

# %%
# Remove white spaces

df1["Gender"]=df1["Gender"].str.strip()
df1["vehicle_age"]=df1["vehicle_age"].str.strip()
df1["vehicle_damage"]=df1["vehicle_damage"].str.strip()
df1
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    Male  74.0                      1.0         26.0
# 381105     381106.0    Male  30.0                      1.0         37.0
# 381106     381107.0    Male  21.0                      1.0         30.0
# 381107     381108.0  Female  68.0                      1.0         14.0
# 381108     381109.0    Male  46.0                      1.0         29.0
#
#         previously_insured vehicle_age vehicle_damage
# ...

# %%
# case correction(lower or upper, any one) 

df1["Gender"]=df1["Gender"].str.upper()
df1["vehicle_age"]=df1["vehicle_age"].str.upper()
df1["vehicle_damage"]=df1["vehicle_damage"].str.upper()
df1
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0    MALE  44.0                      1.0         28.0
# 1               2.0    MALE  76.0                      1.0          3.0
# 2               3.0    MALE  47.0                      1.0         28.0
# 3               4.0    MALE  21.0                      1.0         11.0
# 4               5.0  FEMALE  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    MALE  74.0                      1.0         26.0
# 381105     381106.0    MALE  30.0                      1.0         37.0
# 381106     381107.0    MALE  21.0                      1.0         30.0
# 381107     381108.0  FEMALE  68.0                      1.0         14.0
# 381108     381109.0    MALE  46.0                      1.0         29.0
#
#         previously_insured vehicle_age vehicle_damage
# ...

# %%
# Convert nominal data (categorical) into dummies 
# for future modeling use if required
dummies_gender=pd.get_dummies(df1["Gender"])
dummies_gender
# Out:
#         FEMALE  MALE
# 0            0     1
# 1            0     1
# 2            0     1
# 3            0     1
# 4            1     0
# ...        ...   ...
# 381104       0     1
# 381105       0     1
# 381106       0     1
# 381107       1     0
# 381108       0     1
#
# [378049 rows x 2 columns]

# %%
dummies_vehicle_age=pd.get_dummies(df1["vehicle_age"])
dummies_vehicle_age
# Out:
#         1-2 YEAR  < 1 YEAR  > 2 YEARS
# 0              0         0          1
# 1              1         0          0
# 2              0         0          1
# 3              0         1          0
# 4              0         1          0
# ...          ...       ...        ...
# 381104         1         0          0
# 381105         0         1          0
# 381106         0         1          0
# 381107         0         0          1
# 381108         1         0          0
#
# [378049 rows x 3 columns]

# %%
dummies_vehicle_damage=pd.get_dummies(df1["vehicle_damage"])
dummies_vehicle_damage
# Out:
#         NO  YES
# 0        0    1
# 1        1    0
# 2        0    1
# 3        1    0
# 4        1    0
# ...     ..  ...
# 381104   1    0
# 381105   1    0
# 381106   1    0
# 381107   0    1
# 381108   1    0
#
# [378049 rows x 2 columns]

# %%
dummies_dlp=pd.get_dummies(df1["driving_licence_present"])
dummies_dlp
# Out:
#         0.0  1.0
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ...     ...  ...
# 381104    0    1
# 381105    0    1
# 381106    0    1
# 381107    0    1
# 381108    0    1
#
# [378049 rows x 2 columns]

# %%
dummies_pi=pd.get_dummies(df1["previously_insured"])
dummies_pi
# Out:
#         0.0  1.0
# 0         1    0
# 1         1    0
# 2         1    0
# 3         0    1
# 4         0    1
# ...     ...  ...
# 381104    0    1
# 381105    0    1
# 381106    0    1
# 381107    1    0
# 381108    1    0
#
# [378049 rows x 2 columns]

# %%
#Drop duplicates (duplicated rows)

print(df1.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Table 2  ( customer_policy_details )

# %%
df2 = pd.read_csv("customer_policy_details.csv")
df2
# Out:
#                0        1      2      3    4
# 0            1.0  40454.0   26.0  217.0  1.0
# 1            2.0  33536.0   26.0  183.0  0.0
# 2            3.0  38294.0   26.0   27.0  1.0
# 3            4.0  28619.0  152.0  203.0  0.0
# 4            5.0  27496.0  152.0   39.0  0.0
# ...          ...      ...    ...    ...  ...
# 381104  381105.0  30170.0   26.0   88.0  0.0
# 381105  381106.0  40016.0  152.0  131.0  0.0
# 381106  381107.0  35118.0  160.0  161.0  0.0
# 381107  381108.0  44617.0  124.0   74.0  0.0
# 381108  381109.0  41777.0   26.0  237.0  0.0
#
# [381109 rows x 5 columns]

# %%
# Column Name for customer_policy table:
df2.columns=['customer_id','annual_premium(Rs)','sales_channel_code','vintage','response']

df2
# Out:
#         customer_id  annual_premium(Rs)  sales_channel_code  vintage  response
# 0               1.0             40454.0                26.0    217.0       1.0
# 1               2.0             33536.0                26.0    183.0       0.0
# 2               3.0             38294.0                26.0     27.0       1.0
# 3               4.0             28619.0               152.0    203.0       0.0
# 4               5.0             27496.0               152.0     39.0       0.0
# ...             ...                 ...                 ...      ...       ...
# 381104     381105.0             30170.0                26.0     88.0       0.0
# 381105     381106.0             40016.0               152.0    131.0       0.0
# 381106     381107.0             35118.0               160.0    161.0       0.0
# 381107     381108.0             44617.0               124.0     74.0       0.0
# 381108     381109.0             41777.0                26.0    237.0       0.0
#
# ...

# %%
#checking and cleaning data from customer_details.csv
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   customer_id         380722 non-null  float64
#  1   annual_premium(Rs)  380763 non-null  float64
#  2   sales_channel_code  380709 non-null  float64
#  3   vintage             380721 non-null  float64
#  4   response            380748 non-null  float64
# dtypes: float64(5)
# memory usage: 14.5 MB

# %%
# Null values of columns
# Generate a summary of count of all the null values column wise

print('Null Values in Cusmoter_id:',df2['customer_id'].isna().sum())
print('Null Values in annual_premium(Rs):',df2['annual_premium(Rs)'].isna().sum())
print('Null Values in sales_channel_code:',df2['sales_channel_code'].isna().sum())
print('Null Values in vintage:',df2['vintage'].isna().sum())
print('Null Values in response:',df2['response'].isna().sum())
# Out:
# Null Values in Cusmoter_id: 387
# Null Values in annual_premium(Rs): 346
# Null Values in sales_channel_code: 400
# Null Values in vintage: 388
# Null Values in response: 361

# %%
#droping and filling null values
#Drop Null values for customer_id because central tendencies for id’s is not feasible.
df2.dropna(subset=['customer_id'])
df2.dropna(inplace=True)
print('Null Values in Cusmoter_id after droping Null values:',df2['customer_id'].isna().sum())
# Out:
# Null Values in Cusmoter_id after droping Null values: 0

# %%
#Replace all null values for numeric columns by mean.

df2['annual_premium(Rs)'].fillna(df2['annual_premium(Rs)'].mean(),inplace=True)
print('Null Values in annual_premium(Rs) after droping Null values:',df2['annual_premium(Rs)'].isna().sum())
 
df2['sales_channel_code'].fillna(df2['sales_channel_code'].mean,inplace=True)
print('Null Values in sales_channel_code after droping Null values:',df2['sales_channel_code'].isna().sum())
 
df2['vintage'].fillna(df2['vintage'].mean,inplace=True)
print('Null Values in vintage after droping Null values:',df2['vintage'].isna().sum())
 
df2['response'].fillna(df2['response'].mean,inplace=True)
print('Null Values in response after droping Null values:',df2['response'].isna().sum())
# Out:
# Null Values in annual_premium(Rs) after droping Null values: 0
# Null Values in sales_channel_code after droping Null values: 0
# Null Values in vintage after droping Null values: 0
# Null Values in response after droping Null values: 0

# %%
df2.describe()
# Out:
#          customer_id  annual_premium(Rs)  sales_channel_code        vintage  \
# count  379231.000000       379231.000000       379231.000000  379231.000000
# mean   190548.188698        30564.974251          112.034488     154.349233
# std    110009.267483        17197.813416           54.207671      83.669422
# min         1.000000         2630.000000            1.000000      10.000000
# 25%     95290.500000        24407.500000           29.000000      82.000000
# 50%    190530.000000        31669.000000          133.000000     154.000000
# 75%    285804.500000        39403.000000          152.000000     227.000000
# max    381109.000000       540165.000000          163.000000     299.000000
#
#             response
# count  379231.000000
# mean        0.122530
# std         0.327897
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
# Generate a summary of count of all the outliers column wise
# Replace all outlier values for numeric columns by mean. 

Q1=df2.describe().loc["25%","annual_premium(Rs)"]
Q3=df2.describe().loc["75%","annual_premium(Rs)"]

IQR=Q3-Q1
print("IQR value of annual_premium(Rs)",IQR)

print('Outliners in annual_premium(Rs):',(Q1-IQR*1.5))
print('Outliners in annual_premium(Rs):',(Q3+IQR*1.5))

print('Outliners in annual_premium(Rs):',df2.loc[df2["annual_premium(Rs)"]<(Q1-IQR*1.5),"annual_premium(Rs)"].count())
print('Outliners in annual_premium(Rs):',df2.loc[df2["annual_premium(Rs)"]>(Q3+IQR*1.5),"annual_premium(Rs)"].count())
# Out:
# IQR value of annual_premium(Rs) 14995.5
# Outliners in annual_premium(Rs): 1914.25
# Outliners in annual_premium(Rs): 61896.25
# Outliners in annual_premium(Rs): 0
# Outliners in annual_premium(Rs): 10261

# %%
a = (df2[["annual_premium(Rs)"]]<(Q1-IQR*1.5)) | (df2[["annual_premium(Rs)"]]>(Q3+IQR*1.5))
b = a[a["annual_premium(Rs)"]].index
b
# Out:
# Int64Index([    25,     37,     67,    139,    149,    167,    176,    216,
#                310,    315,
#             ...
#             380655, 380733, 380761, 380815, 380860, 380959, 380998, 381035,
#             381047, 381079],
#            dtype='int64', length=10261)

# %%
df2.loc[b,"annual_premium(Rs)"]=df2["annual_premium(Rs)"].mean()

# %%
Q1=df2.describe().loc["25%","sales_channel_code"]
Q3=df2.describe().loc["75%","sales_channel_code"]

IQR=Q3-Q1
print("IQR value of sales_channel_code",IQR)

print('Outliners in sales_channel_code:',(Q1-IQR*1.5))
print('Outliners in sales_channel_code:',(Q3+IQR*1.5))

print('Outliners in sales_channel_code:',df2.loc[df2["sales_channel_code"]<(Q1-IQR*1.5),"sales_channel_code"].count())
print('Outliners in sales_channel_code:',df2.loc[df2["sales_channel_code"]>(Q3+IQR*1.5),"sales_channel_code"].count())
# Out:
# IQR value of sales_channel_code 123.0
# Outliners in sales_channel_code: -155.5
# Outliners in sales_channel_code: 336.5
# Outliners in sales_channel_code: 0
# Outliners in sales_channel_code: 0

# %%
Q1=df2.describe().loc["25%","vintage"]
Q3=df2.describe().loc["75%","vintage"]

IQR=Q3-Q1
print("IQR value of vintage",IQR)

print('Outliners in vintage:',(Q1-IQR*1.5))
print('Outliners in vintage:',(Q3+IQR*1.5))

print('Outliners in vintage:',df2.loc[df2["vintage"]<(Q1-IQR*1.5),"vintage"].count())
print('Outliners in vintage:',df2.loc[df2["vintage"]>(Q3+IQR*1.5),"vintage"].count())
# Out:
# IQR value of vintage 145.0
# Outliners in vintage: -135.5
# Outliners in vintage: 444.5
# Outliners in vintage: 0
# Outliners in vintage: 0

# %%
Q1=df2.describe().loc["25%","response"]
Q3=df2.describe().loc["75%","response"]

IQR=Q3-Q1
print("IQR value of response",IQR)

print('Outliners in response:',(Q1-IQR*1.5))
print('Outliners in response:',(Q3+IQR*1.5))

print('Outliners in response:',df2.loc[df2["response"]<(Q1-IQR*1.5),"response"].count())
print('Outliners in response:',df2.loc[df2["response"]>(Q3+IQR*1.5),"response"].count())
# Out:
# IQR value of response 0.0
# Outliners in response: 0.0
# Outliners in response: 0.0
# Outliners in response: 0
# Outliners in response: 46467

# %%
c = (df2[["response"]]<(Q1-IQR*1.5)) | (df2[["response"]]>(Q3+IQR*1.5))
d = c[c["response"]].index
d
# Out:
# Int64Index([     0,      2,      7,     10,     15,     19,     26,     29,
#                 57,     69,
#             ...
#             380987, 380997, 381026, 381029, 381031, 381057, 381061, 381073,
#             381075, 381097],
#            dtype='int64', length=46467)

# %%
df2.loc[d,"response"]=df2["response"].mean()

# %%
df2['annual_premium(Rs)']
# Out:
# 0         40454.0
# 1         33536.0
# 2         38294.0
# 3         28619.0
# 4         27496.0
#            ...
# 381104    30170.0
# 381105    40016.0
# 381106    35118.0
# 381107    44617.0
# 381108    41777.0
# Name: annual_premium(Rs), Length: 379231, dtype: float64

# %%
# white space,case correction,creating dummies not because there is no nominal data
print(df2.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Table 1 ( customer_details ) and Table 2 ( customer_policy_details ) merge data

# %%
#Merging
master_data=pd.merge(df1,df2,on='customer_id')
master_data
# Out:
#         customer_id  Gender   age  driving_licence_present  region_code  \
# 0               1.0    MALE  44.0                      1.0         28.0
# 1               2.0    MALE  76.0                      1.0          3.0
# 2               3.0    MALE  47.0                      1.0         28.0
# 3               4.0    MALE  21.0                      1.0         11.0
# 4               5.0  FEMALE  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 376179     381105.0    MALE  74.0                      1.0         26.0
# 376180     381106.0    MALE  30.0                      1.0         37.0
# 376181     381107.0    MALE  21.0                      1.0         30.0
# 376182     381108.0  FEMALE  68.0                      1.0         14.0
# 376183     381109.0    MALE  46.0                      1.0         29.0
#
#         previously_insured vehicle_age vehicle_damage  annual_premium(Rs)  \
# ...

# %%
#Gender wise average annual premium

Gender_wise_average_annual_premium = master_data.groupby(["Gender"])["annual_premium(Rs)"].mean()
Gender_wise_average_annual_premium
# Out:
# Gender
# FEMALE    29275.302038
# MALE      29322.847186
# Name: annual_premium(Rs), dtype: float64

# %%
import matplotlib.pyplot as pyplot
Gender_wise_average_annual_premium.plot()
pyplot.show()

# %%
#Age wise average annual premium

Age_wise_average_annual_premium = master_data.groupby(["age"])["annual_premium(Rs)"].mean()
Age_wise_average_annual_premium
# Out:
# age
# 20.0    26325.376814
# 21.0    29741.484658
# 22.0    29950.827249
# 23.0    29841.140853
# 24.0    30133.156848
#             ...
# 81.0    29287.962906
# 82.0    36480.619802
# 83.0    28995.862466
# 84.0    35440.818182
# 85.0    26637.543114
# Name: annual_premium(Rs), Length: 66, dtype: float64

# %%
import matplotlib.pyplot as pyplot
Age_wise_average_annual_premium.plot(color='r')
pyplot.show()

# %%
#Is your data balanced between the genders?

master_data.groupby('Gender').count()
# Out:
#         customer_id     age  driving_licence_present  region_code  \
# Gender
# FEMALE       172775  172775                   172775       172775
# MALE         203409  203409                   203409       203409
#
#         previously_insured  vehicle_age  vehicle_damage  annual_premium(Rs)  \
# Gender
# FEMALE              172775       172775          172775              172775
# MALE                203409       203409          203409              203409
#
#         sales_channel_code  vintage  response
# Gender
# FEMALE              172775   172775    172775
# MALE                203409   203409    203409

# %%
result_ftomratio = f"male to female ration is {round(master_data['Gender'].value_counts()[0]/master_data['Gender'].value_counts()[1],2)}"
print(result_ftomratio)
# Out:
# male to female ration is 1.18

# %%
print(f"generally, the standard is: \n balanced data ratio: {50/50}\n slightly balanced data ratio: {round(55/45,2)}-{60/40} \n imbalanced data ratio: {80/20}-{90/10}")
# Out:
# generally, the standard is:
#  balanced data ratio: 1.0
#  slightly balanced data ratio: 1.22-1.5
#  imbalanced data ratio: 4.0-9.0

# %%
#Vehicle age wise average annual premium. (Hint: Data is balanced if number of counts in each group is approximately same)

Vehicle_age_wise_average_annual_premium = master_data.groupby(["vehicle_age"])["annual_premium(Rs)"].mean()
Vehicle_age_wise_average_annual_premium
# Out:
# vehicle_age
# 1-2 YEAR     29099.895155
# < 1 YEAR     29191.645557
# > 2 YEARS    32945.012039
# Name: annual_premium(Rs), dtype: float64

# %%
import matplotlib.pyplot as pyplot
Vehicle_age_wise_average_annual_premium.plot(color='g')
pyplot.show()

# %%
#relation between Person Age and annual premium

master_data['age'].corr(master_data["annual_premium(Rs)"])
# Out:
# 0.050969404658155464

# %%
master_data[['age','annual_premium(Rs)']].corr()
# Out:
#                          age  annual_premium(Rs)
# age                 1.000000            0.050969
# annual_premium(Rs)  0.050969            1.000000

# %%
# 5. Is there any relation between Person Age and annual premium?
# (Hint: use correlation function (Correlation describes the relationship between two variables))
n = master_data['age'].corr(master_data['annual_premium(Rs)'])
if n<-0.5:
    print("Strong negative relationship")
if n>0.5:
    print("Strong positive relationship")
if n>-0.5 and n<0.5:
    print("There is no relationship!")
# Out:
# There is no relationship!
