# %% [markdown]
# # PYTHON MATPLOTLIB

# %%
# MATPLOTLIB
# import matplotlib
# checking matplotlib version (print(matplotlib.__version__))

# %%
import matplotlib

print(matplotlib.__version__) # the version string is stored under __version__ attribute
# Out:
# 3.4.3

# %% [markdown]
# Matplotlib Pyplot

# %% [markdown]
# Pyplot

# %%
""" most of the matplotlib utilites lies under the pyplot sub module,
and arer usually imported under the plt alias:"""
# import matplotlib.pyplot as plt]
# now pyplot package can be referred to as plt.

# %%
# example 
# darw a line in a diagram from position (0,0) to position (6,250)

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Matplotlib plotting ( plotting x and y points)

# %%
# darw a line in a diagram from position (1,3) to position (8,10)

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# b as dark blue line
# c as sky blue line
# d as dimond
# g as green line
# h, H as hexgon
# k as black line
# m as pink line 
# o as circle
# p pentagon
# s as square
# r as red
# v as down triangle
# w as empty
# x, X as cross point
# y as yellow
# ^ as upper dimond
# 1,2,3,4 as small fly wing rotation( down, up left, right)
# * as star
# . as point
# , as pixel
# <,> left triangle, right triangle
# + as plus 
# - as line
# 8 as cicle
# |, _ (v line, h line)

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints, ypoints, '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# MULTIPLE POINTS

# %%
import matplotlib as pyplt
import numpy as np

xpoints = np.array([2,3,5,6])
ypoints = np.array([50,150,100,250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2,3,5,6])
ypoints = np.array([50,150,100,250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib as pyplt
import numpy as np

xpoints = np.array([2,3,5,6])
ypoints = np.array([50,150,100,250])

plt.plot(xpoints, ypoints, 'm')
plt.show()

# %% [markdown]
# DEFAULT X-POINTS

# %%
# below x points use as default points

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7,])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 8, 2, 10, 4, 1,])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# DEFAULT Y POINTS

# %%
# below y of points use as default points

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 8, 2, 10, 4, 1,])

plt.plot(xpoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 8, 2, 10, 4, 1,])

plt.plot(ypoints, 'o')
plt.show()

# %% [markdown]
# MATPLOTLIB MARKERS

# %%
# MARKERS

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 6, 8, 2])
ypoints = np.array([2, 9, 6, 3])

plt.plot(xpoints, ypoints, marker='o')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2,3,5,6])
ypoints = np.array([50,150,100,250])

plt.plot(xpoints, ypoints, marker = '*')
plt.show()

plt.savefig(sys.stdout.buffer)
sys.stdoubt.flush()

# %% [markdown]
# FORMAT STRINGS fmt

# %%
# this parameter also known as fmt, and is written with this syntex
# marker|line|color
# '-' as solid line
# ':' as dotted line
#'--' as dashed line
# '-.' as dashed| dotted line

"""import marker but is written with this syntex """

# %%
# COLOR REFERENCE
# r as red 
# g as green
# b as blue 
# c as cyan
# m as magenta
# y as yellow
# k as black
# w as white

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,4,6,9])
ypoints = np.array([10, 100, 50, 160])

plt.plot(xpoints, ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,4,6,9])
ypoints = np.array([10, 100, 50, 160])

plt.plot(xpoints, ypoints, 'o-')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,4,6,9])
ypoints = np.array([10, 100, 50, 160])

plt.plot(xpoints, ypoints, 'o:')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,4,6,9])
ypoints = np.array([10, 100, 50, 160])

plt.plot(xpoints, ypoints, 'o--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,4,6,9])
ypoints = np.array([10, 100, 50, 160])

plt.plot(xpoints, ypoints, 'o-.c')
plt.show()

# %% [markdown]
# MARKER SIZE

# %%
# you can key word arugment maarkersize or the shorter version,
# ms to set the size of the markers:

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([20, 80, 40, 60])

plt.plot(xpoints, ypoints, 'o:', ms ='20')
plt.show()

# %% [markdown]
# MARKER COLOR

# %%
# you can use keyword arugemnt (markerdgecolor) or 
# the shorter mec to set the color of the edge of the markers:

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([20, 80, 40, 60])

plt.plot(xpoints, ypoints, 'o:b', ms = '10', mec = 'r')
plt.show()

# %% [markdown]
# MARKERFACE COLOR

# %%
# you can use the argument markerfacolor or
# shorter mfc to set the color inside the edge of the markers:

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([20, 80, 40, 60])

plt.plot(xpoints, ypoints, 'o:g', ms = '15', mec = 'k', mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([20, 80, 40, 60])

plt.plot(xpoints, ypoints, 'o:g', ms = '10', mec = 'r', mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([20, 80, 40, 60])

plt.plot(xpoints, ypoints, 'o:r', ms = '15', mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([20, 80, 40, 60])

plt.plot(xpoints, ypoints, 'o:g', ms = '10', mec = '#800080', mfc = '#800080')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([20, 80, 40, 60])

plt.plot(xpoints, ypoints, 'o:g', ms = '10', mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %% [markdown]
# MATPLOTLIB LINE

# %%
# LINESTYLE
# you can use the keyword argument linestyle, or
# shorter 'ls', to change to the style of the plotted line 
# linestyle can be written as ls = '-', = ':', ='--', = 'or'
# dotted can be written as :
# dashed can be written as --

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([10, 50, 20, 80])

plt.plot(xpoints, ypoints, ls = '-')
plt.show()

# %%
# LINE COLOR
# you can use the ketword argument color or
# the shorter c to set the color of the line:

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([10, 50, 20, 80])

plt.plot(xpoints, ypoints, color = 'r')  # color as written as c
plt.show()

# %%
# LINE WIDTH
# you can use the keywords argument linewidth or
# the shorter lw to change the width of the line.
# the value in the floating number, in points:

import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([10, 50, 20, 80])

plt.plot(xpoints, ypoints, linewidth = '20.5')
plt.show()

# ANOTHER CODE
xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([10, 50, 20, 80])

plt.plot(xpoints, ypoints, lw = '10.5')
plt.show()

# %%
# MULTIPLE LINES
# you can plot as many limes as you like by simply adding more
# plt.plot() functions:

# draw a two lines by specifying a plt.plot()
# function for each line:

import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, 'o:r', ms = '5', mec = 'k', mfc = 'b', lw = '2.5')
plt.plot(x2, y2, '*-g', ms = '8', mec = 'r', mfc = 'm', lw = '2.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, '*-g', x2, y2, 'o-r', ms = '5', mec = 'k', mfc = 'b', lw = '2.5')
plt.show()

# %% [markdown]
# CREATE TITLE AND LABEL FOR A PLOT

# %%
# CREATE LABELS FOR A PLOT
# with pyplot, you can use the xlabel() and ylabel() functions to set a label 
# for x and y axis

import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

plt.xlabel('8 months')
plt.ylabel('spent money')

plt.show()

# %%
# CREATE A TITle FOR A PLOT
# with pyplot, you can use the title() function to set a title for the plot
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

plt.title('vinay spent money')
plt.xlabel('8 months')
plt.ylabel('spent money')

plt.show()

# %% [markdown]
# SET FONT PROPERTIES FOR TITLE AND LABLES

# %%
# you can use the fontdict parameter in 
# xlabel(), ylabel() and title() to set font properties for the title and labels
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'blue','size':'20'}
font2 = {'family':'serif','color':'darkred','size':'15'}
plt.title("vinay spent money", fontdict = font1)
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'red','size':'20'}
font2 = {'family':'serif','color':'green','size':'15'}
plt.title("vinay spent money", fontdict = font1)
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)

plt.show()

# %% [markdown]
# POSITION THE TITLE

# %%
# you can use the loc parameter in title() to position the title.
# legel values are: 'left', 'right', and 'center'. DEFAULT values is 'center'

import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'blue','size':'20'}
font2 = {'family':'serif','color':'darkred','size':'15'}
plt.title("vinay spent money", fontdict = font1, loc = 'left')
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'blue','size':'20'}
font2 = {'family':'serif','color':'darkred','size':'15'}
plt.title("vinay spent money", fontdict = font1, loc = 'right')
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)

plt.show()

# %% [markdown]
# MATPLOTLIB ADDING GRID LINES

# %%
# ADD GRID LINES TO PLOT
# with pyplot, you can use the grid() function to add grid lines to the plot.
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'blue','size':'20'}
font2 = {'family':'serif','color':'darkred','size':'15'}
plt.title("vinay spent money", fontdict = font1)
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)

plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'blue','size':'20'}
font2 = {'family':'serif','color':'darkred','size':'15'}
plt.title("vinay spent money", fontdict = font1)
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)

plt.grid(axis = 'x')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'blue','size':'20'}
font2 = {'family':'serif','color':'darkred','size':'15'}
plt.title("vinay spent money", fontdict = font1)
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)

plt.grid( axis = 'y')

plt.show()

# %%
# GRID COLOR, LINESTYLE AND LINEWIDTH 
# shoter as c, ls, lw
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([2, 4, 6, 8])
x2 = np.array([1, 3, 5, 7])
y1 = np.array([10, 50, 20, 80])
y2 = np.array([60, 40, 70, 30])

plt.plot(x1, y1, x2, y2)

font1 = {'family':'serif','color':'blue','size':'20'}
font2 = {'family':'serif','color':'darkred','size':'15'}
plt.title("vinay spent money", fontdict = font1)
plt.xlabel("8 months", fontdict = font2)
plt.ylabel("spent money", fontdict = font2)
plt.grid(c = 'green', ls = '--', lw = '1')
plt.show()

# %% [markdown]
# MATPLOTLIB SUBPLOT

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(1, 2, 1) # (1 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y)

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(1, 2, 2) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(2, 1, 1) # (1 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y)

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(2, 1, 2) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(2, 2, 1) # (2 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y)

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(2, 2, 2) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y)

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(2, 2, 3) # (1 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y)

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(2, 2, 4) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y, '-g')
x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(2, 2, 1) # (1 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y, '-r')

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(2, 2, 2) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(3, 2, 1) # (2 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y, '-r')

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(3, 2, 2) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y, '-y')

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(3, 2, 3) # (1 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y, '-m')

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(3, 2, 4) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y, '-k')

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(3, 2, 5) # (1 ROW, 2 COLUMNS, 1 PLOT)
plt.plot(x,y)

x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(3, 2, 6) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.plot(x,y, '-g')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])

plt.subplot(1, 2, 1)# (1 ROW, 2 COLUMNS, 1 PLOT)
plt.title('income')
plt.xlabel('month')
plt.ylabel('money')
plt.plot(x,y)


x = np.array([1, 3, 5, 7])
y = np.array([60, 40, 70, 30])

plt.subplot(1, 2, 2) # (1 ROW, 2 COLUMNS, 2 PLOT)
plt.title('sales')
plt.xlabel('month')


plt.suptitle('AVERAGE GDP')

print(plt.plot(x,y));

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # MATPLOTLIN SCATTER

# %%
# CRAETING SCATTER PLOTS
# with pyplot, you can use the sactter functions to draw a scatter plot.
# the sactter function dot for each observation
# it needs two arrays of the same length,
# one of the value of x-axis,
# and one for values on the y-axis:

import matplotlib.pyplot as lt
import numpy as np

x = np.array([10, 50, 90, 40 ,50, 62, 41, 55, 75, 61, 63])
y = np.array([5, 6, 2, 4, 3, 9, 1, 8, 6, 4, 3])

plt.scatter(x,y, c = 'r')
plt.show()

# %%
import matplotlib.pyplot as lt
import numpy as np

x = np.array([10, 50, 90, 40 ,50, 62, 41, 55, 75, 61, 63])
y = np.array([5, 6, 2, 4, 3, 9, 1, 8, 6, 4, 3])

plt.scatter(x,y, c = 'r')

x = np.array([65, 82, 58, 24, 62, 45, 35, 75, 95, 54, 42])
y = np.array([9, 5, 9, 3, 7, 4, 3, 7, 6, 8, 1])

plt.scatter(x,y, c = 'darkgreen')
plt.title('GDP income', c = 'r', size = '20')
plt.xlabel('income', c = 'darkblue', size = '10')
plt.ylabel('months', c = 'darkgreen', size = '10')
plt.show()

# %%
import matplotlib.pyplot as lt
import numpy as np

x = np.array([10, 50, 90, 40 ,50, 62, 41])
y = np.array([5, 6, 2, 4, 3, 9, 1])
colors = np.array(['red','blue','green','hotpink','orange','purple','black'])

plt.scatter(x,y, c = colors)
plt.show()

# %%
# COLOR MAP 
# 0 - 20 PURPLE TO DARK BLUE
# 20 - 40 DARK BLUE TO SKY BLUE
# 40 - 60 sky blue to light green
# 60 - 80 light green to dark greeen
# 80 - 100 dark green to yellow

# %%
import matplotlib.pyplot as lt
import numpy as np

x = np.array([10, 50, 90, 40 ,50, 62, 41])
y = np.array([5, 6, 2, 4, 3, 9, 1])
colors = np.array([25,92,62,37,62,42,36])

plt.scatter(x,y, c = colors, cmap = 'viridis')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))

plt.scatter(x,y, c = colors, cmap = 'Accent')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))

plt.scatter(1, 2, 1)
plt.colorbar()
plt.scatter(x,y)

import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(200, size = (200))
y = np.random.randint(200, size = (200))
colors = np.random.randint(200, size = (200))

plt.scatter(2, 1, 2)
plt.colorbar()
plt.scatter(x,y)

plt.show()

# %%
# sizes of scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2, 4, 6, 8])
y = np.array([10, 50, 20, 80])
colors = np.array([52, 62, 75, 98])
sizes = np.array([12, 62, 32, 96])

plt.scatter(x, y, c = colors, s = sizes, alpha = 0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))
sizes = 10*np.random.randint(100, size = (100))
plt.scatter(x,y, c = colors, s = sizes, alpha = 0.5, cmap = 'nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # MATPLOTLIB BARS

# %%
# CREATINFG BARS
# with pyplot, you can use the bar() function to darw 
# bar graph:
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([1, 2, 3, 4])

plt.bar(x,y)
plt.title("waiting list", color = 'red', size = 20)
plt.xlabel("Alphabets", color = 'blue', size = 15)
plt.ylabel("Numbers", color = 'green', size =15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["apple", "bannana", "grape"])
y = np.array([85, 42, 63])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([1, 2, 3, 4])

plt.barh(x,y) # barh means horiziontal
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([1, 2, 3, 4])

plt.bar(x,y, color = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([1, 2, 3, 4])

plt.bar(x,y, alpha = 0.5, color = 'green', width = 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([1, 2, 3, 4])

plt.barh(x,y, alpha = 0.5, color = 'green', height = 0.5)
plt.show()

# %% [markdown]
# # HISTOGRAM

# %%
# A histogram is a graph showing frequency distributions.
# the graph showing the number of observations
# EX: say you ask for the heifghts 250 peoples,
# you might end up with a histogram like this:
import numpy as np

x = np.random.normal(170, 10, 50)

print(x);
# Out:
# [174.31453374 168.04731854 167.64427177 172.88317235 158.38538809
#  174.18320034 159.79002104 176.68908224 155.32391604 171.57546237
#  172.03331261 172.77890288 162.77416233 169.75290471 176.38529612
#  169.84953973 153.4841333  175.98730779 169.98913244 174.09748512
#  180.0831396  173.41903193 171.21995847 173.4493716  169.17734214
#  166.0280446  169.25982614 186.74038281 169.52651327 155.77668129
#  190.52814211 185.84828599 167.19212594 190.12164007 149.46300271
#  164.56307785 187.57226551 164.4636576  175.39470277 173.59991532
#  159.71871667 176.43046625 182.24649367 166.1376752  185.36256504
#  174.13164333 175.22668933 177.201169   168.83825603 145.29692735]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 50)

plt.hist(x, color = 'purple', width = 5)
plt.xlabel('population members', size = 15, color = 'red')
plt.ylabel('population heights', size = 15, color = 'green')
plt.title('population', size = 20, color = 'blue')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 50)

plt.hist(x, alpha = 0.5, color = 'r', width = 3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 50)

plt.hist(x, color = 'r', width = 2)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # MATPLOTLIB PIE CHARTS

# %%
# CREATING PIE CHARTS
# with pyplot, you can use the pie() function to 
# draw the pie charts:
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.title('num')
plt.show()

# %%
# CREATE A LABELS
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
# CRAETE START ANGLE
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
plt.pie(y, labels = mylabels, startangle = 0)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
myexplode = [0.2,0,0,0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
myexplode = [0.2,0.1,0.1,0.1]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
myexplode = [0.2,0,0,0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

labels = ['civil','electrical','mechanical','chemical']
sizes = [15,50,45,10]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.5f%%')
ax.axis('equal')
ax.set_title('engineering diciplines', size = 15)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
myexplode = [0.2,0.1,0.1,0.1]
mycolors = ["red", "purple", "lightgreen", "yellow"]

plt.pie(y, labels = mylabels, explode = myexplode, colors = mycolors, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["apple", "bananas", "grape", "lemon"]
myexplode = [0.2,0.1,0.1,0.1]
mycolors = ["red", "purple", "lightgreen", "yellow"]

plt.pie(y, labels = mylabels, explode = myexplode, colors = mycolors, shadow = True)
plt.legend( title = "Fruites")
plt.title('fruits', size = 20, color = 'blue')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

labels = ['civil','electrical','mechanical','chemical']
sizes = [15, 50, 45, 10]

explode = (0.1, 0.1, 0.1, 0.4)

fig, ax = plt.subplots()
ax.pie(sizes,
       explode=explode,
       labels=labels,
       autopct='%1.1f%%',
       shadow=True,
       startangle=90)
ax.axis('equal')
ax.set_title('engineering diciplines')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

labels = ['civil','electrical','mechanical','chemical']
sizes = [15, 30, 45, 10]

explode = (0.1, 0.1, 0.1, 0.1)

fig, ax = plt.subplots()
ax.pie(sizes,
       explode=explode,
       labels=labels,
       autopct='%1.1f%%',
       shadow=False,
       startangle=90)
ax.axis('equal')
ax.set_title('engineering diciplines')


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

sem11 = np.array([78])
sem12 = np.array([86])
sem21 = np.array([87])
sem22 = np.array([85])
sem31 = np.array([86])
sem32 = np.array([82])
sem41 = np.array([83])
sem42 = np.array([93])

sem11_mean = np.mean(sem11)
sem12_mean = np.mean(sem12)
sem21_mean = np.mean(sem21)
sem22_mean = np.mean(sem22)
sem31_mean = np.mean(sem31)
sem32_mean = np.mean(sem32)
sem41_mean = np.mean(sem41)
sem42_mean = np.mean(sem42)

semesters = ['sem11', 'sem12', 'sem21', 'sem22', 'sem31', 'sem32', 'sem41', 'sem42']
x_pos = np.arange(len(semesters))
CTEs = [sem11_mean, sem12_mean, sem21_mean, sem22_mean, sem31_mean, sem32_mean, sem41_mean, sem42_mean]

fig, ax = plt.subplots()

ax.bar(x_pos, CTEs, align='center', alpha=0.9)
ax.set_ylabel('semester percentage')
ax.set_xticks(x_pos)
ax.set_xticklabels(semesters)
ax.set_title('(vinay sai) SEMESTER RESULTS ENGINEERING', size = 15, color = 'red')
ax.yaxis.grid(True)

plt.tight_layout()
plt.savefig('bar_plot.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

aluminum = np.array([6.4e-5, 3.01e-5, 2.36e-5, 3.0e-5, 7.0e-5, 4.5e-5, 3.8e-5, 4.2e-5, 2.62e-5, 3.6e-5])
copper = np.array([4.5e-5, 1.97e-5, 1.6e-5, 1.97e-5, 4.0e-5, 2.4e-5, 1.9e-5, 2.41e-5, 1.85e-5, 3.3e-5])
steel = np.array([3.3e-5, 1.2e-5, 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 1.58e-5, 1.32e-5, 2.1e-5])

aluminum_mean = np.mean(aluminum)
copper_mean = np.mean(copper)
steel_mean = np.mean(steel)

materials = ['aluminum', 'copper', 'steel']
x_pos = np.arange(len(materials))
CTEs = [aluminum_mean, copper_mean, steel_mean]

fig, ax = plt.subplots()

ax.bar(x_pos, CTEs, align='center', alpha=0.5)
ax.set_ylabel('coefficient of thermal expansion(\degreeC^-1)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('COEFFICIENT OF THERMAL EXPANSION (CTE) OF THREE METALS')
ax.yaxis.grid(True)

plt.tight_layout()
plt.savefig('bar_plot.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x = np.linspace(0, 5.5, 10)
y = 10*np.exp(-x)
xerr = np.random.random_sample(10)
yerr = np.random.random_sample(10)

fig, ax = plt.subplots()

ax.errorbar(x, y,
           xerr=xerr,
           yerr=yerr,
           fmt='-0')

ax.set_xlabel('x_axis')
ax.set_ylabel('y_axis')
ax.set_title('line plot with error bars')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

aluminum = np.array([6.4e-5, 3.01e-5, 2.36e-5, 3.0e-5, 7.0e-5, 4.5e-5, 3.8e-5, 4.2e-5, 2.62e-5, 3.6e-5])
copper = np.array([4.5e-5, 1.97e-5, 1.6e-5, 1.97e-5, 4.0e-5, 2.4e-5, 1.9e-5, 2.41e-5, 1.85e-5, 3.3e-5])
steel = np.array([3.3e-5, 1.2e-5, 0.9e-5, 1.2e-5, 1.3e-5, 1.6e-5, 1.4e-5, 1.58e-5, 1.32e-5, 2.1e-5])

aluminum_mean = np.mean(aluminum)
copper_mean = np.mean(copper)
steel_mean = np.mean(steel)

aluminum_std = np.std(aluminum)
copper_std = np.std(copper)
steel_std = np.std(steel)

materials = ['aluminum', 'copper', 'steel']
x_pos = np.arange(len(materials))
CTEs = [aluminum_mean, copper_mean, steel_mean]
error= [aluminum_std, copper_std, steel_std]

fig, ax = plt.subplots()

ax.bar(x_pos,
       CTEs,
       yerr=error,
       align='center',
       alpha=0.5,
       ecolor='red',
       capsize=10)
ax.set_ylabel('coefficient of thermal expansion(\degreeC^-1)')
ax.set_xticks(x_pos)
ax.set_xticklabels(materials)
ax.set_title('COEFFICIENT OF THERMAL EXPANSION (CTE) OF THREE METALS')
ax.yaxis.grid(True)

plt.tight_layout()
plt.savefig('bar_plot_with_error_bars.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('fivethirtyeight')

mu = 80
sigma = 7
x = np.random.normal(mu, sigma, size=200)


fig, ax = plt.subplots()

ax.hist(x, 20)
ax.set_title('historgram')
ax.set_xlabel('bin range')
ax.set_ylabel('frequency')

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

data1 = np.random.normal(0, 20, 100)
data2 = np.random.normal(0, 9, 100)
data3 = np.random.normal(0, 8, 100)
data4 = np.random.normal(0, 10, 100)
data = list([data1, data2, data3, data4])

fig, ax = plt.subplots()

ax.boxplot(data)

ax.set_title('box_plot')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
xticklabels=['category 1', 'category 2', 'category 3', 'category 4']
ax.set_xticklabels(xticklabels)

ax.yaxis.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

data1 = np.random.normal(0, 6, 100)
data2 = np.random.normal(0, 7, 100)
data3 = np.random.normal(0, 8, 100)
data4 = np.random.normal(0, 9, 100)
data = list([data1, data2, data3, data4])

fig, ax = plt.subplots()

ax.violinplot(data, showmeans=False, showmedians=True)

ax.set_title('violin_plot')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
xticklabels=['category 1', 'category 2', 'category 3', 'category 4']
ax.set_xticks([1,2,3,4])
ax.set_xticklabels(xticklabels)

ax.yaxis.grid(True)

plt.show()
